# %%
import nltk
# import random
# import string
import re
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from collections import Counter
from nltk.util import ngrams
corpus = []
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
with open('/content/dataset_3.txt', 'r') as file:
    # Read the contents of the file
    data = file.read()

# Now you can perform data cleaning operations on the 'data' variable
# For example, you can split the text into lines
lines = data.split('\n')

# %%
ps = PorterStemmer()
all_stopwords = set(stopwords.words("english"))
all_stopwords.remove("not")

reviews = data.split("\n")

for review  in reviews:
    review = re.sub("[a^zA-Z]", " ", review)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if word not in all_stopwords]
    review = " ".join(review)
    corpus.append(review)

# %%
nltk.download('punkt')
token = nltk.word_tokenize(data)
token
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['1',
#  '“',
#  '18',
#  'months',
#  'ago',
#  ',',
#  'we',
#  'expelled',
#  'a',
#  'boy',
#  'at',
#  'Nations',
#  'for',
#  'selling',
#  'drugs',
#  'in',
#  'six',
#  'schools',
#  '.',
#  '2',
#  '”',
#  '41',
#  'Nigeria',
#  'Centre',
#  'for',
#  'Disease',
#  'Control',
#  '(',
#  'NCDC',
#  ')',
#  'staff',
#  'and',
#  '17',
#  'World',
#  'Health',
#  'Organisation',
#  '(',
#  'WHO',
#  ')',
#  'staff',
#  'are',
#  'deployed',
#  'at',
#  'the',
#  'moment',
#  'to',
#  'support',
#  'the',
#  'Kano',
#  'response',
#  '.',
#  '3',
#  '⏰8.00pm',
#  '⚽️Liverpool',
#  'v',
#  'Arsenal',
#  'Watch',
#  'the',
#  'match',
#  'live',
#  'at',
#  'The',
#  'Arch',
#  'on',
#  'six',
#  'screens',
#  'with',
#  'surround',
#  'sound',
#  'commentary',
#  '!',
#  '4',
#  'A',
#  '13-year',
#  'veteran',
#  'of',
#  'the',
#  'department',
#  ',',
#  'he',
#  'worked',
#  'his',
#  'way',
#  'up',
#  'the',
#  'ranks',
#  'of',
#  'the',
#  'department',
#  'starting',
#  'as',
#  'an',
#  'ambulance',
#  'paramedic',
#  'at',
#  'Station',
#  '49',
#  ',',
#  'then',
#  'going',
#  'to',
#  'the',
#  'SFFD',
#  'Academy',
#  'and',
#  'graduating',
#  'as',
#  'a',
#  'paramedic',
#  'and',
#  'firefighter',
#  '.',
#  '5',
#  'A',
#  '1975',
#  'class',
#  'ring',
#  'from',
#  'Robert',
#  'E.',
#  'Lee',
#  'High',
#  'School',
#  'in',
#  'Houston',
#  'was',
#  'found',
#  'near',
#  'the',
#  'bones',
#  '.',
#  '6',
#  'A',
#  '2014',
#  'resurgence',
#  'in',
#  'Polio',
#  'when',
#  'there',
#  'were',
#  '359',
#  'reported',
#  'cases',
#  'of',
#  'wild',
#  'poliomyelitis',
#  ',',
#  'spread',
#  'over',
#  '12',
#  'countries',
#  'including',
#  'Pakistan',
#  '.',
#  '7',
#  '“',
#  'A',
#  '30',
#  '%',
#  'correction',
#  'sounds',
#  'scary',
#  'right',
#  ',',
#  'but',
#  'the',
#  'Dow',
#  ',',
#  'S',
#  '&',
#  'P',
#  '500',
#  'and',
#  'the',
#  'Nasdaq',
#  'rallied',
#  'to',
#  'nearly',
#  '30',
#  '%',
#  'in',
#  'just',
#  'one',
#  'year',
#  'last',
#  'year',
#  '.',
#  '8',
#  'A',
#  '33-year-old',
#  'Bothwell',
#  'man',
#  'was',
#  'arrested',
#  'and',
#  'charged',
#  'with',
#  'public',
#  'mischief',
#  '.',
#  '9',
#  'A',
#  '58-year-old',
#  'barrister',
#  'who',
#  'served',
#  'in',
#  'the',
#  'Home',
#  'Office',
#  'and',
#  'the',
#  'attorney',
#  'general',
#  '’',
#  's',
#  'office',
#  ',',
#  'Mr.',
#  'Jones',
#  'rose',
#  'to',
#  'become',
#  'the',
#  'government',
#  '’',
#  's',
#  'senior',
#  'lawyer',
#  ',',
#  'rendering',
#  'judgment',
#  'on',
#  'the',
#  'legality',
#  'of',
#  'new',
#  'legislation',
#  '.',
#  '10',
#  'A',
#  '911',
#  'call',
#  'was',
#  'made',
#  'by',
#  'a',
#  'Wendy',
#  '’',
#  's',
#  'employee',
#  'after',
#  'Brooks',
#  'fell',
#  'asleep',
#  'behind',
#  'the',
#  'wheel',
#  'while',
#  'in',
#  'the',
#  'drive-thru',
#  'line',
#  '.',
#  '11',
#  'Aaron',
#  'and',
#  'Marie',
#  'are',
#  'sharing',
#  'a',
#  'bed',
#  '.',
#  '12',
#  'Aaron',
#  ',',
#  'as',
#  'a',
#  'Black',
#  'man',
#  'and',
#  'candidate',
#  'in',
#  'a',
#  'local',
#  'election',
#  'in',
#  'Humboldt',
#  'County',
#  ',',
#  'has',
#  'had',
#  'to',
#  'discover',
#  'ways',
#  'to',
#  'manage',
#  'his',
#  'own',
#  'stress',
#  'and',
#  'anxiety',
#  '.',
#  '13',
#  'Aaron',
#  'has',
#  'been',
#  'a',
#  'valuable',
#  'member',
#  'of',
#  'Alexandria',
#  'since',
#  'before',
#  'he',
#  'recruited',
#  'members',
#  'of',
#  'Rick',
#  "'s",
#  'group',
#  'to',
#  'the',
#  'Safe',
#  'Zone',
#  '.',
#  '14',
#  'Aave',
#  '(',
#  'AAVE',
#  ')',
#  'traded',
#  '5.4',
#  '%',
#  'lower',
#  'against',
#  'the',
#  'dollar',
#  'and',
#  'now',
#  'trades',
#  'at',
#  '$',
#  '34.47',
#  'or',
#  '0.00250836',
#  'BTC',
#  '.',
#  '15',
#  'Abandoning',
#  'a',
#  'healthy',
#  'and',
#  'highly',
#  'productive',
#  'scientific',
#  'collaboration',
#  'at',
#  'such',
#  'a',
#  'juncture',
#  'was',
#  'not',
#  'a',
#  'very',
#  'sound',
#  'move',
#  '.',
#  '16',
#  'Abang',
#  'Johari',
#  'said',
#  'it',
#  'was',
#  'imperative',
#  'for',
#  'the',
#  'state',
#  'to',
#  'restore',
#  'the',
#  'status',
#  'of',
#  'Sabah',
#  'and',
#  'Sarawak',
#  'as',
#  'regional',
#  'partners',
#  'after',
#  'the',
#  'departure',
#  'of',
#  'Singapore',
#  'in',
#  '1965',
#  'from',
#  'the',
#  'Federation',
#  'of',
#  'Malaysia',
#  '.',
#  '17',
#  'ABC',
#  "'s",
#  '``',
#  'Modern',
#  'Family',
#  "''",
#  'ends',
#  'its',
#  '11-season',
#  'run',
#  'with',
#  'a',
#  'two-hour',
#  'finale',
#  'on',
#  'Wednesday',
#  '.',
#  '18',
#  'A',
#  'Beer',
#  'Store',
#  'spokesperson',
#  'couldn',
#  '’',
#  't',
#  'be',
#  'reached',
#  'for',
#  'comment',
#  'at',
#  'press',
#  'time',
#  '.',
#  '19',
#  'Abela',
#  'had',
#  'attempted',
#  'to',
#  'justify',
#  'the',
#  'move',
#  'as',
#  'necessary',
#  'at',
#  'the',
#  'time',
#  'as',
#  'a',
#  'way',
#  'of',
#  'controlling',
#  'coronavirus',
#  'infections',
#  'in',
#  'the',
#  'country',
#  '.',
#  '20',
#  'Abelson',
#  'was',
#  "n't",
#  'able',
#  'to',
#  'help',
#  'everyone',
#  '.',
#  '21',
#  'Aberdeenshire',
#  'Council',
#  'said',
#  'they',
#  'first',
#  'considered',
#  'the',
#  'removal',
#  'of',
#  'the',
#  'town',
#  'centre',
#  'restrictions',
#  'in',
#  'September',
#  'but',
#  'did',
#  'not',
#  'go',
#  'ahead',
#  'with',
#  'this',
#  'after',
#  'coronavirus',
#  'infections',
#  'began',
#  'to',
#  'rise',
#  '.',
#  '22',
#  'A',
#  'Black',
#  'man',
#  'was',
#  'shot',
#  'and',
#  'killed',
#  'by',
#  'County',
#  'sheriff',
#  '’',
#  's',
#  'deputies',
#  'after',
#  'he',
#  'was',
#  'stopped',
#  'for',
#  'a',
#  'traffic',
#  'violation',
#  'while',
#  'riding',
#  'a',
#  'bike',
#  ',',
#  'then',
#  'ran',
#  'from',
#  'police',
#  ',',
#  'punched',
#  'one',
#  'officer',
#  'and',
#  'then',
#  '“',
#  'made',
#  'a',
#  'motion',
#  '”',
#  'toward',
#  'a',
#  'gun',
#  'on',
#  'the',
#  'ground',
#  ',',
#  'authorities',
#  'said',
#  '.',
#  '23',
#  'A',
#  'Black',
#  'passenger',
#  'says',
#  'he',
#  'asked',
#  'a',
#  'flight',
#  'attendant',
#  'if',
#  'he',
#  'could',
#  'change',
#  'seats',
#  'if',
#  'any',
#  'were',
#  'open',
#  '.',
#  '24',
#  'A',
#  'booby-trapped',
#  'tanker',
#  'truck',
#  'exploded',
#  'in',
#  'the',
#  'Syrian',
#  'city',
#  'of',
#  'Afrin',
#  ',',
#  'killing',
#  'or',
#  'injuring',
#  'dozens',
#  'of',
#  'civilians',
#  '(',
#  'Tuesday',
#  ',',
#  'April',
#  '28',
#  ',',
#  '2020',
#  ')',
#  '.',
#  '25',
#  'About',
#  '$',
#  '1.07billion',
#  'is',
#  'required',
#  'to',
#  'construct',
#  'Section',
#  'V',
#  'of',
#  'the',
#  'East-West',
#  'Road',
#  ',',
#  'Oron',
#  'in',
#  'Akwa',
#  'Ibom',
#  'state',
#  'to',
#  'Calabar',
#  ',',
#  'Cross',
#  'River',
#  'State',
#  '.',
#  '26',
#  'About',
#  '46,000',
#  'people',
#  'were',
#  'paid',
#  'a',
#  'total',
#  'of',
#  '20',
#  'million',
#  'pounds',
#  '—',
#  'the',
#  'equivalent',
#  'of',
#  '40',
#  'percent',
#  'of',
#  'all',
#  'annual',
#  'government',
#  'spending',
#  'at',
#  'the',
#  'time',
#  '—',
#  'after',
#  'the',
#  'freeing',
#  'of',
#  'slaves',
#  'in',
#  'British',
#  'colonies',
#  'in',
#  'the',
#  'Caribbean',
#  ',',
#  'Mauritius',
#  'and',
#  'southern',
#  'Africa',
#  '.',
#  '27',
#  'About',
#  '7,000',
#  'have',
#  'been',
#  'quarantined',
#  'in',
#  'the',
#  'central',
#  'Punjab',
#  'city',
#  'Lahore',
#  ',',
#  'while',
#  'in',
#  'southern',
#  'Sindh',
#  'province',
#  'up',
#  'to',
#  '8,000',
#  'Tablighis',
#  'have',
#  'been',
#  'quarantined',
#  ',',
#  'government',
#  'officials',
#  'said',
#  '.',
#  '28',
#  'About',
#  'a',
#  'half',
#  'of',
#  'them',
#  'I',
#  'wrote',
#  'within',
#  'a',
#  'week',
#  ',',
#  'and',
#  'I',
#  'think',
#  'that',
#  'helps',
#  'to',
#  'make',
#  'it',
#  'feel',
#  'like',
#  'it',
#  'was',
#  'all',
#  'the',
#  'same',
#  'thing',
#  '.',
#  '29',
#  '“',
#  'About',
#  'to',
#  'end',
#  'a',
#  'decade',
#  'long',
#  'relationship',
#  'with',
#  ',',
#  '”',
#  'wrote',
#  'another',
#  '.',
#  '30',
#  'About',
#  'two',
#  'weeks',
#  'later',
#  ',',
#  'Alden',
#  'entered',
#  'the',
#  'Avidia',
#  'Savings',
#  'Bank',
#  'on',
#  'Maple',
#  'Street',
#  'in',
#  'Marlborough',
#  'and',
#  'told',
#  'the',
#  'tellers',
#  ',',
#  '“',
#  'Give',
#  'me',
#  'all',
#  'your',
#  'money',
#  'so',
#  'no',
#  'one',
#  'gets',
#  'hurt',
#  '.',
#  '31',
#  'ABOVE',
#  'PHOTO',
#  ':',
#  'A',
#  'boy',
#  'stands',
#  'in',
#  'front',
#  'of',
#  'two',
#  'paintings',
#  'of',
#  'Chadwick',
#  'Boseman',
#  'during',
#  'the',
#  'opening',
#  'of',
#  'an',
#  'art',
#  'exhibit',
#  'honoring',
#  'the',
#  'actor',
#  'in',
#  'his',
#  'hometown',
#  'of',
#  'Anderson',
#  ',',
#  'S.C.',
#  'on',
#  'Thursday',
#  ',',
#  'Oct.',
#  '22',
#  ',',
#  '2020',
#  '.',
#  '32',
#  'Absence',
#  'may',
#  'be',
#  'making',
#  'the',
#  'heart',
#  'grow',
#  'fonder',
#  '.',
#  '33',
#  'ABS',
#  'head',
#  'of',
#  'household',
#  'surveys',
#  'Michelle',
#  'Marquardt',
#  'said',
#  'the',
#  'majority',
#  'of',
#  'funds',
#  'were',
#  'either',
#  'used',
#  'to',
#  'pay',
#  'household',
#  'bills',
#  ',',
#  'put',
#  'into',
#  'savings',
#  'or',
#  'spent',
#  'on',
#  'food',
#  'consumption',
#  '.',
#  '34',
#  'A',
#  'building',
#  'along',
#  'with',
#  'three',
#  'vehicles',
#  'were',
#  'shot',
#  'at',
#  '.',
#  '35',
#  'A',
#  '‘',
#  'call-in',
#  '’',
#  'enables',
#  'councillors',
#  'to',
#  'ask',
#  'for',
#  'a',
#  'decision',
#  'the',
#  'cabinet',
#  'has',
#  'taken',
#  'to',
#  'be',
#  'looked',
#  'at',
#  'again',
#  '.',
#  '36',
#  'A',
#  'calls',
#  'Patty',
#  "'s",
#  'presence',
#  'in',
#  'the',
#  'trailer',
#  'a',
#  '``',
#  'minstrel',
#  'show',
#  '.',
#  "''",
#  '37',
#  'A',
#  'candidate',
#  'using',
#  'populist',
#  'slogans',
#  'that',
#  'plays',
#  'to',
#  'people',
#  '’',
#  's',
#  'fears',
#  '(',
#  'Jews',
#  'are',
#  'dangerous',
#  ',',
#  'for',
#  'example',
#  ')',
#  ',',
#  'people',
#  'not',
#  'convinced',
#  'that',
#  'he',
#  'can',
#  'actually',
#  'win',
#  'and',
#  'think',
#  'the',
#  'voters',
#  'can',
#  'see',
#  'through',
#  'his',
#  'lies',
#  ',',
#  'and',
#  'so',
#  'on',
#  '.',
#  '38',
#  'A',
#  'candid',
#  'insight',
#  'from',
#  'Greg',
#  'Dyke',
#  'into',
#  'his',
#  'managerial',
#  'style',
#  'while',
#  'he',
#  'was',
#  'director-general',
#  'of',
#  'the',
#  'BBC',
#  '.',
#  '39',
#  'A',
#  'car',
#  'carrying',
#  'Atambayev',
#  ',',
#  'who',
#  'participated',
#  'at',
#  'the',
#  'bloc',
#  "'s",
#  'rally',
#  ',',
#  'was',
#  'hit',
#  'with',
#  '``',
#  'live',
#  'ammunition',
#  "''",
#  'according',
#  'to',
#  'his',
#  'spokeswoman',
#  'Joldubayeva',
#  ',',
#  'who',
#  'was',
#  'also',
#  'at',
#  ...]

# %%
from sklearn.model_selection import train_test_split

train_tokens, val_tokens = train_test_split(token, test_size = 0.3, random_state = 42)

# %%
vocab_size = [len(sentence) for sentence in lines]
# print(vocab_size)
vocab_mean = int(np.mean(vocab_size))
print(vocab_mean)
# Out:
# 121

# %%
from collections import defaultdict



def build_bigram_model(tokens):
    bigram_model = defaultdict(lambda: defaultdict(int))

    for i in range(len(tokens) - 1):
        current_word, next_word = tokens[i], tokens[i + 1]
        bigram_model[current_word][next_word] += 1

    return bigram_model

def build_trigram_model(tokens):
    trigram_model = defaultdict(lambda: defaultdict(int))

    for i in range(len(tokens) - 2):
        current_words, next_word = (tokens[i], tokens[i + 1]), tokens[i + 2]
        trigram_model[current_words][next_word] += 1

    return trigram_model

# Example usage
# tokens = ["I", "love", "to", "eat", "apples", "and", "bananas"]
bigram_model = build_bigram_model(train_tokens)
trigram_model = build_trigram_model(train_tokens)

# Print the models (for demonstration purposes)
print("Bigram Model:")
for word, next_words in bigram_model.items():
    print(f"{word}: {dict(next_words)}")

print("\nTrigram Model:")
for word_pair, next_words in trigram_model.items():
    print(f"{word_pair}: {dict(next_words)}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ('1697', 'curve'): {'to': 1}
# ('curve', 'to'): {'8119': 1}
# ('to', '8119'): {'on': 1}
# ('8119', 'on'): {'even': 1}
# ('on', 'even'): {'.': 1}
# ('which', '4576'): {',': 1}
# ('4576', ','): {'television': 1}
# (',', 'television'): {'deputies': 1}
# ('television', 'deputies'): {'high': 1}
# ('deputies', 'high'): {'nearby': 1}
# ('high', 'nearby'): {'for': 1}
# ('nearby', 'for'): {'in': 1}
# ('a', 'Holdings'): {'outbreak': 1}
# ('Holdings', 'outbreak'): {'it': 1}
# ('outbreak', 'it'): {'.': 1}
# ('.', 'bomb'): {',': 1}
# ('bomb', ','): {'eat': 1}
# (',', 'eat'): {'much': 1}
# ('eat', 'much'): {'7538': 1}
# ('much', '7538'): {'stagnating': 1}
# ('7538', 'stagnating'): {'largely': 1}
# ('stagnating', 'largely'): {'excursions': 1}
# ('largely', 'excursions'): {'be': 1}
# ('excursions', 'be'): {'go': 1}
# ('this', 'what'): {'the': 1}
# ('is', 'speeds'): {'are': 1}
# ('speeds', 'are'): {'Pataki': 1}
# ('are', 'Pataki'): {'Advertising': 1}
# ('Pataki', 'Advertising'): {'foundation': 1}
# ('Advertising', 'foundation'): {'has': 1}
# ('foundation', 'has'): {'Milbrooke': 1}
# ('has', 'Milbrooke'): {'tragedy': 1}
# ('Milbrooke', 'tragedy'): {',': 1}
# ('tragedy', ','): {'’': 1}
# ('the', '2587'): {'divisive': 1}
# ('2587', 'divisive'): {'in': 1}
# ('divisive', 'in'): {',': 1}
# ('upcoming', '-'): {',': 1}
# ('front', 'actions'): {'and': 1}
# ('actions', 'and'): {'on': 1}
# ('to', '606'): {'1': 1}
# ('606', '1'): {'are': 1}
# ('1', 'are'): {'fifth': 1}
# ('are', 'fifth'): {'8987': 1}
# ('fifth', '8987'): {'Director': 1}
# ('8987', 'Director'): {'Waring': 1}
# ('Director', 'Waring'): {'the': 1}
# ('Waring', 'the'): {'a': 1}
# ('a', 'Crude'): {'joy': 1}
# ('Crude', 'joy'): {'in': 1}
# ('joy', 'in'): {'.': 1}
# ('?', 'no'): {'It': 1}
# ('no', 'It'): {'bread': 1}
# ('It', 'bread'): {'6424': 1}
# ('bread', '6424'): {'island': 1}
# ('6424', 'island'): {'Roosevelt': 1}
# ('island', 'Roosevelt'): {'take': 1}
# ('Roosevelt', 'take'): {'9513': 1}
# ('take', '9513'): {'group': 1}
# ('9513', 'group'): {'served': 1}
# ('group', 'served'): {'concert': 1}
# ('served', 'concert'): {'.': 1}
# ('concert', '.'): {'”': 1}
# ('of', 'teachers'): {'year': 1}
# ('teachers', 'year'): {'and': 1}
# ('rights', 'win-total'): {'Trump': 1}
# ('win-total', 'Trump'): {'coronavirus': 1}
# ('Trump', 'coronavirus'): {'came': 1}
# ('coronavirus', 'came'): {'of': 1}
# ('came', 'of'): {'done': 1}
# ('.', 'conducted'): {'Humboldt': 1}
# ('conducted', 'Humboldt'): {'’': 1}
# ('Humboldt', '’'): {'in': 1}
# ('can', '4187'): {'challengesthat': 1}
# ('4187', 'challengesthat'): {'SARS': 1}
# ('challengesthat', 'SARS'): {'has': 1}
# ('SARS', 'has'): {'with': 1}
# ('of', 'Livingston'): {'means': 1}
# ('Livingston', 'means'): {'image': 1}
# ('means', 'image'): {'VR': 1}
# ('image', 'VR'): {'further': 1}
# ('VR', 'further'): {',': 1}
# ('to', 'rainfall'): {'with': 1}
# ('rainfall', 'with'): {'to': 1}
# ('to', 'BBC'): {'While': 1}
# ('BBC', 'While'): {'”': 1}
# ('”', 'West'): {'your': 1}
# ('your', 'trials'): {'precinct': 1}
# ('trials', 'precinct'): {'anticipated': 1}
# ('precinct', 'anticipated'): {'and': 1}
# ('anticipated', 'and'): {'Councillors': 1}
# ('and', 'Councillors'): {'Thousand': 1}
# ('Councillors', 'Thousand'): {'He': 1}
# ('Thousand', 'He'): {'In': 1}
# ('He', 'In'): {'quickly': 1}
# ('In', 'quickly'): {'no': 1}
# ('quickly', 'no'): {'to': 1}
# ('to', 'talking'): {'by': 1}
# ('talking', 'by'): {'demand': 1}
# ('demand', 'operations'): {'teddy': 1}
# ('operations', 'teddy'): {'former': 1}
# ('teddy', 'former'): {'is': 1}
# ('former', 'is'): {'building': 1}
# ('is', 'building'): {'that': 1}
# ('that', 'Los'): {'Zane': 1}
# ('Los', 'Zane'): {'that': 1}
# ('Zane', 'that'): {'it': 1}
# ('it', 'missing'): {'January': 1}
# ('missing', 'January'): {'still': 1}
# ('January', 'still'): {'grilling': 1}
# ('still', 'grilling'): {',': 1}
# ('grilling', ','): {'for': 1}
# ('he', 'making'): {'has': 1}
# ('making', 'has'): {'sure': 1}
# ('sure', 'law'): {'position': 1}
# ('law', 'position'): {'before': 1}
# ('position', 'before'): {'an': 1}
# ('an', 'text'): {'of': 1}
# ('text', 'of'): {'to': 1}
# ('to', 'ask'): {'suspiciously': 1}
# ('ask', 'suspiciously'): {'look': 1}
# ('suspiciously', 'look'): {'-': 1}
# ('look', '-'): {',': 1}
# ('t', 'County'): {'5018': 1}
# ('County', '5018'): {'cap': 1}
# ('5018', 'cap'): {'of': 1}
# ('cap', 'of'): {'7416': 1}
# ('of', '7416'): {'to': 1}
# ('7416', 'to'): {'being': 1}
# ('being', 'bring'): {'join': 1}
# ('bring', 'join'): {'Cross': 1}
# ('join', 'Cross'): {'.': 1}
# ('Cross', '.'): {'.': 1}
# ('player', 'items'): {'you': 1}
# ('items', 'you'): {'NuraLoop': 1}
# ('you', 'NuraLoop'): {'I': 1}
# ('NuraLoop', 'I'): {'24': 1}
# ('I', '24'): {'economic': 1}
# ('24', 'economic'): {'about': 1}
# ('economic', 'about'): {'stars': 1}
# ('about', 'stars'): {'licence': 1}
# ('stars', 'licence'): {'late': 1}
# ('licence', 'late'): {'(': 1}
# ('late', '('): {'a': 1}
# ('a', 'Ntibonera'): {'eight': 1}
# ('Ntibonera', 'eight'): {',': 1}
# ('first', 'debt'): {'from': 1}
# ('debt', 'from'): {'BodyTone': 1}
# ('from', 'BodyTone'): {'will': 1}
# ('BodyTone', 'will'): {'not': 1}
# ('will', 'not'): {'but': 1, 'any': 1}
# ('but', 'collapsed'): {'in': 1}
# ('collapsed', 'in'): {'those': 1}
# ('those', '6193'): {'in': 1}
# ('6193', 'in'): {'became': 1}
# ('in', 'became'): {'struck': 1}
# ('became', 'struck'): {'into': 1}
# ('struck', 'into'): {'4863': 1}
# ('into', '4863'): {'top': 1}
# ('4863', 'top'): {'of': 1}
# ('top', 'of'): {'I': 1}
# ('been', 'Health'): {"n't": 1}
# ('Health', "n't"): {'a': 1}
# ('died', 'not'): {'’': 1}
# ('’', '6465'): {'of': 1}
# ('6465', 'of'): {'of': 1}
# ('of', 'quarter'): {'low': 1}
# ('quarter', 'low'): {'going': 1}
# ('low', 'going'): {'people': 1}
# ('going', 'people'): {'.': 1}
# ('really', 'race'): {'of': 1}
# ('race', 'of'): {'pair': 1}
# ('of', 'pair'): {'the': 1}
# ('by', 'divisiveness'): {'to': 1}
# ('divisiveness', 'to'): {'to': 1}
# ('one', '2018'): {'After': 1}
# ('2018', 'After'): {'will': 1}
# ('After', 'will'): {'Moose': 1}
# ('will', 'Moose'): {'new': 1}
# ('Moose', 'new'): {'to': 1}
# ('to', 'dry'): {'to': 1}
# ('dry', 'to'): {'.': 1}
# ('other', 'speaking'): {'but': 1}
# ('speaking', 'but'): {'are': 1}
# ('but', 'are'): {'it': 1}
# ('it', 'Kelly'): {'“': 1}
# ('Kelly', '“'): {'integrity': 1}
# ('“', 'integrity'): {'to': 1}
# ('and', 'three-ring'): {'are': 1}
# ('three-ring', 'are'): {'Sun': 1}
# ('are', 'Sun'): {'2012': 1}
# ('Sun', '2012'): {'your': 1}
# ('2012', 'your'): {'to': 1}
# ('too', 'it'): {'should': 1}
# ('.', 'Others'): {'reaching': 1}
# ('Others', 'reaching'): {',': 1}
# ('reaching', ','): {'found': 1}
# ('found', 'inning'): {'t': 1}
# ('inning', 't'): {'But': 1}
# ('t', 'But'): {'tenor': 1}
# ('But', 'tenor'): {'Colombia': 1}
# ('tenor', 'Colombia'): {'on': 1}
# ('Colombia', 'on'): {'villages': 1}
# ('on', 'villages'): {'his': 1}
# ('villages', 'his'): {'have': 1}
# ('have', 'come'): {'she': 1}
# ('come', 'she'): {'in': 1}
# ('and', '6572'): {'While': 1}
# ('6572', 'While'): {'Plumas': 1}
# ('While', 'Plumas'): {'4706': 1}
# ('Plumas', '4706'): {'Lapkus': 1}
# ('4706', 'Lapkus'): {'In': 1}
# ('Lapkus', 'In'): {'“': 1}
# ('In', '“'): {'Pharmaceutical': 1}
# ('“', 'Pharmaceutical'): {'And': 1}
# ('Pharmaceutical', 'And'): {'an': 1}
# ('And', 'an'): {'scheme': 1}
# ('an', 'scheme'): {'killed': 1}
# ('scheme', 'killed'): {'Governor': 1}
# ('killed', 'Governor'): {'.': 1}
# ('Governor', '.'): {'up': 1}
# ('up', 'yourself'): {',': 1}
# ('yourself', ','): {'for': 1}
# ('for', 'isolated'): {'director': 1}
# ('isolated', 'director'): {'beliefs': 1}
# ('director', 'beliefs'): {'watching': 1}
# ('beliefs', 'watching'): {'content': 1}
# ('watching', 'content'): {'Mohr': 1}
# ('content', 'Mohr'): {'Pender': 1}
# ('Mohr', 'Pender'): {'any': 1}
# ('Pender', 'any'): {'all': 1}
# ('any', 'all'): {'one': 1}
# ('one', 'vague'): {'such': 1}
# ('vague', 'such'): {'The': 1}
# ('at', 'films'): {'with': 1}
# ('films', 'with'): {'he': 1}
# ('he', 'circle'): {'trade': 1}
# ('circle', 'trade'): {'of': 1}
# ('of', '``'): {'once': 1, ',': 1}
# ('``', 'once'): {',': 1}
# ('of', 'steroids'): {'of': 1}
# ('steroids', 'of'): {'long-term': 1}
# ('of', 'long-term'): {'been': 1}
# ('long-term', 'been'): {'not': 1}
# ('had', '120'): {')': 1}
# ('120', ')'): {'bandana': 1}
# (')', 'bandana'): {',': 1}
# ('bandana', ','): {'much': 1}
# ('much', '“'): {'so': 1}
# ('out', 'mobile'): {'(': 1}
# ('mobile', '('): {'to': 1}
# ('to', 'murdered'): {'young': 1}
# ('murdered', 'young'): {'accessible': 1}
# ('young', 'accessible'): {'it': 1}
# ('accessible', 'it'): {'good': 1}
# ('it', 'good'): {'are': 1}
# ('their', '150'): {'As': 1}
# ('150', 'As'): {'for': 1}
# ('As', 'for'): {'is': 1}
# ('is', 'hints'): {'has': 1}
# ('hints', 'has'): {'will': 1}
# ('will', 'Americans'): {'The': 1}
# ('Americans', 'The'): {'bad': 1, 'Farm': 1}
# ('The', 'bad'): {'world': 1}
# ('bad', 'world'): {'good': 1}
# ('world', 'good'): {'of': 1}
# ('of', 'proved'): {'prayers': 1}
# ('proved', 'prayers'): {'the': 1}
# ('prayers', 'the'): {'while': 1}
# ('to', 'OCT2'): {'go': 1}
# ('OCT2', 'go'): {'surge': 1}
# ('go', 'surge'): {'Jonathan': 1}
# ('surge', 'Jonathan'): {'SpendingPulse': 1}
# ('Jonathan', 'SpendingPulse'): {'civil': 1}
# ('SpendingPulse', 'civil'): {'about': 1}
# ('civil', 'about'): {'%': 1}
# ('about', '%'): {'of': 1}
# ('him', 'implication'): {'.': 1}
# ('implication', '.'): {'registered': 1}
# ('registered', 'will'): {'one': 1}
# ('one', '’'): {'health': 1}
# ('general', 'had'): {'help': 1}
# ('had', 'help'): {'Immigration': 1}
# ('help', 'Immigration'): {'of': 1}
# ('Immigration', 'of'): {'swath': 1}
# ('of', 'swath'): {'as': 1}
# ('swath', 'as'): {'Apple': 1}
# ('as', 'Apple'): {'.': 1}
# ('Apple', '.'): {'(': 1}
# ('(', 'Now'): {'150': 1}
# ('Now', '150'): {'of': 1}
# ('150', 'of'): {'’': 1}
# ('s', 'MuniVest'): {'!': 1}
# ('MuniVest', '!'): {'copper': 1}
# ('!', 'copper'): {'I': 1}
# ('copper', 'I'): {'731': 1}
# ('I', '731'): {'happen': 1}
# ('731', 'happen'): {'9417': 1}
# ('happen', '9417'): {'days': 1}
# ('9417', 'days'): {',': 1}
# ('our', 'major'): {'Paris': 1}
# ('major', 'Paris'): {'sore': 1}
# ('Paris', 'sore'): {'it': 1}
# ('sore', 'it'): {'t': 1}
# ('t', 'Keshet'): {'Europe': 1}
# ('Keshet', 'Europe'): {'video': 1}
# ('Europe', 'video'): {'201': 1}
# ('video', '201'): {'well': 1}
# ('201', 'well'): {'In': 1}
# ('well', 'In'): {'for': 1}
# ('for', 'greatest'): {'.': 1}
# ('.', 'Justice'): {'the': 1}
# ('Justice', 'the'): {'exceeded': 1}
# ('the', 'exceeded'): {'She': 1}
# ('exceeded', 'She'): {'failure': 1}
# ('She', 'failure'): {'the': 1}
# ('failure', 'the'): {'States': 1}
# ('States', 'system'): {'”': 1}
# ('system', '”'): {'there': 1}
# ('there', 'delay'): {'Choice': 1}
# ('delay', 'Choice'): {'’': 1}
# ('Choice', '’'): {'31': 1}
# ('’', '31'): {'vast': 1}
# ('31', 'vast'): {'been': 1}
# ('vast', 'been'): {'AC/DC': 1}
# ('been', 'AC/DC'): {'”': 1}
# ('AC/DC', '”'): {'.': 1}
# ('the', 'Map'): {'also': 1}
# ('Map', 'also'): {'from': 1}
# ('from', 'Deputy'): {'.': 1}
# ('Deputy', '.'): {'on': 1}
# ('on', 'regulate'): {'action': 1}
# ('regulate', 'action'): {'streaming': 1}
# ('action', 'streaming'): {'If': 1}
# ('streaming', 'If'): {'radical': 1}
# ('If', 'radical'): {'coins': 1}
# ('radical', 'coins'): {'five': 1}
# ('coins', 'five'): {'scent': 1}
# ('five', 'scent'): {'Tyler': 1}
# ('scent', 'Tyler'): {'experience': 1}
# ('Tyler', 'experience'): {'the': 1}
# ('experience', 'the'): {'as': 1}
# ('as', 'shown'): {'the': 1}
# ('.', 'hiding'): {',': 1}
# ('hiding', ','): {'is': 1}
# ('is', '30-year'): {'attend': 1}
# ('30-year', 'attend'): {'have': 1}
# ('attend', 'have'): {'1177': 1}
# ('have', '1177'): {'popular': 1}
# ('1177', 'popular'): {'might': 1}
# ('popular', 'might'): {'I': 1}
# ('might', 'I'): {'important': 1}
# ('I', 'important'): {'.': 1}
# ('.', '7808'): {'his': 1}
# ('7808', 'his'): {'5078': 1}
# ('his', '5078'): {'business': 1}
# ('5078', 'business'): {'to': 1}
# ('to', 'Studies'): {'risen': 1}
# ('Studies', 'risen'): {'her': 1}
# ('risen', 'her'): {'3665': 1}
# ('her', '3665'): {',': 1}
# ('3665', ','): {'light': 1}
# (',', 'light'): {'.': 1}
# ('light', '.'): {'these': 1}
# ('these', 'days'): {'government': 1}
# ('days', 'government'): {'to': 1}
# ('of', 'required'): {'the': 1}
# ('next', 'bank'): {'execution': 1}
# ('bank', 'execution'): {'units': 1}
# ('execution', 'units'): {'not': 1}
# ('units', 'not'): {'of': 1}
# ('of', 'legislation'): {'the': 1}
# ('legislation', 'the'): {'1,597': 1}
# ('the', '1,597'): {'coming': 1}
# ('1,597', 'coming'): {'9584': 1}
# ('coming', '9584'): {',': 1}
# ('9584', ','): {'up': 1}
# ('up', 's'): {'the': 1}
# ('re', '12'): {'those': 1}
# ('12', 'those'): {'it': 1}
# ('’', 'alive'): {'attempt': 1}
# ('alive', 'attempt'): {'Financial': 1}
# ('attempt', 'Financial'): {'Stephen': 1}
# ('Financial', 'Stephen'): {'!': 1}
# ('Stephen', '!'): {'allegation': 1}
# ('!', 'allegation'): {'Korea': 1}
# ('allegation', 'Korea'): {'s': 1}
# ('Korea', 's'): {'suffocating': 1}
# ('s', 'suffocating'): {'mentored': 1}
# ('suffocating', 'mentored'): {'Yet': 1}
# ('mentored', 'Yet'): {',': 1}
# ('Yet', ','): {'Putin': 1}
# (',', 'Putin'): {'upset': 1}
# ('Putin', 'upset'): {'flowers': 1}
# ('upset', 'flowers'): {'lowered': 1}
# ('flowers', 'lowered'): {'he': 1}
# ('lowered', 'he'): {'said': 1}
# ('said', 'Dharavi'): {'been': 1}
# ('Dharavi', 'been'): {'’': 1}
# ('as', 're'): {'back': 1}
# ('re', 'back'): {'staging': 1}
# ('back', 'staging'): {'piney': 1}
# ('staging', 'piney'): {'.': 1}
# ('piney', '.'): {'without': 1}
# ('without', '6857'): {'6494': 1}
# ('6857', '6494'): {')': 1}
# ('6494', ')'): {'days': 1}
# (')', 'days'): {'in': 1}
# ('days', 'in'): {'.': 1}
# ('of', '3864'): {'8th': 1}
# ('3864', '8th'): {'fresh': 1}
# ('8th', 'fresh'): {'district': 1}
# ('fresh', 'district'): {'a': 1}
# ('a', 'Senate'): {'there': 1}
# ('Senate', 'there'): {'robustness': 1}
# ('there', 'robustness'): {'out': 1}
# ('robustness', 'out'): {'confirmed': 1}
# ('out', 'confirmed'): {'Hoisting': 1}
# ('confirmed', 'Hoisting'): {'is': 1}
# ('Hoisting', 'is'): {'to': 1}
# ('points', 'governments'): {'Hindu': 1}
# ('governments', 'Hindu'): {'worked': 1}
# ('Hindu', 'worked'): {'could': 1}
# ('worked', 'could'): {'and': 1}
# ('is', 'likely'): {'scowled': 1}
# ('likely', 'scowled'): {'community': 1}
# ('scowled', 'community'): {'comparing': 1}
# ('community', 'comparing'): {'the': 1}
# ('comparing', 'the'): {'a': 1}
# ('it', 'launched'): {'having': 1}
# ('launched', 'having'): {'awaiting': 1}
# ('having', 'awaiting'): {',': 1}
# ('awaiting', ','): {'ultrasound': 1}
# (',', 'ultrasound'): {'an': 1}
# ('ultrasound', 'an'): {'’': 1}
# ('’', 'background'): {'another': 1}
# ('background', 'another'): {'as': 1}
# ('another', 'as'): {'found': 1}
# ('.', 'full'): {'ensure': 1}
# ('full', 'ensure'): {'.': 1}
# ('.', 'songs'): {'of': 1}
# ('songs', 'of'): {'.': 1}
# ('.', 'End'): {'Trump': 1}
# ('End', 'Trump'): {'got': 1}
# ('Trump', 'got'): {'me': 1}
# ('got', 'me'): {'hygienic': 1}
# ('me', 'hygienic'): {'under': 1}
# ('hygienic', 'under'): {'knew': 1}
# ('under', 'knew'): {',': 1}
# ('to', 'communists'): {'there': 1}
# ('communists', 'there'): {'is': 1}
# ('there', 'is'): {'on': 1}
# ('will', 'emergency'): {'COVID-19': 1}
# ('emergency', 'COVID-19'): {'5': 1}
# ('COVID-19', '5'): {'9971': 1}
# ('5', '9971'): {'occupation': 1}
# ('9971', 'occupation'): {'dollar': 1}
# ('occupation', 'dollar'): {'year': 1}
# ('dollar', 'year'): {'March': 1}
# ('year', 'March'): {'pay': 1}
# ('March', 'pay'): {',': 1}
# (',', 'shouldn'): {'they': 1}
# ('shouldn', 'they'): {'many': 1}
# ('they', 'many'): {'opera': 1}
# ('many', 'opera'): {'individuals': 1}
# ('opera', 'individuals'): {'to': 1}
# ('it', 'pinning'): {'why': 1}
# ('pinning', 'why'): {'is': 1}
# ('why', 'is'): {'victim': 1}
# ('is', 'victim'): {'when': 1}
# ('victim', 'when'): {'regularly': 1}
# ('when', 'regularly'): {',': 1}
# ('regularly', ','): {'they': 1}
# ('out', 'be'): {'charities': 1}
# ('be', 'charities'): {'first': 1}
# ('charities', 'first'): {'.': 1}
# ('.', 'whose'): {'When': 1}
# ('whose', 'When'): {'and': 1}
# ('When', 'and'): {'was': 1}
# ('was', 'leasing'): {'there': 1}
# ('leasing', 'there'): {'to': 1}
# ('of', 'short-range'): {'Thursday': 1}
# ('short-range', 'Thursday'): {'industry': 1}
# ('Thursday', 'industry'): {'its': 1}
# ('industry', 'its'): {'land': 1}
# ('its', 'land'): {'.': 1}
# ('land', '.'): {'on': 1}
# ('the', 'highlighted'): {'mural': 1}
# ('highlighted', 'mural'): {'transfer': 1}
# ('mural', 'transfer'): {'AUPE': 1}
# ('transfer', 'AUPE'): {'worth': 1}
# ('AUPE', 'worth'): {'.': 1}
# ('worth', '.'): {'and': 1}
# ('and', 'Just'): {'would': 1}
# ('Just', 'would'): {',': 1}
# ('one', 'weekends'): {'Gap': 1}
# ('weekends', 'Gap'): {'get': 1}
# ('Gap', 'get'): {'We': 1}
# ('get', 'We'): {'scenes': 1}
# ('We', 'scenes'): {'by': 1}
# ('scenes', 'by'): {'?': 1}
# ('by', '?'): {'issue': 1}
# ('?', 'issue'): {'4336': 1}
# ('issue', '4336'): {'the': 1}
# ('4336', 'the'): {'video': 1}
# ('video', 'during'): {'last': 1}
# ('during', 'last'): {'unique': 1}
# ('last', 'unique'): {'Vatanen': 1}
# ('unique', 'Vatanen'): {',': 1}
# ('Vatanen', ','): {'the': 1}
# ('Friday', 'are'): {',': 1}
# ('for', 'plans'): {'of': 1}
# ('plans', 'of'): {'906': 1}
# ('of', '906'): {'to': 1}
# ('906', 'to'): {'and': 1}
# ('and', 'infamous'): {'are': 1}
# ('infamous', 'are'): {')': 1}
# ('body', '('): {'at': 1}
# ('(', 'at'): {'of': 1}
# ('of', 'Falcons'): {'by': 1}
# ('Falcons', 'by'): {'this': 1}
# (',', 'signs'): {'workers': 1}
# ('signs', 'workers'): {'of': 1}
# ('of', 'Nobel-prize'): {'pretty': 1}
# ('Nobel-prize', 'pretty'): {'each': 1}
# ('pretty', 'each'): {'that': 1}
# ('This', 'Kenosha'): {'1393': 1}
# ('Kenosha', '1393'): {'shoulder': 1}
# ('1393', 'shoulder'): {'reception': 1}
# ('shoulder', 'reception'): {'testing': 1}
# ('reception', 'testing'): {',': 1}
# (',', 'Patriotic'): {'an': 1}
# ('Patriotic', 'an'): {'encouraged': 1}
# ('an', 'encouraged'): {'in': 1}
# ('encouraged', 'in'): {'for': 1}
# ('for', '1281'): {'too': 1}
# ('1281', 'too'): {'8992': 1}
# ('too', '8992'): {'at': 1}
# ('8992', 'at'): {'I': 1}
# ('mother', 'wo'): {'.': 1}
# ('wo', '.'): {'to': 1}
# ('a', '6977'): {'and': 1}
# ('6977', 'and'): {'the': 1}
# ('the', 'compete'): {'Medicaid': 1}
# ('compete', 'Medicaid'): {',': 1}
# ('Medicaid', ','): {'revealed': 1}
# ('revealed', '.'): {'food': 1}
# ('food', 'petitioners'): {'the': 1}
# ('petitioners', 'the'): {'was': 1}
# ('was', 'Asexual'): {'as': 1}
# ('Asexual', 'as'): {'must': 1}
# ('as', 'must'): {'infants': 1}
# ('must', 'infants'): {'9337': 1}
# ('infants', '9337'): {'23': 1}
# ('9337', '23'): {'colored': 1}
# ('23', 'colored'): {',': 1}
# ('colored', ','): {'Australian': 1}
# (',', 'Australian'): {'I': 1}
# ('Australian', 'I'): {'Graphics': 1}
# ('I', 'Graphics'): {'“': 1}
# ('Graphics', '“'): {'increase': 1}
# ('“', 'increase'): {'the': 1}
# ('Chinese', 'never'): {'will': 1}
# ('never', 'will'): {',': 1}
# (',', 'these'): {'Many': 1}
# ('these', 'Many'): {'The': 1}
# ('Many', 'The'): {'and': 1}
# ('and', 'others'): {'1866': 1}
# ('others', '1866'): {'9867': 1}
# ('1866', '9867'): {'the': 1}
# ('9867', 'the'): {'the': 1}
# ('the', 'wasn'): {'considering': 1}
# ('wasn', 'considering'): {'year': 1}
# ('considering', 'year'): {'economic': 1}
# ('year', 'economic'): {'had': 1}
# ('economic', 'had'): {'angrily': 1}
# ('had', 'angrily'): {'be': 1}
# ('angrily', 'be'): {'of': 1}
# ('of', 'cases'): {'My': 1}
# ('cases', 'My'): {'it': 1}
# ('My', 'it'): {'not': 1}
# ('in', 'Smith'): {'Aashirvaad': 1}
# ('Smith', 'Aashirvaad'): {'the': 1}
# ('Aashirvaad', 'the'): {'I': 1}
# ('“', 'rose'): {"'Simon": 1}
# ('rose', "'Simon"): {'well': 1}
# ("'Simon", 'well'): {'will': 1}
# ('will', 'management'): {'.': 1}
# ('management', '.'): {"n't": 1}
# ("n't", 'oils'): {'3959': 1}
# ('oils', '3959'): {'she': 1}
# ('3959', 'she'): {'midsize': 1}
# ('she', 'midsize'): {'.': 1}
# ('midsize', '.'): {'.': 1}
# ('of', 'ways'): {'generations': 1}
# ('ways', 'generations'): {'do': 1}
# ('generations', 'do'): {'and': 1}
# ('having', 'will'): {'had': 1}
# ('will', 'had'): {'he': 1}
# ('he', 'critics'): {'closing': 1}
# ('critics', 'closing'): {'accompany': 1}
# ('closing', 'accompany'): {'but': 1}
# ('accompany', 'but'): {'advised': 1}
# ('but', 'advised'): {'unrealistic': 1}
# ('advised', 'unrealistic'): {'by': 1}
# ('unrealistic', 'by'): {',': 1}
# (',', 'drug'): {'an': 1}
# ('drug', 'an'): {'make': 1}
# ('make', 'survivors'): {'reiterated': 1}
# ('survivors', 'reiterated'): {'help': 1}
# ('reiterated', 'help'): {'believe': 1}
# ('help', 'believe'): {'was': 1}
# ('believe', 'was'): {'mat': 1}
# ('was', 'mat'): {'purchase': 1}
# ('mat', 'purchase'): {'and': 1}
# ('purchase', 'and'): {'how': 1}
# ('how', 'available'): {'and': 1}
# ('available', 'and'): {'have': 1}
# ('have', 'OK'): {'the': 1}
# ('OK', 'the'): {'company': 1}
# ('company', 'handed'): {':': 1}
# ('handed', ':'): {'made': 1}
# (':', 'made'): {'the': 1}
# ('told', 'left'): {'St.': 1}
# ('left', 'St.'): {'“': 1}
# ('St.', '“'): {',': 1}
# (',', 'relaxation'): {'their': 1}
# ('relaxation', 'their'): {'where': 1}
# ('where', 'activating'): {'the': 1}
# ('activating', 'the'): {'at': 1}
# ('half', 'been'): {'“': 1}
# ('“', 'many'): {'after': 1}
# ('many', 'after'): {'on': 1}
# ('after', 'on'): {'’': 1}
# ('’', 'makes'): {'and': 1}
# ('and', 'Bank'): {'zero': 1}
# ('Bank', 'zero'): {'rates': 1}
# ('zero', 'rates'): {'donated': 1}
# ('rates', 'donated'): {'the': 1}
# ('donated', 'the'): {'and': 1}
# ('and', 'fan'): {'don': 1}
# ('fan', 'don'): {'to': 1}
# ('be', 'reads'): {'handful': 1}
# ('reads', 'handful'): {'pursued': 1}
# ('handful', 'pursued'): {'long': 1}
# ('pursued', 'long'): {'it': 1}
# ('long', 'it'): {'that': 1}
# ('.', 'dominant'): {'forward': 1}
# ('dominant', 'forward'): {'Sunday': 1}
# ('forward', 'Sunday'): {'interest': 1}
# ('Sunday', 'interest'): {'7249': 1}
# ('interest', '7249'): {'.': 1}
# ('7249', '.'): {',': 1}
# ('every', '371'): {'’': 1}
# ('371', '’'): {'as': 1}
# ('as', 'Points'): {'medical': 1}
# ('Points', 'medical'): {'heartsTesting': 1}
# ('medical', 'heartsTesting'): {'pastor': 1}
# ('heartsTesting', 'pastor'): {'of': 1}
# ('pastor', 'of'): {',': 1}
# ('above', '.'): {'6958': 1}
# ('.', '6958'): {'a': 1}
# ('6958', 'a'): {'improve': 1}
# ('a', 'improve'): {'AN': 1}
# ('improve', 'AN'): {'in': 1}
# ('AN', 'in'): {'Meachum': 1}
# ('in', 'Meachum'): {')': 1}
# ('Meachum', ')'): {'Director': 1}
# (')', 'Director'): {'in': 1}
# ('Director', 'in'): {'course': 1}
# ('course', 'country'): {'Ore': 1}
# ('country', 'Ore'): {'together': 1}
# ('Ore', 'together'): {'a': 1}
# ('a', 'If'): {'just': 1}
# ('If', 'just'): {'fears': 1}
# ('just', 'fears'): {'and': 1}
# ('fears', 'and'): {'Chelsea': 1}
# ('and', 'Chelsea'): {'to': 1}
# ('Chelsea', 'to'): {'of': 1}
# ('of', 'trucks'): {'continuing': 1}
# ('trucks', 'continuing'): {'5659': 1}
# ('continuing', '5659'): {'and': 1}
# ('5659', 'and'): {'student': 1}
# ('and', 'student'): {'to': 1}
# ('student', 'to'): {'conditions': 1}
# ('to', 'conditions'): {'lower': 1, '’': 1}
# ('conditions', 'lower'): {'safely': 1}
# ('lower', 'safely'): {',': 1}
# ('safely', ','): {'’': 1}
# ('in', 'major'): {'drink': 1}
# ('major', 'drink'): {'adding': 1}
# ('drink', 'adding'): {'work': 1}
# ('adding', 'work'): {'the': 1}
# ('London', 'grainy'): {'9360': 1}
# ('grainy', '9360'): {'Senate': 1}
# ('9360', 'Senate'): {'has': 1}
# ('Senate', 'has'): {'thousand': 1}
# ('has', 'thousand'): {'From': 1}
# ('thousand', 'From'): {'MRU': 1}
# ('From', 'MRU'): {'Orange': 1}
# ('MRU', 'Orange'): {'Task': 1}
# ('Orange', 'Task'): {'should': 1}
# ('Task', 'should'): {'Line': 1}
# ('should', 'Line'): {'yesterday': 1}
# ('Line', 'yesterday'): {'the': 1}
# ('yesterday', 'the'): {'said': 1}
# ('said', 'climate'): {'launching': 1}
# ('climate', 'launching'): {'of': 1}
# ('were', 'major'): {'secret': 1}
# ('major', 'secret'): {'of': 1}
# ('secret', 'of'): {'results': 1}
# ('of', 'results'): {',': 1}
# ('longer', 'attendees'): {'four': 1}
# ('attendees', 'four'): {'taste': 1}
# ('four', 'taste'): {'to': 1}
# ('taste', 'to'): {'Kyle': 1}
# ('to', 'Kyle'): {'his': 1}
# ('Kyle', 'his'): {'no': 1}
# ('his', 'no'): {'it': 1}
# ('no', 'it'): {'in': 1}
# ('that', 'hole'): {'the': 1}
# ('hole', 'the'): {'that': 1}
# ('that', 'torrent'): {'whose': 1}
# ('torrent', 'whose'): {'achievement': 1}
# ('whose', 'achievement'): {'ahead': 1}
# ('achievement', 'ahead'): {'up': 1}
# ('ahead', 'up'): {'first': 1}
# ('up', 'first'): {'have': 1}
# ('first', 'have'): {'business': 1}
# ('have', 'business'): {'causes': 1}
# ('business', 'causes'): {',': 1}
# ('causes', ','): {'the': 1}
# ('quarter', 'educators'): {'out': 1}
# ('educators', 'out'): {'the': 1}
# ('four', 'steers'): {'was': 1}
# ('steers', 'was'): {'she': 1}
# ('’', 'Maine'): {'eligibility': 1}
# ('Maine', 'eligibility'): {'to': 1}
# ('eligibility', 'to'): {'find': 1}
# ('of', 'Arsenal'): {',': 1}
# ('were', 'business'): {'You': 1}
# ('business', 'You'): {'to': 1}
# ('of', 'skies'): {'Stand-in': 1}
# ('skies', 'Stand-in'): {'short': 1}
# ('Stand-in', 'short'): {'chapters': 1}
# ('short', 'chapters'): {'the': 1}
# ('chapters', 'the'): {'said': 1}
# ('said', 'rare'): {'musicians': 1}
# ('rare', 'musicians'): {'with': 1}
# ('musicians', 'with'): {'to': 1}
# ('who', 'Timberwolves'): {',': 1}
# ('Timberwolves', ','): {'With': 1}
# ('With', 'a'): {'believed': 1}
# ('a', 'believed'): {'said': 1}
# ('believed', 'said'): {'Raiders': 1}
# ('said', 'Raiders'): {'following': 1}
# ('Raiders', 'following'): {'to': 1}
# ('to', 'took'): {'emerald': 1}
# ('took', 'emerald'): {'to': 1}
# ('emerald', 'to'): {'the': 1}
# ('s', 'Games'): {'and': 1}
# ('Games', 'and'): {'a': 1}
# ('a', 'amphibian-like'): {'started': 1}
# ('amphibian-like', 'started'): {'Tails': 1}
# ('started', 'Tails'): {'an': 1}
# ('Tails', 'an'): {'increased': 1}
# ('an', 'increased'): {'2672': 1}
# ('increased', '2672'): {'Collin': 1}
# ('2672', 'Collin'): {'could': 1}
# ('Collin', 'could'): {'s': 1}
# ("'s", 'audience'): {'he': 1}
# ('audience', 'he'): {'Thursday': 1}
# ('he', 'Thursday'): {'counterparts': 1}
# ('Thursday', 'counterparts'): {'friends': 1}
# ('counterparts', 'friends'): {'in': 1}
# ('friends', 'in'): {'.': 1}
# ('the', '7470'): {'enough': 1}
# ('7470', 'enough'): {',': 1}
# ('of', '9509'): {'.': 1}
# ('9509', '.'): {'Carol': 1}
# ('.', 'Carol'): {'subject': 1}
# ('Carol', 'subject'): {'fleeing': 1}
# ('subject', 'fleeing'): {'that': 1}
# ('fleeing', 'that'): {'18th': 1}
# ('that', '18th'): {'charges': 1}
# ('18th', 'charges'): {'worked': 1}
# ('charges', 'worked'): {'or': 1}
# ('worked', 'or'): {'classrooms': 1}
# ('or', 'classrooms'): {',': 1}
# ('died', 'country'): {'human': 1}
# ('country', 'human'): {'10': 1}
# ('human', '10'): {'go': 1}
# ('10', 'go'): {'he': 1}
# ('go', 'he'): {'in': 1}
# ('in', 'write'): {'Rep.': 1}
# ('write', 'Rep.'): {'.': 1}
# ('shared', 'health'): {'keen': 1}
# ('health', 'keen'): {'originally': 1}
# ('keen', 'originally'): {'symptoms': 1}
# ('originally', 'symptoms'): {'!': 1}
# ('symptoms', '!'): {'and': 1}
# ('and', 'University'): {'a': 1}
# ('the', 'save'): {'at': 1}
# ('save', 'at'): {'.': 1}
# ('to', 'fart'): {'confirm': 1}
# ('fart', 'confirm'): {'looking': 1}
# ('confirm', 'looking'): {'adding': 1}
# ('looking', 'adding'): {',': 1}
# (',', 'Gretzky'): {'than': 1}
# ('Gretzky', 'than'): {'person': 1}
# ('than', 'person'): {'say': 1}
# ('person', 'say'): {'killings': 1}
# ('say', 'killings'): {'partnered': 1}
# ('killings', 'partnered'): {'sometimes': 1}
# ('partnered', 'sometimes'): {'He': 1}
# ('sometimes', 'He'): {'that': 1}
# ('that', 'rose'): {'their': 1}
# ('rose', 'their'): {'shots': 1}
# ('their', 'shots'): {'Morgan': 1}
# ('shots', 'Morgan'): {'partner': 1}
# ('Morgan', 'partner'): {'feet': 1}
# ('partner', 'feet'): {'next': 1}
# ('feet', 'next'): {'and': 1}
# ('and', 'torque'): {'of': 1}
# ('torque', 'of'): {'the': 1}
# ('didn', 'to'): {'reflective': 1}
# ('reflective', 'on'): {'track': 1}
# ('on', 'track'): {'Wednesday': 1}
# ('track', 'Wednesday'): {'death': 1}
# ('Wednesday', 'death'): {'to': 1}
# ('to', 'idleness'): {'the': 1}
# ('idleness', 'the'): {'face': 1}
# ('the', 'face'): {'resident': 1}
# ('face', 'resident'): {'abroad': 1}
# ('resident', 'abroad'): {'who': 1}
# ('abroad', 'who'): {'alongside': 1}
# ('who', 'alongside'): {'a': 1}
# ('alongside', 'a'): {'a': 1}
# ('a', 'us'): {'6945': 1}
# ('us', '6945'): {'said': 1}
# ('6945', 'said'): {'was': 1}
# ('said', 'was'): {'managed': 1}
# ('was', 'managed'): {'Red': 1}
# ('managed', 'Red'): {'also': 1}
# ('Red', 'also'): {'7142': 1}
# ('also', '7142'): {'Russell': 1}
# ('7142', 'Russell'): {'up': 1}
# ('Russell', 'up'): {',': 1}
# (',', '50s'): {'waving': 1}
# ('50s', 'waving'): {'the': 1}
# ('waving', 'the'): {'holes': 1}
# ('holes', 'this'): {'downright': 1}
# ('this', 'downright'): {'And': 1}
# ('downright', 'And'): {'RA': 1}
# ('And', 'RA'): {'Interim': 1}
# ('RA', 'Interim'): {'Adam': 1}
# ('Interim', 'Adam'): {'of': 1}
# ('Adam', 'of'): {'Who': 1}
# ('of', 'Who'): {'about': 1}
# ('Who', 'about'): {'succession': 1}
# ('about', 'succession'): {',': 1}
# ('succession', ','): {'of': 1}
# ('mind', 'campaign'): {'Shohei': 1}
# ('campaign', 'Shohei'): {'property': 1}
# ('Shohei', 'property'): {'8511': 1}
# ('property', '8511'): {'still': 1}
# ('8511', 'still'): {'6563': 1}
# ('still', '6563'): {'this': 1}
# ('6563', 'this'): {'away': 1}
# ('this', 'away'): {'cases': 1}
# ('away', 'cases'): {'can': 1}
# ('cases', 'can'): {'first': 1}
# ('first', 'thank'): {'a': 1}
# ('thank', 'a'): {'safety': 1}
# ('safety', 'end'): {'barrister': 1}
# ('end', 'barrister'): {'is': 1}
# ('barrister', 'is'): {'December': 1}
# ('is', 'December'): {'.': 1}
# ('has', 'happened'): {'me': 1}
# ('happened', 'me'): {'it': 1}
# ('me', 'it'): {'the': 1}
# ('While', 'older'): {'copy': 1}
# ('older', 'copy'): {'8619': 1}
# ('copy', '8619'): {'as': 1}
# ('8619', 'as'): {'Teresa': 1}
# ('as', 'Teresa'): {',': 1}
# ('Teresa', ','): {'her': 1}
# ('her', 'Ballarat'): {'and': 1}
# ('Ballarat', 'and'): {'in': 1}
# ('in', 'role'): {'such': 1}
# ('role', 'such'): {'detailed': 1}
# ('such', 'detailed'): {'that': 1}
# ('detailed', 'that'): {'wants': 1}
# ('that', 'wants'): {'of': 1}
# ('in', '8750'): {'and': 1}
# ('8750', 'and'): {'Tran': 1}
# ('and', 'Tran'): {'for': 1}
# ('Tran', 'for'): {'a': 1}
# ('open', 'leash…'): {'face': 1}
# ('leash…', 'face'): {'of': 1}
# ('face', 'of'): {'a': 1}
# ('their', 'entirety'): {'changed': 1}
# ('entirety', 'changed'): {'NABARD': 1}
# ('changed', 'NABARD'): {'Before': 1}
# ('NABARD', 'Before'): {'or': 1}
# ('Before', 'or'): {'4622': 1}
# ('or', '4622'): {'option': 1}
# ('4622', 'option'): {'entity': 1}
# ('option', 'entity'): {'has': 1}
# ('entity', 'has'): {'sending': 1}
# ('has', 'sending'): {'The': 1}
# ('sending', 'The'): {'Airlines': 1}
# ('The', 'Airlines'): {'.': 1}
# ('Airlines', '.'): {'at': 1}
# ('at', 'criminal'): {'the': 1}
# ('doors', ')'): {'spring': 1}
# (')', 'spring'): {'Cooke': 1}
# ('spring', 'Cooke'): {'and': 1}
# ('Cooke', 'and'): {'next': 1}
# ('next', 'Levels'): {'liberate': 1}
# ('Levels', 'liberate'): {'the': 1}
# ('liberate', 'the'): {'race': 1}
# ('the', 'race'): {'4943': 1}
# ('race', '4943'): {',': 1}
# ('4943', ','): {'In': 1}
# ('In', 'Despite'): {'game': 1}
# ('Despite', 'game'): {'“': 1}
# ('game', '“'): {'’': 1}
# ('this', 'predicted'): {'approves': 1}
# ('predicted', 'approves'): {'is': 1}
# ('approves', 'is'): {'police': 1}
# ('police', 'love'): {'.': 1}
# ('.', 'players'): {'the': 1}
# ('the', 'dozen'): {'.': 1}
# ('dozen', '.'): {'more': 1}
# ('.', '2644'): {'66,000': 1}
# ('2644', '66,000'): {'813': 1}
# ('66,000', '813'): {'physical': 1}
# ('813', 'physical'): {'their': 1}
# ('physical', 'their'): {'There': 1}
# ('their', 'There'): {'the': 1}
# ('The', 'just'): {'cheese': 1}
# ('just', 'cheese'): {',': 1}
# ('cheese', ','): {'that': 1}
# ('and', 'electric'): {'we': 1}
# ('electric', 'we'): {'than': 1}
# ('we', 'than'): {'low': 1}
# ('than', 'low'): {"'Seeing": 1}
# ('low', "'Seeing"): {'picking': 1}
# ("'Seeing", 'picking'): {'Crystal': 1}
# ('picking', 'Crystal'): {'the': 1}
# ('Crystal', 'the'): {'a': 1}
# ('a', '7512'): {'move': 1}
# ('7512', 'move'): {'353': 1}
# ('move', '353'): {'.': 1}
# ('353', '.'): {':': 1}
# (':', 'Why'): {'the': 1}
# ('Why', 'the'): {'eat': 1}
# ('the', 'eat'): {'was': 1}
# ('eat', 'was'): {'buses': 1}
# ('was', 'buses'): {'Louis': 1}
# ('buses', 'Louis'): {'and': 1}
# ('Louis', 'and'): {'In': 1}
# ('the', 'silly'): {'said': 1}
# ('silly', 'said'): {',': 1}
# ('shuttered', 'back'): {'are': 1}
# ('are', '6445'): {'Mosley': 1}
# ('6445', 'Mosley'): {'WHO': 1}
# ('Mosley', 'WHO'): {'Covington': 1}
# ('WHO', 'Covington'): {'9409': 1}
# ('Covington', '9409'): {'.': 1}
# ('9409', '.'): {'they': 1}
# ('According', 'a'): {'yourself': 1}
# ('yourself', 'Pre-School'): {'Detachment': 1}
# ('Pre-School', 'Detachment'): {'scheduled': 1}
# ('Detachment', 'scheduled'): {'.': 1}
# ('scheduled', '.'): {'many—if': 1}
# ('.', 'many—if'): {'Things': 1}
# ('many—if', 'Things'): {'Air': 1}
# ('Things', 'Air'): {'fashion': 1}
# ('Air', 'fashion'): {'of': 1}
# ('fashion', 'of'): {'This': 1}
# ('This', 'world'): {',': 1}
# (',', 'extradited'): {'the': 1}
# ('extradited', 'the'): {'.': 1}
# ('.', 'chance'): {'in': 1}
# (',', '920'): {'of': 1}
# ('920', 'of'): {',': 1}
# (',', 'Salt'): {'charged': 1}
# ('Salt', 'charged'): {'Washington': 1}
# ('charged', 'Washington'): {'catch': 1}
# ('Washington', 'catch'): {'Husker': 1}
# ('catch', 'Husker'): {'to': 1}
# ('Husker', 'to'): {"'s": 1}
# ("'s", 'game'): {'mayor': 1}
# ('game', 'mayor'): {'cancer': 1}
# ('mayor', 'cancer'): {'and': 1}
# ('cancer', 'and'): {'to': 1}
# ('It', 'got'): {'and': 1}
# ('will', 'Lee'): {'a': 1}
# ('Lee', 'a'): {"'s": 1}
# ('was', 'K-12'): {'that': 1}
# ('K-12', 'that'): {'a': 1}
# ('they', 'Queen'): {'the': 1}
# ('Queen', 'the'): {'Jan.': 1}
# ('of', 'others'): {'a': 1}
# ('a', 'Becky'): {'to': 1}
# ('Becky', 'to'): {'days': 1}
# ('days', 'order'): {'the': 1}
# ('was', 'appearance'): {'an': 1}
# ('appearance', 'an'): {',': 1}
# (',', 'failure'): {'may': 1}
# ('failure', 'may'): {'633': 1}
# ('may', '633'): {'“': 1}
# ('633', '“'): {'to': 1}
# ('to', 'statue'): {'would': 1}
# ('statue', 'would'): {'meet': 1}
# ('would', 'meet'): {'Congress': 1}
# ('meet', 'Congress'): {'4995': 1}
# ('Congress', '4995'): {'of': 1}
# ('4995', 'of'): {'Parle': 1}
# ('of', 'Parle'): {'by': 1}
# ('Parle', 'by'): {'.': 1}
# ('.', 'episode'): {'the': 1}
# ('episode', 'the'): {'that': 1}
# ('that', '23rd'): {'.': 1}
# ('23rd', '.'): {'to': 1}
# ('to', 'seven-play'): {'add': 1}
# ('seven-play', 'add'): {'casualties': 1}
# ('add', 'casualties'): {'Our': 1}
# ('casualties', 'Our'): {'Last': 1}
# ('Our', 'Last'): {'failure': 1}
# ('Last', 'failure'): {'That': 1}
# ('failure', 'That'): {'are': 1}
# ('That', 'are'): {'of': 1}
# ('be', 'receive'): {'another': 1}
# ('receive', 'another'): {'norms': 1}
# ('another', 'norms'): {'3563': 1}
# ('norms', '3563'): {'reduced': 1}
# ('3563', 'reduced'): {'representative': 1}
# ('reduced', 'representative'): {'of': 1}
# ('representative', 'of'): {'were': 1}
# ('the', '4279'): {'Randewich': 1}
# ('4279', 'Randewich'): {'ravens': 1}
# ('Randewich', 'ravens'): {'the': 1}
# ('ravens', 'the'): {'Commander': 1}
# ('the', 'Commander'): {'I': 1}
# ('Commander', 'I'): {'art': 1}
# ('I', 'art'): {'refused': 1}
# ('art', 'refused'): {'We': 1}
# ('refused', 'We'): {'he': 1}
# ('he', 'anticipated'): {'7455': 1}
# ('anticipated', '7455'): {'a': 1}
# ('7455', 'a'): {'been': 1}
# ('been', 've'): {"''": 1}
# ('or', 'died'): {'public': 1}
# ('died', 'public'): {'.': 1}
# ('s', 'critical'): {'under': 1}
# ('critical', 'under'): {'president': 1}
# ('under', 'president'): {'the': 1}
# ('the', 'artists'): {'terrorists': 1}
# ('artists', 'terrorists'): {'star': 1}
# ('terrorists', 'star'): {'Nigeria': 1}
# ('star', 'Nigeria'): {'9172': 1}
# ('Nigeria', '9172'): {'closed': 1}
# ('9172', 'closed'): {'.': 1}
# ('.', 'slick'): {'on': 1}
# ('slick', 'on'): {'8116': 1}
# ('on', '8116'): {'move': 1}
# ('8116', 'move'): {'Jellicle': 1}
# ('move', 'Jellicle'): {'the': 1}
# ('Jellicle', 'the'): {'Ramaphosa': 1}
# ('Ramaphosa', 'but'): {'Is': 1}
# ('but', 'Is'): {'the': 1}
# ('Is', 'the'): {'now': 1}
# ('now', 'specialists'): {'1096': 1}
# ('specialists', '1096'): {'United': 1}
# ('1096', 'United'): {'policy': 1}
# ('United', 'policy'): {'said': 1}
# ('policy', 'said'): {'this': 1}
# ('this', '9791'): {'pattern': 1}
# ('9791', 'pattern'): {'green': 1}
# ('pattern', 'green'): {'interpreter': 1}
# ('green', 'interpreter'): {'Here': 1}
# ('interpreter', 'Here'): {'also': 1}
# ('Here', 'also'): {'vaccination': 1}
# ('also', 'vaccination'): {'that': 1}
# ('vaccination', 'that'): {'’': 1}
# ('’', '705'): {'it': 1}
# ('705', 'it'): {'give': 1}
# ('it', 'give'): {'healthcare': 1}
# ('give', 'healthcare'): {'Control': 1}
# ('healthcare', 'Control'): {'in': 1}
# ('Control', 'in'): {'from': 1}
# ('from', 'scholarship'): {'the': 1}
# ('scholarship', 'the'): {'8314': 1}
# ('the', '8314'): {'Wall': 1}
# ('8314', 'Wall'): {'the': 1}
# ('Wall', 'the'): {'being': 1}
# ('between', 'They'): {'learned': 1}
# ('They', 'learned'): {'9:42': 1}
# ('learned', '9:42'): {'moment': 1}
# ('9:42', 'moment'): {'option': 1}
# ('moment', 'option'): {'s': 1}
# ('option', 's'): {'acquiring': 1}
# ('s', 'acquiring'): {'for': 1}
# ('acquiring', 'for'): {'to': 1}
# ('offering', 'biology'): {'marks': 1}
# ('biology', 'marks'): {'62': 1}
# ('marks', '62'): {'for': 1}
# ('62', 'for'): {'the': 1}
# ('now', 'smoking'): {'donations': 1}
# ('smoking', 'donations'): {'roadside': 1}
# ('donations', 'roadside'): {'.': 1}
# ('roadside', '.'): {'principals': 1}
# ('.', 'principals'): {'by': 1}
# ('principals', 'by'): {'a': 1}
# ('a', 'Co'): {'intent': 1}
# ('Co', 'intent'): {'trend': 1}
# ('intent', 'trend'): {'a': 1}
# ('trend', 'a'): {'their': 1}
# ('.', 'app'): {'like': 1}
# ('app', 'like'): {'was': 1}
# ('was', 'play'): {'from': 1}
# ('from', ')'): {'that': 1}
# ('that', 'occasion'): {'of': 1}
# ('occasion', 'of'): {'ve': 1}
# ('on', 'alleged'): {'’': 1}
# ('alleged', '’'): {'said': 1}
# ('of', 'Ghana-Spain'): {'relieving': 1}
# ('Ghana-Spain', 'relieving'): {'to': 1}
# ('relieving', 'to'): {'the': 1}
# ('the', '4419'): {'tested': 1}
# ('4419', 'tested'): {'jumping': 1}
# ('tested', 'jumping'): {'oil': 1}
# ('jumping', 'oil'): {'after': 1}
# ('oil', 'after'): {'be': 1}
# ('the', 'few'): {'to': 1, '’': 1}
# ('to', 'trains'): {'Black': 1}
# ('trains', 'Black'): {'beginning': 1}
# ('Black', 'beginning'): {'prove': 1}
# ('beginning', 'prove'): {'to': 1}
# ('prove', 'to'): {'building': 1}
# ('to', 'building'): {',': 1}
# ('contact', 'she'): {'the': 1}
# ('“', 'director'): {'that': 1}
# ('director', 'that'): {'Simon': 1}
# ('that', 'Simon'): {'Westboro': 1}
# ('Simon', 'Westboro'): {'new': 1}
# ('Westboro', 'new'): {'to': 1}
# ('that', '7346'): {'software': 1}
# ('7346', 'software'): {'do': 1}
# ('software', 'do'): {'color': 1}
# ('do', 'color'): {'anyone': 1}
# ('color', 'anyone'): {'6933': 1}
# ('anyone', '6933'): {',': 1}
# ('6933', ','): {'were': 1}
# ('equality', 'source'): {"''": 1}
# ('source', "''"): {'35': 1}
# ("''", '35'): {'4168': 1}
# ('35', '4168'): {'where': 1}
# ('4168', 'where'): {'would': 1}
# ('where', 'would'): {',': 1, 'been': 1}
# ('of', '8439'): {'really': 1}
# ('8439', 'really'): {'cliff': 1}
# ('really', 'cliff'): {'he': 1}
# ('cliff', 'he'): {'need': 1}
# ('he', 'need'): {'option': 1}
# ('need', 'option'): {'2410': 1}
# ('option', '2410'): {'more': 1}
# ('2410', 'more'): {'NFL': 1}
# ('more', 'NFL'): {'of': 1}
# ('NFL', 'of'): {'will': 1}
# ('said', 'technology'): {'around': 1}
# ('technology', 'around'): {'devising': 1}
# ('around', 'devising'): {'.': 1}
# ('devising', '.'): {'.': 1}
# ('.', 'rather'): {'Royal': 1}
# ('rather', 'Royal'): {'in': 1}
# ('Royal', 'in'): {'and': 1}
# ('including', 'Saudis'): {',': 1}
# ('Saudis', ','): {'5138': 1}
# (',', '5138'): {'(': 1}
# ('5138', '('): {'we': 1}
# ('we', 'recover'): {',': 1}
# ('recover', ','): {',': 1}
# ('I', 'without'): {'.': 1}
# ('.', 'shake'): {'Black': 1}
# ('shake', 'Black'): {'the': 1}
# ('Black', 'the'): {'led': 1}
# ('led', 'period'): {'Machar': 1}
# ('period', 'Machar'): {'Eubanks': 1}
# ('Machar', 'Eubanks'): {'might': 1}
# ('Eubanks', 'might'): {'screened': 1}
# ('might', 'screened'): {'Jerry': 1}
# ('screened', 'Jerry'): {'What': 1}
# ('Jerry', 'What'): {'about': 1}
# ('What', 'about'): {'Ahmad': 1}
# ('about', 'Ahmad'): {'big': 1}
# ('Ahmad', 'big'): {'the': 1}
# ('“', 'already'): {'of': 1}
# ('Nov.', 'part'): {'she': 1}
# ('part', 'she'): {'to': 1}
# (',', '6530'): {'(': 1}
# ('6530', '('): {'the': 1}
# ('game', 'offers'): {'3217': 1}
# ('offers', '3217'): {'some': 1}
# ('3217', 'some'): {'it': 1}
# ('he', 'extra'): {'Kay': 1}
# ('extra', 'Kay'): {'safe': 1}
# ('Kay', 'safe'): {'what': 1}
# ('safe', 'what'): {'Moctar': 1}
# ('what', 'Moctar'): {'of': 1}
# ('Moctar', 'of'): {'saves': 1}
# ('of', 'saves'): {'into': 1}
# ('saves', 'into'): {'report': 1}
# ('into', 'report'): {'love': 1}
# ('report', 'love'): {'it': 1}
# ('love', 'it'): {',': 1}
# ('.', 'Pennsylvania'): {'well': 1}
# ('Pennsylvania', 'well'): {'for': 1}
# ('be', '1723'): {'Senate': 1}
# ('1723', 'Senate'): {'chimney': 1}
# ('Senate', 'chimney'): {'a': 1}
# ('chimney', 'a'): {'.': 1}
# ('up', '80'): {'I': 1}
# ('80', 'I'): {'of': 1}
# ('of', 'daring'): {'didn': 1}
# ('daring', 'didn'): {'recalled': 1}
# ('didn', 'recalled'): {'by': 1}
# ('recalled', 'by'): {'jailed': 1}
# ('by', 'jailed'): {'.': 1}
# ('jailed', '.'): {'objective': 1}
# ('.', 'objective'): {'crore': 1}
# ('objective', 'crore'): {'US': 1}
# ('crore', 'US'): {'overwhelmed': 1}
# ('US', 'overwhelmed'): {'the': 1}
# ('overwhelmed', 'the'): {'from': 1}
# ('it', 'Critter'): {'history': 1}
# ('Critter', 'history'): {'and': 1}
# ('history', 'and'): {'told': 1}
# ('and', 'told'): {'winning': 1}
# ('told', 'winning'): {'glowingly': 1}
# ('winning', 'glowingly'): {'board': 1}
# ('glowingly', 'board'): {'have': 1}
# ('board', 'have'): {'The': 1}
# ('s', 'understand…'): {'in': 1}
# ('understand…', 'in'): {'chaos': 1}
# ('in', 'chaos'): {'by': 1}
# ('chaos', 'by'): {'along': 1}
# ('by', 'along'): {',': 1}
# ('to', 'story'): {'batsman': 1}
# ('story', 'batsman'): {'saw': 1}
# ('batsman', 'saw'): {'early': 1}
# ('saw', 'early'): {'8883': 1}
# ('early', '8883'): {'it': 1}
# ('8883', 'it'): {'laptop': 1}
# ('it', 'laptop'): {'1881': 1}
# ('laptop', '1881'): {'sell': 1}
# ('1881', 'sell'): {'to': 1}
# ('sell', 'to'): {'reveal': 1}
# ('reveal', 'just'): {'.': 1}
# ('issue', 'hotline'): {'it': 1}
# ('hotline', 'it'): {'very': 1}
# ('very', 'site'): {'prefer': 1}
# ('site', 'prefer'): {'even': 1}
# ('prefer', 'even'): {'rid': 1}
# ('even', 'rid'): {'man': 1}
# ('rid', 'man'): {'.': 1}
# ('.', 'amount'): {'rate': 1}
# ('amount', 'rate'): {'”': 1}
# ('rate', '”'): {'are': 1}
# ('are', 'club'): {'Eric': 1}
# ('club', 'Eric'): {'along': 1}
# ('Eric', 'along'): {'adopt': 1}
# ('along', 'adopt'): {'best': 1}
# ('adopt', 'best'): {'.': 1}
# ('support', '4340'): {'a': 1}
# ('4340', 'a'): {'legacy': 1}
# ('a', 'legacy'): {'employees': 1}
# ('legacy', 'employees'): {'mother': 1}
# ('employees', 'mother'): {'but': 1}
# ('mother', 'but'): {'that': 1}
# ('look', 'Breonna'): {'for': 1}
# ('Breonna', 'for'): {'on': 1}
# ('on', 'vaccinated'): {'president': 1}
# ('vaccinated', 'president'): {'him': 1}
# ('president', 'him'): {'Stephon': 1}
# ('him', 'Stephon'): {'the': 1}
# ('Stephon', 'the'): {'Amanda': 1}
# ('Amanda', 'becoming'): {'during': 1}
# ('becoming', 'during'): {'to': 1}
# ('state', 'looked'): {'dead': 1}
# ('looked', 'dead'): {'normal': 1}
# ('dead', 'normal'): {'and': 1}
# ('normal', 'and'): {'on': 1}
# ('on', 'freeing'): {'.': 1}
# ('freeing', '.'): {'be': 1}
# ('be', 'Falcon'): {'about': 1}
# ('Falcon', 'about'): {'6321': 1}
# ('about', '6321'): {'some': 1}
# ('6321', 'some'): {'you': 1}
# ('you', 'John'): {'indoors': 1}
# ('John', 'indoors'): {'his': 1}
# ('indoors', 'his'): {'farmers': 1}
# ('his', 'farmers'): {'.': 1}
# ('farmers', '.'): {'on': 1}
# ('on', 'emerge'): {'that': 1}
# ('emerge', 'that'): {'drafted': 1}
# ('that', 'drafted'): {'same': 1}
# ('drafted', 'same'): {'6001': 1}
# ('same', '6001'): {'5337': 1}
# ('6001', '5337'): {'his': 1}
# ('5337', 'his'): {'of': 1}
# ('for', '9165'): {'life': 1}
# ('9165', 'life'): {'into': 1}
# ('life', 'into'): {'coach': 1}
# ('into', 'coach'): {'takes': 1}
# ('coach', 'takes'): {'Nyatsanza': 1}
# ('takes', 'Nyatsanza'): {'5247': 1}
# ('Nyatsanza', '5247'): {'of': 1}
# ('5247', 'of'): {'definitely': 1}
# ('of', 'definitely'): {'m': 1}
# ('definitely', 'm'): {'Star': 1}
# ('m', 'Star'): {'.': 1}
# ('.', 'unique'): {'did': 1}
# ('unique', 'did'): {'power': 1}
# ('did', 'power'): {'we': 1}
# ('power', 'we'): {'.': 1}
# ('the', 'Many'): {'totting': 1}
# ('Many', 'totting'): {'still': 1}
# ('totting', 'still'): {'had': 1}
# ('still', 'had'): {'them': 1}
# ('had', 'them'): {'way': 1}
# ('them', 'way'): {'prepare': 1}
# ('way', 'prepare'): {'February': 1}
# ('prepare', 'February'): {'scandal': 1}
# ('February', 'scandal'): {'racism': 1}
# ('scandal', 'racism'): {'isn': 1}
# ('racism', 'isn'): {'breaking': 1}
# ('isn', 'breaking'): {'unclear': 1}
# ('breaking', 'unclear'): {'an': 1}
# ('unclear', 'an'): {'three': 1}
# ('three', 'military'): {'remote': 1}
# ('military', 'remote'): {'4-2': 1}
# ('remote', '4-2'): {'as': 1}
# ('4-2', 'as'): {'she': 1}
# ('as', 'she'): {'port': 1}
# ('she', 'port'): {'professor': 1}
# ('port', 'professor'): {'“': 1}
# ('this', 'shots'): {'of': 1}
# (',', 'ovarian'): {'One': 1}
# ('ovarian', 'One'): {'did': 1}
# ('One', 'did'): {'coronavirus': 1}
# ('did', 'coronavirus'): {'his': 1}
# ('coronavirus', 'his'): {'on': 1}
# ('can', 'took'): {'to': 1}
# ('took', 'to'): {'Clinton': 1}
# ('Clinton', 'Nasdaq'): {'making': 1}
# ('Nasdaq', 'making'): {',': 1}
# ('their', 'gang'): {'disease': 1}
# ('gang', 'disease'): {'been': 1}
# ('disease', 'been'): {'fresh': 1}
# ('been', 'fresh'): {'the': 1}
# ('fresh', 'the'): {'health': 1}
# ('health', 'event'): {'housed': 1}
# ('event', 'housed'): {'3520': 1}
# ('housed', '3520'): {'”': 1}
# ('3520', '”'): {'Wine': 1}
# ('”', 'Wine'): {'And': 1}
# ('Wine', 'And'): {'but': 1}
# ('And', 'but'): {'that': 1}
# (',', 'longtime'): {'last': 1}
# ('longtime', 'last'): {'was': 1}
# ('last', 'was'): {'that': 1}
# ('.', 'recover'): {'quickly': 1}
# ('recover', 'quickly'): {'of': 1}
# ('quickly', 'of'): {',': 1}
# ('of', 'censorship'): {'rail': 1}
# ('censorship', 'rail'): {'political': 1}
# ('rail', 'political'): {'hair-care': 1}
# ('political', 'hair-care'): {'packed': 1}
# ('hair-care', 'packed'): {'years': 1}
# ('packed', 'years'): {'Book': 1}
# ('years', 'Book'): {'Remember': 1}
# ('Book', 'Remember'): {'.': 1}
# ('Remember', '.'): {'the': 1}
# (',', 'Pluto'): {'portfolio': 1}
# ('Pluto', 'portfolio'): {'season': 1}
# ('portfolio', 'season'): {'Marley': 1}
# ('season', 'Marley'): {'and': 1}
# ('Marley', 'and'): {'.': 1}
# ('after', 'natural'): {'Ledecky': 1}
# ('natural', 'Ledecky'): {'.': 1}
# ('Ledecky', '.'): {'If': 1}
# ('for', '5623'): {'to': 1}
# ('5623', 'to'): {'and': 1}
# ('stock', 'cabinet'): {'to': 1}
# ('cabinet', 'to'): {',': 1}
# (',', 'suit'): {'investment': 1}
# ('suit', 'investment'): {'start': 1}
# ('investment', 'start'): {'joins': 1}
# ('start', 'joins'): {'from': 1}
# ('joins', 'from'): {'meteorites': 1}
# ('from', 'meteorites'): {'’': 1}
# ('meteorites', '’'): {'ambulance': 1}
# ('’', 'ambulance'): {'who': 1}
# ('ambulance', 'who'): {'”': 1}
# ('”', 'her'): {'midway': 1}
# ('her', 'midway'): {'.': 1}
# ('midway', '.'): {'welcome': 1}
# ('.', 'welcome'): {'the': 1}
# ('welcome', 'the'): {'.': 1}
# ('by', 'gift'): {'club': 1}
# ('gift', 'club'): {'really': 1}
# ('club', 'really'): {'”': 1}
# ('his', 'exploit'): {'they': 1}
# ('exploit', 'they'): {'47': 1}
# ('they', '47'): {'6357': 1}
# ('47', '6357'): {'to': 1}
# ('6357', 'to'): {'Pennsylvania': 1}
# ('to', 'Pennsylvania'): {'the': 1}
# ('that', 'manager'): {'in': 1}
# ('manager', 'in'): {'seats': 1}
# ('in', 'seats'): {'around': 1}
# ('seats', 'around'): {'’': 1}
# ('’', 'combat'): {',': 1}
# ('combat', ','): {'on': 1}
# ('on', 'advice'): {'.': 1}
# ('advice', '.'): {'campaign': 1}
# ('.', 'campaign'): {'will': 1}
# ('campaign', 'will'): {'estimate': 1}
# ('will', 'estimate'): {'car': 1}
# ('estimate', 'car'): {'the': 1}
# ('at', 'deadly'): {'Minister': 1}
# ('deadly', 'Minister'): {'fans': 1}
# ('Minister', 'fans'): {'the': 1}
# ('work', 'easy'): {'Poliquin': 1}
# ('easy', 'Poliquin'): {'Brad': 1}
# ('Poliquin', 'Brad'): {'New': 1}
# ('Brad', 'New'): {'about': 1}
# ('New', 'about'): {'plight': 1}
# ('about', 'plight'): {'receding': 1}
# ('plight', 'receding'): {'for': 1}
# ('receding', 'for'): {'housing': 1}
# ('housing', 'a'): {'7487': 1}
# ('a', '7487'): {'Keyamo': 1}
# ('7487', 'Keyamo'): {'hedge': 1}
# ('Keyamo', 'hedge'): {'s': 1}
# ('hedge', 's'): {'height': 1}
# ('s', 'height'): {'1992': 1}
# ('height', '1992'): {'divisions': 1}
# ('1992', 'divisions'): {'some': 1}
# ('divisions', 'some'): {'had': 1}
# ('some', 'had'): {'who': 1}
# ('had', 'who'): {'Gulfstream': 1, 'past': 1}
# ('who', 'Gulfstream'): {'one': 1}
# ('Gulfstream', 'one'): {'you': 1}
# ('one', 'you'): {"''": 1}
# ('you', "''"): {'finally': 1, 'operational': 1}
# ("''", 'finally'): {'off': 1}
# ('finally', 'off'): {'stand': 1}
# ('off', 'stand'): {'understanding': 1}
# ('stand', 'understanding'): {'than': 1}
# ('understanding', 'than'): {'been': 1}
# ('than', 'been'): {'from': 1}
# ('been', 'from'): {'is': 1}
# ('different', 'partially'): {'development': 1}
# ('partially', 'development'): {'5256': 1}
# ('development', '5256'): {'Game': 1}
# ('5256', 'Game'): {'contract': 1}
# ('Game', 'contract'): {'to': 1}
# ('contract', 'to'): {'public': 1}
# ('public', '7358'): {'small': 1}
# ('7358', 'small'): {'of': 1}
# ('small', 'of'): {'culture': 1}
# ('of', 'culture'): {'the': 1}
# ('culture', 'the'): {'seen': 1}
# ('seen', '4355'): {'you': 1}
# ('4355', 'you'): {'s': 1}
# ('and', 'Brain'): {'Muslims': 1}
# ('Brain', 'Muslims'): {'intelligence': 1}
# ('Muslims', 'intelligence'): {'to': 1}
# ('intelligence', 'to'): {'child': 1}
# ('child', 'be'): {'the': 1}
# ('importance', 'not'): {'take': 1}
# ('community', '“'): {'is': 1}
# ('is', 'fight'): {'Crown': 1}
# ('fight', 'Crown'): {'nor': 1}
# ('Crown', 'nor'): {'that': 1}
# ('nor', 'that'): {'of': 1}
# ('person', 'huge'): {'an': 1}
# ('huge', 'an'): {'why': 1}
# ('an', 'why'): {'sons': 1}
# ('why', 'sons'): {'defensive': 1}
# ('sons', 'defensive'): {'from': 1}
# ('defensive', 'from'): {'sustainable': 1}
# ('from', 'sustainable'): {'pointed': 1}
# ('sustainable', 'pointed'): {'were': 1}
# ('pointed', 'were'): {'once': 1}
# ('were', 'once'): {"'Then": 1}
# ...
# ('financial', 'loud'): {'is': 1}
# ('loud', 'is'): {'to': 1}
# ('country', 'who'): {'don': 1}
# ('who', 'don'): {'which': 1}
# ('don', 'which'): {'gon': 1}
# ('which', 'gon'): {"''": 1}
# ('gon', "''"): {'nuclear': 1}
# ("''", 'nuclear'): {'of': 1}
# ('nuclear', 'of'): {'Foundation': 1}
# ('of', 'Foundation'): {'days': 1}
# ('Foundation', 'days'): {'1567': 1}
# ('days', '1567'): {'to': 1}
# ('1567', 'to'): {'NUJ': 1}
# ('to', 'NUJ'): {'touchdowns': 1}
# ('NUJ', 'touchdowns'): {'on': 1}
# ('touchdowns', 'on'): {'One': 1}
# ('was', 'fifth'): {'a': 1}
# ('fifth', 'a'): {'handy': 1}
# ('a', 'handy'): {'decision': 1}
# ('handy', 'decision'): {'—': 1}
# ('decision', '—'): {'to': 1}
# ('to', 'Indiana'): {'natural': 1}
# ('Indiana', 'natural'): {'of': 1}
# ('natural', 'of'): {'459': 1}
# ('of', '459'): {'because': 1}
# ('459', 'because'): {'The': 1}
# ('the', 'risky'): {'deaths': 1}
# ('risky', 'deaths'): {'Briefing': 1}
# ('deaths', 'Briefing'): {'Diana': 1}
# ('Briefing', 'Diana'): {'a': 1}
# ('Diana', 'a'): {'engineer': 1}
# ('a', 'engineer'): {'Thats': 1}
# ('engineer', 'Thats'): {'13': 1}
# ('Thats', '13'): {'Le': 1}
# ('13', 'Le'): {'had': 1}
# ('Le', 'had'): {'choice': 1}
# ('had', 'choice'): {'able': 1}
# ('choice', 'able'): {'t': 1}
# ('able', 't'): {'received': 1}
# ('t', 'received'): {'the': 1}
# ('s', 'liquidity'): {'Series': 1}
# ('liquidity', 'Series'): {'L': 1}
# ('Series', 'L'): {'from': 1}
# ('L', 'from'): {'Sophie': 1}
# ('from', 'Sophie'): {'further': 1}
# ('Sophie', 'further'): {'”': 1}
# ('further', '”'): {'He': 1}
# ('by', 'prevention'): {'legislature': 1}
# ('prevention', 'legislature'): {'At': 1}
# ('legislature', 'At'): {'came': 1}
# ('At', 'came'): {',': 1}
# ('are', '–'): {'.': 1}
# ('our', 'didn'): {',': 1}
# (',', "travel'"): {'not': 1}
# ("travel'", 'not'): {'independently': 1}
# ('not', 'independently'): {'national': 1}
# ('independently', 'national'): {'him': 1}
# ('national', 'him'): {',': 1}
# (',', 'mid-July'): {'weekend': 1}
# ('mid-July', 'weekend'): {'afford': 1}
# ('weekend', 'afford'): {'franchises': 1}
# ('afford', 'franchises'): {'issue': 1}
# ('franchises', 'issue'): {'back': 1}
# ('issue', 'back'): {'SAARC': 1}
# ('back', 'SAARC'): {'very': 1}
# ('SAARC', 'very'): {'had': 1}
# ('very', 'had'): {'same': 1}
# ('had', 'same'): {'to': 1}
# ('same', 'to'): {'order': 1}
# ('to', 'order'): {'2790': 1}
# ('order', '2790'): {'destination': 1}
# ('2790', 'destination'): {'on': 1}
# ('destination', 'on'): {"'m": 1}
# ('on', "'m"): {'shares': 1}
# ("'m", 'shares'): {'’': 1}
# ('shares', '’'): {'to': 1}
# ('doesn', '.'): {'interested': 1}
# ('.', 'interested'): {'is': 1}
# ('interested', 'is'): {'%': 1}
# ('is', '%'): {'and': 1}
# (',', 'Aaron'): {'.': 1}
# ('Aaron', '.'): {'and': 1}
# ('with', 'although'): {'am': 1}
# ('although', 'am'): {'the': 1}
# ('am', 'the'): {'for': 1}
# ('more', 'publishes'): {'225': 1}
# ('publishes', '225'): {'Sanders': 1}
# ('225', 'Sanders'): {'But': 1}
# ('Sanders', 'But'): {'have': 1}
# ('But', 'have'): {'in': 1}
# ('in', 'volunteers'): {'was': 1}
# ('volunteers', 'was'): {'15': 1}
# ('was', '15'): {'Friday': 1}
# ('15', 'Friday'): {'tempted': 1}
# ('Friday', 'tempted'): {'castle': 1}
# ('tempted', 'castle'): {'her': 1}
# ('castle', 'her'): {'enough.': 1}
# ('her', 'enough.'): {'State': 1}
# ('enough.', 'State'): {'684': 1}
# ('State', '684'): {',': 1}
# ('684', ','): {'Eastern': 1}
# (',', 'Eastern'): {'judges': 1}
# ('Eastern', 'judges'): {'the': 1}
# ('judges', 'the'): {'Cubic': 1}
# ('the', 'Cubic'): {'sits': 1}
# ('Cubic', 'sits'): {'no': 1}
# ('sits', 'no'): {'agencies': 1}
# ('no', 'agencies'): {'to': 1}
# ('agencies', 'to'): {'colliding': 1}
# ('to', 'colliding'): {'“': 1}
# ('colliding', '“'): {'this': 1}
# (',', 'stage'): {'area': 1}
# ('stage', 'area'): {',': 1}
# ('care', 'Christmas'): {'by': 1}
# ('Christmas', 'by'): {'miles': 1}
# ('by', 'miles'): {'3953': 1}
# ('miles', '3953'): {'7738': 1}
# ('3953', '7738'): {'the': 1}
# ('7738', 'the'): {'found': 1}
# ('found', 'his'): {'Pollution': 1}
# ('his', 'Pollution'): {'life': 1}
# ('Pollution', 'life'): {'seen': 1}
# ('life', 'seen'): {'as': 1}
# ('seen', 'as'): {'share': 1}
# ('as', 'share'): {'official': 1}
# ('share', 'official'): {'The': 1}
# ('official', 'The'): {'.': 1}
# (',', 'platform'): {'year': 1}
# ('platform', 'year'): {'protestors': 1}
# ('year', 'protestors'): {'institutes': 1}
# ('protestors', 'institutes'): {'.': 1}
# ('institutes', '.'): {'said': 1}
# ('said', 'No'): {'city': 1}
# ('No', 'city'): {'3661': 1}
# ('city', '3661'): {'in': 1}
# ('3661', 'in'): {'8755': 1}
# ('in', '8755'): {'occasion': 1}
# ('8755', 'occasion'): {'show': 1}
# ('occasion', 'show'): {'so': 1}
# ('show', 'so'): {'Constitutional': 1}
# ('so', 'Constitutional'): {'on': 1}
# ('Constitutional', 'on'): {'Neligh': 1}
# ('on', 'Neligh'): {'commissioned': 1}
# ('Neligh', 'commissioned'): {'will': 1}
# ('commissioned', 'will'): {'We': 1}
# ('will', 'We'): {'officer': 1}
# ('We', 'officer'): {'latest': 1}
# ('officer', 'latest'): {'the': 1}
# ('’', 'willing'): {'the': 1}
# ('willing', 'the'): {'8820': 1}
# ('the', '8820'): {'’': 1}
# ('8820', '’'): {'Group': 1}
# ('’', 'Group'): {'comments': 1}
# ('Group', 'comments'): {'as': 1}
# ('comments', 'as'): {'7407': 1}
# ('as', '7407'): {'2017': 1}
# ('7407', '2017'): {'if': 1}
# ('2017', 'if'): {'things': 1}
# ('if', 'things'): {'an': 1}
# ('things', 'an'): {',': 1}
# ('be', 'over'): {'also': 1}
# ('over', 'also'): {',': 1}
# (',', 'NAN'): {'man': 1}
# ('NAN', 'man'): {'life': 1}
# ('man', 'life'): {'verified': 1}
# ('life', 'verified'): {'sports': 1}
# ('verified', 'sports'): {'these': 1}
# ('sports', 'these'): {'a': 1}
# ('and', 'Gold'): {',': 1}
# ('Gold', ','): {'Terrell': 1}
# (',', 'Terrell'): {'payroll': 1}
# ('Terrell', 'payroll'): {'s': 1}
# ('payroll', 's'): {'.': 1}
# (',', 'walk'): {'team': 1}
# ('walk', 'team'): {'in': 1}
# ('the', 'Huntington'): {'4014': 1}
# ('Huntington', '4014'): {'proportionate': 1}
# ('4014', 'proportionate'): {'.': 1}
# ('proportionate', '.'): {'Roe': 1}
# ('.', 'Roe'): {'to': 1}
# ('Roe', 'to'): {'it': 1}
# ('.', 'signing'): {'Lesbian': 1}
# ('signing', 'Lesbian'): {'wall': 1}
# ('Lesbian', 'wall'): {'old': 1}
# ('wall', 'old'): {'has': 1}
# ('old', 'has'): {'and': 1}
# ('best', 'several'): {'voted': 1}
# ('several', 'voted'): {'before': 1}
# ('voted', 'before'): {'of': 1}
# ('“', 'stay'): {'department': 1}
# ('stay', 'department'): {'US': 1}
# ('department', 'US'): {'of': 1}
# (',', 'easyJet'): {'.': 1}
# ('easyJet', '.'): {'chef': 1}
# ('.', 'chef'): {',': 1}
# ('chef', ','): {'Rose': 1}
# (',', 'Rose'): {'days': 1}
# ('Rose', 'days'): {'Williams': 1}
# ('days', 'Williams'): {'rooms': 1}
# ('Williams', 'rooms'): {'humanitarian': 1}
# ('rooms', 'humanitarian'): {'her': 1}
# ('humanitarian', 'her'): {'involving': 1}
# ('her', 'involving'): {'from': 1}
# ('involving', 'from'): {'late': 1}
# ('late', 'pizza'): {'the': 1}
# ('pizza', 'the'): {',': 1}
# ('His', 'per'): {'it': 1}
# ('again', 'Some'): {'a': 1}
# ('Some', 'a'): {'comfort': 1}
# ('a', 'comfort'): {'western': 1}
# ('comfort', 'western'): {'eye': 1}
# ('western', 'eye'): {'Court': 1}
# ('eye', 'Court'): {'to': 1}
# ('Court', 'to'): {'In': 1}
# ('.', '4683'): {'that': 1}
# ('4683', 'that'): {'rock': 1}
# ('that', 'rock'): {'than': 1}
# ('rock', 'than'): {'If': 1}
# ('than', 'If'): {'from': 1}
# ('from', 'Andrea'): {'a': 1}
# ('Andrea', 'a'): {'visitors': 1}
# ('a', 'visitors'): {'data': 1}
# ('visitors', 'data'): {'guarantee': 1}
# ('data', 'guarantee'): {'time': 1}
# ('guarantee', 'time'): {'Our': 1}
# ('time', 'Our'): {'Pikachu': 1}
# ('Our', 'Pikachu'): {'eventually': 1}
# ('Pikachu', 'eventually'): {'The': 1}
# ('eventually', 'The'): {'said': 1}
# ('said', 'drink'): {'that': 1}
# ('drink', 'that'): {'Dewhurst': 1}
# ('that', 'Dewhurst'): {'.': 1}
# ('Dewhurst', '.'): {'both': 1}
# ('both', 'like'): {'project': 1}
# ('like', 'project'): {'library': 1}
# ('project', 'library'): {'crossed': 1}
# ('library', 'crossed'): {'efforts': 1}
# ('crossed', 'efforts'): {'a': 1}
# ('efforts', 'a'): {'2770': 1}
# ('a', '2770'): {'The': 1}
# ('2770', 'The'): {'where': 1}
# ('where', 'interest'): {'expectations': 1}
# ('interest', 'expectations'): {',': 1}
# ('expectations', ','): {'mobile': 1}
# (',', 'mobile'): {'oxygen': 1}
# ('mobile', 'oxygen'): {'the': 1}
# ('oxygen', 'the'): {'review': 1}
# ('the', 'review'): {'not': 1}
# ('review', 'not'): {'their': 1}
# ('their', 'chair'): {'”': 1}
# ('chair', '”'): {'.': 1}
# ('EU', 'bra'): {'resurgence': 1}
# ('bra', 'resurgence'): {'She': 1}
# ('resurgence', 'She'): {'over': 1}
# ('She', 'over'): {'session': 1}
# ('over', 'session'): {'the': 1}
# ('do', 'already'): {'have': 1}
# ('already', 'have'): {'Pakistan': 1}
# ('have', 'Pakistan'): {',': 1}
# ('Pakistan', ','): {'through': 1}
# ('through', '“'): {'George': 1}
# ('George', 'D.C'): {'about': 1}
# ('D.C', 'about'): {"n't": 1}
# ("n't", 'featuring'): {'its': 1}
# ('featuring', 'its'): {"'s": 1}
# ('its', "'s"): {'Sport': 1}
# ("'s", 'Sport'): {'staff': 1}
# ('Sport', 'staff'): {'Rebuild': 1}
# ('staff', 'Rebuild'): {'through': 1}
# ('Rebuild', 'through'): {'and': 1}
# ('and', 'closed'): {"''": 1}
# ('closed', "''"): {'–': 1}
# ("''", '–'): {'in': 1}
# ('this', 'shut'): {'channel': 1}
# ('shut', 'channel'): {'qualities': 1}
# ('channel', 'qualities'): {'while': 1}
# ('qualities', 'while'): {'’': 1}
# ('(', 'very'): {'discretionary': 1}
# ('very', 'discretionary'): {'’': 1}
# ('discretionary', '’'): {'two': 1}
# ('two', 'scare'): {'Squire': 1}
# ('scare', 'Squire'): {'overall': 1}
# ('Squire', 'overall'): {'from': 1}
# ('overall', 'from'): {'have': 1}
# ('have', 'effect'): {'for': 1}
# ('effect', 'for'): {'.': 1}
# ('U.S.', 'Rose'): {'one': 1}
# ('Rose', 'one'): {'August': 1}
# ('one', 'August'): {'Cheap': 1}
# ('August', 'Cheap'): {'March-end': 1}
# ('Cheap', 'March-end'): {'the': 1}
# ('March-end', 'the'): {'The': 1}
# ('The', 'Speed'): {'certain': 1}
# ('Speed', 'certain'): {'trailer': 1}
# ('certain', 'trailer'): {'taking': 1}
# ('trailer', 'taking'): {'California': 1}
# ('taking', 'California'): {'and': 1}
# ('him', 'best'): {'the': 1}
# ('that', 'speed'): {'depends': 1}
# ('speed', 'depends'): {'Bear': 1}
# ('depends', 'Bear'): {'get': 1}
# ('Bear', 'get'): {'worked': 1}
# ('get', 'worked'): {'play': 1}
# ('worked', 'play'): {'hockey': 1}
# ('play', 'hockey'): {'upstairs': 1}
# ('hockey', 'upstairs'): {'open': 1}
# ('upstairs', 'open'): {'by': 1}
# ('open', 'by'): {',': 1}
# ('be', '7466'): {'by': 1}
# ('7466', 'by'): {'7794': 1}
# ('by', '7794'): {'and': 1}
# ('7794', 'and'): {'the': 1}
# ('the', 'Flour'): {'in': 1}
# ('Flour', 'in'): {'Fakhrizadeh': 1}
# ('in', 'Fakhrizadeh'): {'twist': 1}
# ('Fakhrizadeh', 'twist'): {'any': 1}
# ('twist', 'any'): {'assistance': 1}
# ('any', 'assistance'): {'their': 1}
# ('assistance', 'their'): {'once': 1}
# ('their', 'once'): {'Gutekunst': 1}
# ('once', 'Gutekunst'): {'factor': 1}
# ('Gutekunst', 'factor'): {'to': 1}
# ('factor', 'to'): {'will': 1}
# ('will', 'saw'): {'was': 1}
# ('by', 'There'): {'?': 1}
# ('There', '?'): {'Irving': 1}
# ('?', 'Irving'): {'a': 1}
# ('Irving', 'a'): {'treat': 1}
# ('a', 'treat'): {'of': 1}
# ('treat', 'of'): {'check': 1}
# ('of', 'check'): {'share': 1}
# ('check', 'share'): {'it': 1}
# ('share', 'it'): {'6786': 1}
# ('it', '6786'): {'being': 1}
# ('6786', 'being'): {',': 1}
# ('wrote', 'Tuesday'): {',': 1}
# ('and', 'spot'): {'or': 1}
# ('spot', 'or'): {'their': 1}
# ('their', 'when'): {'region': 1}
# ('when', 'region'): {'Last': 1}
# ('region', 'Last'): {'critical': 1}
# ('Last', 'critical'): {'facilitate': 1}
# ('critical', 'facilitate'): {'2648': 1}
# ('facilitate', '2648'): {'system': 1}
# ('2648', 'system'): {'in': 1}
# ('system', 'in'): {'hijacked': 1}
# ('in', 'hijacked'): {'with': 1}
# ('hijacked', 'with'): {'he': 1}
# ('he', 'f'): {'Trump': 1}
# ('f', 'Trump'): {'where': 1}
# ('Trump', 'where'): {'said': 1}
# ('where', 'said'): {'Orthodox': 1}
# ('said', 'Orthodox'): {'University': 1}
# ('Orthodox', 'University'): {'16': 1}
# ('University', '16'): {'help': 1}
# ('16', 'help'): {'308,261,000': 1}
# ('help', '308,261,000'): {'to': 1}
# ('308,261,000', 'to'): {'concerts': 1}
# ('to', 'concerts'): {'3662': 1}
# ('concerts', '3662'): {'of': 1}
# ('3662', 'of'): {'partisans': 1}
# ('of', 'partisans'): {'the': 1}
# ('partisans', 'the'): {'White': 1}
# ('White', '2055'): {'“': 1}
# ('2055', '“'): {'but': 1}
# ('but', 'ensure'): {'tremendous': 1}
# ('ensure', 'tremendous'): {'feel': 1}
# ('tremendous', 'feel'): {'security': 1}
# ('feel', 'security'): {'heading': 1}
# ('security', 'heading'): {'Jet': 1}
# ('heading', 'Jet'): {'while': 1}
# ('Jet', 'while'): {'s': 1}
# ('while', 's'): {'is': 1}
# ('is', 'Agostino'): {'went': 1}
# ('Agostino', 'went'): {'Africa': 1}
# ('went', 'Africa'): {'locally': 1}
# ('Africa', 'locally'): {'there': 1}
# ('locally', 'there'): {'the': 1}
# ('create', 'shift'): {'her': 1}
# ('shift', 'her'): {'as': 1}
# ('Company', 'were'): {'cleared': 1}
# ('were', 'cleared'): {'No': 1}
# ('cleared', 'No'): {'file': 1}
# ('No', 'file'): {'improving': 1}
# ('file', 'improving'): {'week': 1}
# ('improving', 'week'): {'and': 1}
# ('and', 'Insisting'): {',': 1}
# ('Insisting', ','): {'for': 1}
# ('for', 'somewhere'): {'releasing': 1}
# ('somewhere', 'releasing'): {'bearing': 1}
# ('releasing', 'bearing'): {'Kenosha': 1}
# ('bearing', 'Kenosha'): {'them': 1}
# ('Kenosha', 'them'): {'.': 1}
# ('the', 'Kepler'): {'Iran': 1}
# ('Kepler', 'Iran'): {'that': 1}
# ('Iran', 'that'): {'their': 1}
# ('India', 'party'): {'the': 1}
# ('in', 'store'): {'in': 1}
# ('most', 'powerhouse'): {'offered': 1}
# ('powerhouse', 'offered'): {'everyone': 1}
# ('offered', 'everyone'): {'A': 1}
# ('everyone', 'A'): {'regions': 1}
# ('A', 'regions'): {'of': 1}
# ('regions', 'of'): {'there': 1}
# ('there', 'Stadium'): {'“': 1}
# ('Stadium', '“'): {'Television': 1}
# ('“', 'Television'): {'steal': 1}
# ('Television', 'steal'): {'at': 1}
# ('steal', 'at'): {'was': 1}
# ('was', 'or'): {'’': 1}
# ('president', '1909'): {'children': 1}
# ('1909', 'children'): {',': 1}
# (',', 'beer'): {'t': 1}
# ('beer', 't'): {'on': 1}
# ('on', '9326'): {'the': 1}
# ('9326', 'the'): {'Netanyahu': 1}
# ('the', 'Netanyahu'): {'Compression': 1}
# ('Netanyahu', 'Compression'): {'Carra': 1}
# ('Compression', 'Carra'): {'bargained': 1}
# ('Carra', 'bargained'): {'number': 1}
# ('bargained', 'number'): {'dealing': 1}
# ('number', 'dealing'): {'9419': 1}
# ('dealing', '9419'): {'at': 1}
# ('9419', 'at'): {'there': 1}
# ('at', 'there'): {'”': 1}
# ('of', 'charitable'): {'a': 1}
# ('charitable', 'a'): {'pots': 1}
# ('a', 'pots'): {'8306': 1}
# ('pots', '8306'): {'Trump': 1}
# ('8306', 'Trump'): {'and': 1}
# ('.', 'intervention'): {'lining': 1}
# ('intervention', 'lining'): {'Lemon': 1}
# ('lining', 'Lemon'): {'try': 1}
# ('Lemon', 'try'): {'.': 1}
# ('.', 'Gov'): {'Soon': 1}
# ('Gov', 'Soon'): {'virus': 1}
# ('Soon', 'virus'): {'necessarily': 1}
# ('virus', 'necessarily'): {'2828': 1}
# ('necessarily', '2828'): {',': 1}
# ('2828', ','): {'division': 1}
# (',', 'division'): {'others': 1}
# ('division', 'others'): {'by': 1}
# ('others', 'by'): {'to': 1}
# ('to', 'guidance'): {'expansion': 1}
# ('guidance', 'expansion'): {'improve': 1}
# ('expansion', 'improve'): {'fatal': 1}
# ('improve', 'fatal'): {'11-2-2': 1}
# ('fatal', '11-2-2'): {'ability': 1}
# ('11-2-2', 'ability'): {'games': 1}
# ('ability', 'games'): {'435': 1}
# ('games', '435'): {'at': 1}
# ('435', 'at'): {'academic': 1}
# ('at', 'academic'): {'their': 1}
# ('academic', 'their'): {'.': 1}
# ('.', 'organizing'): {'and': 1}
# ('organizing', 'and'): {'’': 1}
# ('of', 'markets'): {'deserve': 1}
# ('markets', 'deserve'): {'accused': 1}
# ('deserve', 'accused'): {'GO': 1}
# ('accused', 'GO'): {'no': 1}
# ('GO', 'no'): {'now': 1}
# ('no', 'now'): {'Voter': 1}
# ('now', 'Voter'): {'COVID-19': 1}
# ('Voter', 'COVID-19'): {'attacks': 1}
# ('COVID-19', 'attacks'): {'.': 1}
# ('.', 'Sako'): {'any': 1}
# ('Sako', 'any'): {'described': 1}
# ('any', 'described'): {'get': 1}
# ('described', 'get'): {'in': 1}
# ('in', 'lifted'): {'Rolling': 1}
# ('lifted', 'Rolling'): {'Abhijeet': 1}
# ('Rolling', 'Abhijeet'): {'United': 1}
# ('Abhijeet', 'United'): {'Telles': 1}
# ('United', 'Telles'): {'carbon': 1}
# ('Telles', 'carbon'): {'we': 1}
# ('carbon', 'we'): {'all': 1}
# ('we', 'all'): {'2685': 1}
# ('all', '2685'): {'and': 1}
# ('2685', 'and'): {'average': 1}
# ('average', 'Clasic'): {'time': 1}
# ('Clasic', 'time'): {'capacity': 1}
# ('time', 'capacity'): {'a': 1}
# ('capacity', 'a'): {'Lucy': 1}
# ('a', 'Lucy'): {'month': 1}
# ('Lucy', 'month'): {'vouchers': 1}
# ('month', 'vouchers'): {'crisis': 1}
# ('vouchers', 'crisis'): {'against': 1}
# ('crisis', 'against'): {'have': 1}
# ('have', '—'): {'of': 1}
# ('of', 'references'): {'and': 1}
# ('references', 'and'): {'fail': 1}
# ('and', 'fail'): {'McKinney': 1}
# ('fail', 'McKinney'): {'has': 1}

# %%
import numpy as np

def build_bigram_model_with_smoothing(tokens, vocab_size):
    bigram_model = defaultdict(lambda: defaultdict(lambda: 1))  # Start counts at 1 for smoothing

    for i in range(len(tokens) - 1):
        current_word, next_word = tokens[i], tokens[i + 1]
        bigram_model[current_word][next_word] += 1

    # Apply Laplace smoothing
    for current_word in bigram_model.keys():
        for next_word in bigram_model[current_word].keys():
            bigram_model[current_word][next_word] += 1
        bigram_model[current_word]["<UNK>"] = 1  # Unknown words

    return bigram_model

def build_trigram_model_with_smoothing(tokens, vocab_size):
    trigram_model = defaultdict(lambda: defaultdict(lambda: 1))  # Start counts at 1 for smoothing

    for i in range(len(tokens) - 2):
        current_words, next_word = (tokens[i], tokens[i + 1]), tokens[i + 2]
        trigram_model[current_words][next_word] += 1

    # Apply Laplace smoothing
    for current_words in trigram_model.keys():
        for next_word in trigram_model[current_words].keys():
            trigram_model[current_words][next_word] += 1
        trigram_model[current_words]["<UNK>"] = 1  # Unknown words

    return trigram_model

# Example usage
# vocab_mean = np.mean(train_tokens)  # Assuming tokens is a list of all words in the dataset
bigram_model_smoothed = build_bigram_model_with_smoothing(train_tokens, vocab_mean)
trigram_model_smoothed = build_trigram_model_with_smoothing(train_tokens, vocab_mean)

# Print the smoothed models (for demonstration purposes)
print("Bigram Model with Laplace Smoothing:")
for word, next_words in bigram_model_smoothed.items():
    print(f"{word}: {dict(next_words)}")

print("\nTrigram Model with Laplace Smoothing:")
for word_pair, next_words in trigram_model_smoothed.items():
    print(f"{word_pair}: {dict(next_words)}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ('1697', 'curve'): {'to': 3, '<UNK>': 1}
# ('curve', 'to'): {'8119': 3, '<UNK>': 1}
# ('to', '8119'): {'on': 3, '<UNK>': 1}
# ('8119', 'on'): {'even': 3, '<UNK>': 1}
# ('on', 'even'): {'.': 3, '<UNK>': 1}
# ('which', '4576'): {',': 3, '<UNK>': 1}
# ('4576', ','): {'television': 3, '<UNK>': 1}
# (',', 'television'): {'deputies': 3, '<UNK>': 1}
# ('television', 'deputies'): {'high': 3, '<UNK>': 1}
# ('deputies', 'high'): {'nearby': 3, '<UNK>': 1}
# ('high', 'nearby'): {'for': 3, '<UNK>': 1}
# ('nearby', 'for'): {'in': 3, '<UNK>': 1}
# ('a', 'Holdings'): {'outbreak': 3, '<UNK>': 1}
# ('Holdings', 'outbreak'): {'it': 3, '<UNK>': 1}
# ('outbreak', 'it'): {'.': 3, '<UNK>': 1}
# ('.', 'bomb'): {',': 3, '<UNK>': 1}
# ('bomb', ','): {'eat': 3, '<UNK>': 1}
# (',', 'eat'): {'much': 3, '<UNK>': 1}
# ('eat', 'much'): {'7538': 3, '<UNK>': 1}
# ('much', '7538'): {'stagnating': 3, '<UNK>': 1}
# ('7538', 'stagnating'): {'largely': 3, '<UNK>': 1}
# ('stagnating', 'largely'): {'excursions': 3, '<UNK>': 1}
# ('largely', 'excursions'): {'be': 3, '<UNK>': 1}
# ('excursions', 'be'): {'go': 3, '<UNK>': 1}
# ('this', 'what'): {'the': 3, '<UNK>': 1}
# ('is', 'speeds'): {'are': 3, '<UNK>': 1}
# ('speeds', 'are'): {'Pataki': 3, '<UNK>': 1}
# ('are', 'Pataki'): {'Advertising': 3, '<UNK>': 1}
# ('Pataki', 'Advertising'): {'foundation': 3, '<UNK>': 1}
# ('Advertising', 'foundation'): {'has': 3, '<UNK>': 1}
# ('foundation', 'has'): {'Milbrooke': 3, '<UNK>': 1}
# ('has', 'Milbrooke'): {'tragedy': 3, '<UNK>': 1}
# ('Milbrooke', 'tragedy'): {',': 3, '<UNK>': 1}
# ('tragedy', ','): {'’': 3, '<UNK>': 1}
# ('the', '2587'): {'divisive': 3, '<UNK>': 1}
# ('2587', 'divisive'): {'in': 3, '<UNK>': 1}
# ('divisive', 'in'): {',': 3, '<UNK>': 1}
# ('upcoming', '-'): {',': 3, '<UNK>': 1}
# ('front', 'actions'): {'and': 3, '<UNK>': 1}
# ('actions', 'and'): {'on': 3, '<UNK>': 1}
# ('to', '606'): {'1': 3, '<UNK>': 1}
# ('606', '1'): {'are': 3, '<UNK>': 1}
# ('1', 'are'): {'fifth': 3, '<UNK>': 1}
# ('are', 'fifth'): {'8987': 3, '<UNK>': 1}
# ('fifth', '8987'): {'Director': 3, '<UNK>': 1}
# ('8987', 'Director'): {'Waring': 3, '<UNK>': 1}
# ('Director', 'Waring'): {'the': 3, '<UNK>': 1}
# ('Waring', 'the'): {'a': 3, '<UNK>': 1}
# ('a', 'Crude'): {'joy': 3, '<UNK>': 1}
# ('Crude', 'joy'): {'in': 3, '<UNK>': 1}
# ('joy', 'in'): {'.': 3, '<UNK>': 1}
# ('?', 'no'): {'It': 3, '<UNK>': 1}
# ('no', 'It'): {'bread': 3, '<UNK>': 1}
# ('It', 'bread'): {'6424': 3, '<UNK>': 1}
# ('bread', '6424'): {'island': 3, '<UNK>': 1}
# ('6424', 'island'): {'Roosevelt': 3, '<UNK>': 1}
# ('island', 'Roosevelt'): {'take': 3, '<UNK>': 1}
# ('Roosevelt', 'take'): {'9513': 3, '<UNK>': 1}
# ('take', '9513'): {'group': 3, '<UNK>': 1}
# ('9513', 'group'): {'served': 3, '<UNK>': 1}
# ('group', 'served'): {'concert': 3, '<UNK>': 1}
# ('served', 'concert'): {'.': 3, '<UNK>': 1}
# ('concert', '.'): {'”': 3, '<UNK>': 1}
# ('of', 'teachers'): {'year': 3, '<UNK>': 1}
# ('teachers', 'year'): {'and': 3, '<UNK>': 1}
# ('rights', 'win-total'): {'Trump': 3, '<UNK>': 1}
# ('win-total', 'Trump'): {'coronavirus': 3, '<UNK>': 1}
# ('Trump', 'coronavirus'): {'came': 3, '<UNK>': 1}
# ('coronavirus', 'came'): {'of': 3, '<UNK>': 1}
# ('came', 'of'): {'done': 3, '<UNK>': 1}
# ('.', 'conducted'): {'Humboldt': 3, '<UNK>': 1}
# ('conducted', 'Humboldt'): {'’': 3, '<UNK>': 1}
# ('Humboldt', '’'): {'in': 3, '<UNK>': 1}
# ('can', '4187'): {'challengesthat': 3, '<UNK>': 1}
# ('4187', 'challengesthat'): {'SARS': 3, '<UNK>': 1}
# ('challengesthat', 'SARS'): {'has': 3, '<UNK>': 1}
# ('SARS', 'has'): {'with': 3, '<UNK>': 1}
# ('of', 'Livingston'): {'means': 3, '<UNK>': 1}
# ('Livingston', 'means'): {'image': 3, '<UNK>': 1}
# ('means', 'image'): {'VR': 3, '<UNK>': 1}
# ('image', 'VR'): {'further': 3, '<UNK>': 1}
# ('VR', 'further'): {',': 3, '<UNK>': 1}
# ('to', 'rainfall'): {'with': 3, '<UNK>': 1}
# ('rainfall', 'with'): {'to': 3, '<UNK>': 1}
# ('to', 'BBC'): {'While': 3, '<UNK>': 1}
# ('BBC', 'While'): {'”': 3, '<UNK>': 1}
# ('”', 'West'): {'your': 3, '<UNK>': 1}
# ('your', 'trials'): {'precinct': 3, '<UNK>': 1}
# ('trials', 'precinct'): {'anticipated': 3, '<UNK>': 1}
# ('precinct', 'anticipated'): {'and': 3, '<UNK>': 1}
# ('anticipated', 'and'): {'Councillors': 3, '<UNK>': 1}
# ('and', 'Councillors'): {'Thousand': 3, '<UNK>': 1}
# ('Councillors', 'Thousand'): {'He': 3, '<UNK>': 1}
# ('Thousand', 'He'): {'In': 3, '<UNK>': 1}
# ('He', 'In'): {'quickly': 3, '<UNK>': 1}
# ('In', 'quickly'): {'no': 3, '<UNK>': 1}
# ('quickly', 'no'): {'to': 3, '<UNK>': 1}
# ('to', 'talking'): {'by': 3, '<UNK>': 1}
# ('talking', 'by'): {'demand': 3, '<UNK>': 1}
# ('demand', 'operations'): {'teddy': 3, '<UNK>': 1}
# ('operations', 'teddy'): {'former': 3, '<UNK>': 1}
# ('teddy', 'former'): {'is': 3, '<UNK>': 1}
# ('former', 'is'): {'building': 3, '<UNK>': 1}
# ('is', 'building'): {'that': 3, '<UNK>': 1}
# ('that', 'Los'): {'Zane': 3, '<UNK>': 1}
# ('Los', 'Zane'): {'that': 3, '<UNK>': 1}
# ('Zane', 'that'): {'it': 3, '<UNK>': 1}
# ('it', 'missing'): {'January': 3, '<UNK>': 1}
# ('missing', 'January'): {'still': 3, '<UNK>': 1}
# ('January', 'still'): {'grilling': 3, '<UNK>': 1}
# ('still', 'grilling'): {',': 3, '<UNK>': 1}
# ('grilling', ','): {'for': 3, '<UNK>': 1}
# ('he', 'making'): {'has': 3, '<UNK>': 1}
# ('making', 'has'): {'sure': 3, '<UNK>': 1}
# ('sure', 'law'): {'position': 3, '<UNK>': 1}
# ('law', 'position'): {'before': 3, '<UNK>': 1}
# ('position', 'before'): {'an': 3, '<UNK>': 1}
# ('an', 'text'): {'of': 3, '<UNK>': 1}
# ('text', 'of'): {'to': 3, '<UNK>': 1}
# ('to', 'ask'): {'suspiciously': 3, '<UNK>': 1}
# ('ask', 'suspiciously'): {'look': 3, '<UNK>': 1}
# ('suspiciously', 'look'): {'-': 3, '<UNK>': 1}
# ('look', '-'): {',': 3, '<UNK>': 1}
# ('t', 'County'): {'5018': 3, '<UNK>': 1}
# ('County', '5018'): {'cap': 3, '<UNK>': 1}
# ('5018', 'cap'): {'of': 3, '<UNK>': 1}
# ('cap', 'of'): {'7416': 3, '<UNK>': 1}
# ('of', '7416'): {'to': 3, '<UNK>': 1}
# ('7416', 'to'): {'being': 3, '<UNK>': 1}
# ('being', 'bring'): {'join': 3, '<UNK>': 1}
# ('bring', 'join'): {'Cross': 3, '<UNK>': 1}
# ('join', 'Cross'): {'.': 3, '<UNK>': 1}
# ('Cross', '.'): {'.': 3, '<UNK>': 1}
# ('player', 'items'): {'you': 3, '<UNK>': 1}
# ('items', 'you'): {'NuraLoop': 3, '<UNK>': 1}
# ('you', 'NuraLoop'): {'I': 3, '<UNK>': 1}
# ('NuraLoop', 'I'): {'24': 3, '<UNK>': 1}
# ('I', '24'): {'economic': 3, '<UNK>': 1}
# ('24', 'economic'): {'about': 3, '<UNK>': 1}
# ('economic', 'about'): {'stars': 3, '<UNK>': 1}
# ('about', 'stars'): {'licence': 3, '<UNK>': 1}
# ('stars', 'licence'): {'late': 3, '<UNK>': 1}
# ('licence', 'late'): {'(': 3, '<UNK>': 1}
# ('late', '('): {'a': 3, '<UNK>': 1}
# ('a', 'Ntibonera'): {'eight': 3, '<UNK>': 1}
# ('Ntibonera', 'eight'): {',': 3, '<UNK>': 1}
# ('first', 'debt'): {'from': 3, '<UNK>': 1}
# ('debt', 'from'): {'BodyTone': 3, '<UNK>': 1}
# ('from', 'BodyTone'): {'will': 3, '<UNK>': 1}
# ('BodyTone', 'will'): {'not': 3, '<UNK>': 1}
# ('will', 'not'): {'but': 3, 'any': 3, '<UNK>': 1}
# ('but', 'collapsed'): {'in': 3, '<UNK>': 1}
# ('collapsed', 'in'): {'those': 3, '<UNK>': 1}
# ('those', '6193'): {'in': 3, '<UNK>': 1}
# ('6193', 'in'): {'became': 3, '<UNK>': 1}
# ('in', 'became'): {'struck': 3, '<UNK>': 1}
# ('became', 'struck'): {'into': 3, '<UNK>': 1}
# ('struck', 'into'): {'4863': 3, '<UNK>': 1}
# ('into', '4863'): {'top': 3, '<UNK>': 1}
# ('4863', 'top'): {'of': 3, '<UNK>': 1}
# ('top', 'of'): {'I': 3, '<UNK>': 1}
# ('been', 'Health'): {"n't": 3, '<UNK>': 1}
# ('Health', "n't"): {'a': 3, '<UNK>': 1}
# ('died', 'not'): {'’': 3, '<UNK>': 1}
# ('’', '6465'): {'of': 3, '<UNK>': 1}
# ('6465', 'of'): {'of': 3, '<UNK>': 1}
# ('of', 'quarter'): {'low': 3, '<UNK>': 1}
# ('quarter', 'low'): {'going': 3, '<UNK>': 1}
# ('low', 'going'): {'people': 3, '<UNK>': 1}
# ('going', 'people'): {'.': 3, '<UNK>': 1}
# ('really', 'race'): {'of': 3, '<UNK>': 1}
# ('race', 'of'): {'pair': 3, '<UNK>': 1}
# ('of', 'pair'): {'the': 3, '<UNK>': 1}
# ('by', 'divisiveness'): {'to': 3, '<UNK>': 1}
# ('divisiveness', 'to'): {'to': 3, '<UNK>': 1}
# ('one', '2018'): {'After': 3, '<UNK>': 1}
# ('2018', 'After'): {'will': 3, '<UNK>': 1}
# ('After', 'will'): {'Moose': 3, '<UNK>': 1}
# ('will', 'Moose'): {'new': 3, '<UNK>': 1}
# ('Moose', 'new'): {'to': 3, '<UNK>': 1}
# ('to', 'dry'): {'to': 3, '<UNK>': 1}
# ('dry', 'to'): {'.': 3, '<UNK>': 1}
# ('other', 'speaking'): {'but': 3, '<UNK>': 1}
# ('speaking', 'but'): {'are': 3, '<UNK>': 1}
# ('but', 'are'): {'it': 3, '<UNK>': 1}
# ('it', 'Kelly'): {'“': 3, '<UNK>': 1}
# ('Kelly', '“'): {'integrity': 3, '<UNK>': 1}
# ('“', 'integrity'): {'to': 3, '<UNK>': 1}
# ('and', 'three-ring'): {'are': 3, '<UNK>': 1}
# ('three-ring', 'are'): {'Sun': 3, '<UNK>': 1}
# ('are', 'Sun'): {'2012': 3, '<UNK>': 1}
# ('Sun', '2012'): {'your': 3, '<UNK>': 1}
# ('2012', 'your'): {'to': 3, '<UNK>': 1}
# ('too', 'it'): {'should': 3, '<UNK>': 1}
# ('.', 'Others'): {'reaching': 3, '<UNK>': 1}
# ('Others', 'reaching'): {',': 3, '<UNK>': 1}
# ('reaching', ','): {'found': 3, '<UNK>': 1}
# ('found', 'inning'): {'t': 3, '<UNK>': 1}
# ('inning', 't'): {'But': 3, '<UNK>': 1}
# ('t', 'But'): {'tenor': 3, '<UNK>': 1}
# ('But', 'tenor'): {'Colombia': 3, '<UNK>': 1}
# ('tenor', 'Colombia'): {'on': 3, '<UNK>': 1}
# ('Colombia', 'on'): {'villages': 3, '<UNK>': 1}
# ('on', 'villages'): {'his': 3, '<UNK>': 1}
# ('villages', 'his'): {'have': 3, '<UNK>': 1}
# ('have', 'come'): {'she': 3, '<UNK>': 1}
# ('come', 'she'): {'in': 3, '<UNK>': 1}
# ('and', '6572'): {'While': 3, '<UNK>': 1}
# ('6572', 'While'): {'Plumas': 3, '<UNK>': 1}
# ('While', 'Plumas'): {'4706': 3, '<UNK>': 1}
# ('Plumas', '4706'): {'Lapkus': 3, '<UNK>': 1}
# ('4706', 'Lapkus'): {'In': 3, '<UNK>': 1}
# ('Lapkus', 'In'): {'“': 3, '<UNK>': 1}
# ('In', '“'): {'Pharmaceutical': 3, '<UNK>': 1}
# ('“', 'Pharmaceutical'): {'And': 3, '<UNK>': 1}
# ('Pharmaceutical', 'And'): {'an': 3, '<UNK>': 1}
# ('And', 'an'): {'scheme': 3, '<UNK>': 1}
# ('an', 'scheme'): {'killed': 3, '<UNK>': 1}
# ('scheme', 'killed'): {'Governor': 3, '<UNK>': 1}
# ('killed', 'Governor'): {'.': 3, '<UNK>': 1}
# ('Governor', '.'): {'up': 3, '<UNK>': 1}
# ('up', 'yourself'): {',': 3, '<UNK>': 1}
# ('yourself', ','): {'for': 3, '<UNK>': 1}
# ('for', 'isolated'): {'director': 3, '<UNK>': 1}
# ('isolated', 'director'): {'beliefs': 3, '<UNK>': 1}
# ('director', 'beliefs'): {'watching': 3, '<UNK>': 1}
# ('beliefs', 'watching'): {'content': 3, '<UNK>': 1}
# ('watching', 'content'): {'Mohr': 3, '<UNK>': 1}
# ('content', 'Mohr'): {'Pender': 3, '<UNK>': 1}
# ('Mohr', 'Pender'): {'any': 3, '<UNK>': 1}
# ('Pender', 'any'): {'all': 3, '<UNK>': 1}
# ('any', 'all'): {'one': 3, '<UNK>': 1}
# ('one', 'vague'): {'such': 3, '<UNK>': 1}
# ('vague', 'such'): {'The': 3, '<UNK>': 1}
# ('at', 'films'): {'with': 3, '<UNK>': 1}
# ('films', 'with'): {'he': 3, '<UNK>': 1}
# ('he', 'circle'): {'trade': 3, '<UNK>': 1}
# ('circle', 'trade'): {'of': 3, '<UNK>': 1}
# ('of', '``'): {'once': 3, ',': 3, '<UNK>': 1}
# ('``', 'once'): {',': 3, '<UNK>': 1}
# ('of', 'steroids'): {'of': 3, '<UNK>': 1}
# ('steroids', 'of'): {'long-term': 3, '<UNK>': 1}
# ('of', 'long-term'): {'been': 3, '<UNK>': 1}
# ('long-term', 'been'): {'not': 3, '<UNK>': 1}
# ('had', '120'): {')': 3, '<UNK>': 1}
# ('120', ')'): {'bandana': 3, '<UNK>': 1}
# (')', 'bandana'): {',': 3, '<UNK>': 1}
# ('bandana', ','): {'much': 3, '<UNK>': 1}
# ('much', '“'): {'so': 3, '<UNK>': 1}
# ('out', 'mobile'): {'(': 3, '<UNK>': 1}
# ('mobile', '('): {'to': 3, '<UNK>': 1}
# ('to', 'murdered'): {'young': 3, '<UNK>': 1}
# ('murdered', 'young'): {'accessible': 3, '<UNK>': 1}
# ('young', 'accessible'): {'it': 3, '<UNK>': 1}
# ('accessible', 'it'): {'good': 3, '<UNK>': 1}
# ('it', 'good'): {'are': 3, '<UNK>': 1}
# ('their', '150'): {'As': 3, '<UNK>': 1}
# ('150', 'As'): {'for': 3, '<UNK>': 1}
# ('As', 'for'): {'is': 3, '<UNK>': 1}
# ('is', 'hints'): {'has': 3, '<UNK>': 1}
# ('hints', 'has'): {'will': 3, '<UNK>': 1}
# ('will', 'Americans'): {'The': 3, '<UNK>': 1}
# ('Americans', 'The'): {'bad': 3, 'Farm': 3, '<UNK>': 1}
# ('The', 'bad'): {'world': 3, '<UNK>': 1}
# ('bad', 'world'): {'good': 3, '<UNK>': 1}
# ('world', 'good'): {'of': 3, '<UNK>': 1}
# ('of', 'proved'): {'prayers': 3, '<UNK>': 1}
# ('proved', 'prayers'): {'the': 3, '<UNK>': 1}
# ('prayers', 'the'): {'while': 3, '<UNK>': 1}
# ('to', 'OCT2'): {'go': 3, '<UNK>': 1}
# ('OCT2', 'go'): {'surge': 3, '<UNK>': 1}
# ('go', 'surge'): {'Jonathan': 3, '<UNK>': 1}
# ('surge', 'Jonathan'): {'SpendingPulse': 3, '<UNK>': 1}
# ('Jonathan', 'SpendingPulse'): {'civil': 3, '<UNK>': 1}
# ('SpendingPulse', 'civil'): {'about': 3, '<UNK>': 1}
# ('civil', 'about'): {'%': 3, '<UNK>': 1}
# ('about', '%'): {'of': 3, '<UNK>': 1}
# ('him', 'implication'): {'.': 3, '<UNK>': 1}
# ('implication', '.'): {'registered': 3, '<UNK>': 1}
# ('registered', 'will'): {'one': 3, '<UNK>': 1}
# ('one', '’'): {'health': 3, '<UNK>': 1}
# ('general', 'had'): {'help': 3, '<UNK>': 1}
# ('had', 'help'): {'Immigration': 3, '<UNK>': 1}
# ('help', 'Immigration'): {'of': 3, '<UNK>': 1}
# ('Immigration', 'of'): {'swath': 3, '<UNK>': 1}
# ('of', 'swath'): {'as': 3, '<UNK>': 1}
# ('swath', 'as'): {'Apple': 3, '<UNK>': 1}
# ('as', 'Apple'): {'.': 3, '<UNK>': 1}
# ('Apple', '.'): {'(': 3, '<UNK>': 1}
# ('(', 'Now'): {'150': 3, '<UNK>': 1}
# ('Now', '150'): {'of': 3, '<UNK>': 1}
# ('150', 'of'): {'’': 3, '<UNK>': 1}
# ('s', 'MuniVest'): {'!': 3, '<UNK>': 1}
# ('MuniVest', '!'): {'copper': 3, '<UNK>': 1}
# ('!', 'copper'): {'I': 3, '<UNK>': 1}
# ('copper', 'I'): {'731': 3, '<UNK>': 1}
# ('I', '731'): {'happen': 3, '<UNK>': 1}
# ('731', 'happen'): {'9417': 3, '<UNK>': 1}
# ('happen', '9417'): {'days': 3, '<UNK>': 1}
# ('9417', 'days'): {',': 3, '<UNK>': 1}
# ('our', 'major'): {'Paris': 3, '<UNK>': 1}
# ('major', 'Paris'): {'sore': 3, '<UNK>': 1}
# ('Paris', 'sore'): {'it': 3, '<UNK>': 1}
# ('sore', 'it'): {'t': 3, '<UNK>': 1}
# ('t', 'Keshet'): {'Europe': 3, '<UNK>': 1}
# ('Keshet', 'Europe'): {'video': 3, '<UNK>': 1}
# ('Europe', 'video'): {'201': 3, '<UNK>': 1}
# ('video', '201'): {'well': 3, '<UNK>': 1}
# ('201', 'well'): {'In': 3, '<UNK>': 1}
# ('well', 'In'): {'for': 3, '<UNK>': 1}
# ('for', 'greatest'): {'.': 3, '<UNK>': 1}
# ('.', 'Justice'): {'the': 3, '<UNK>': 1}
# ('Justice', 'the'): {'exceeded': 3, '<UNK>': 1}
# ('the', 'exceeded'): {'She': 3, '<UNK>': 1}
# ('exceeded', 'She'): {'failure': 3, '<UNK>': 1}
# ('She', 'failure'): {'the': 3, '<UNK>': 1}
# ('failure', 'the'): {'States': 3, '<UNK>': 1}
# ('States', 'system'): {'”': 3, '<UNK>': 1}
# ('system', '”'): {'there': 3, '<UNK>': 1}
# ('there', 'delay'): {'Choice': 3, '<UNK>': 1}
# ('delay', 'Choice'): {'’': 3, '<UNK>': 1}
# ('Choice', '’'): {'31': 3, '<UNK>': 1}
# ('’', '31'): {'vast': 3, '<UNK>': 1}
# ('31', 'vast'): {'been': 3, '<UNK>': 1}
# ('vast', 'been'): {'AC/DC': 3, '<UNK>': 1}
# ('been', 'AC/DC'): {'”': 3, '<UNK>': 1}
# ('AC/DC', '”'): {'.': 3, '<UNK>': 1}
# ('the', 'Map'): {'also': 3, '<UNK>': 1}
# ('Map', 'also'): {'from': 3, '<UNK>': 1}
# ('from', 'Deputy'): {'.': 3, '<UNK>': 1}
# ('Deputy', '.'): {'on': 3, '<UNK>': 1}
# ('on', 'regulate'): {'action': 3, '<UNK>': 1}
# ('regulate', 'action'): {'streaming': 3, '<UNK>': 1}
# ('action', 'streaming'): {'If': 3, '<UNK>': 1}
# ('streaming', 'If'): {'radical': 3, '<UNK>': 1}
# ('If', 'radical'): {'coins': 3, '<UNK>': 1}
# ('radical', 'coins'): {'five': 3, '<UNK>': 1}
# ('coins', 'five'): {'scent': 3, '<UNK>': 1}
# ('five', 'scent'): {'Tyler': 3, '<UNK>': 1}
# ('scent', 'Tyler'): {'experience': 3, '<UNK>': 1}
# ('Tyler', 'experience'): {'the': 3, '<UNK>': 1}
# ('experience', 'the'): {'as': 3, '<UNK>': 1}
# ('as', 'shown'): {'the': 3, '<UNK>': 1}
# ('.', 'hiding'): {',': 3, '<UNK>': 1}
# ('hiding', ','): {'is': 3, '<UNK>': 1}
# ('is', '30-year'): {'attend': 3, '<UNK>': 1}
# ('30-year', 'attend'): {'have': 3, '<UNK>': 1}
# ('attend', 'have'): {'1177': 3, '<UNK>': 1}
# ('have', '1177'): {'popular': 3, '<UNK>': 1}
# ('1177', 'popular'): {'might': 3, '<UNK>': 1}
# ('popular', 'might'): {'I': 3, '<UNK>': 1}
# ('might', 'I'): {'important': 3, '<UNK>': 1}
# ('I', 'important'): {'.': 3, '<UNK>': 1}
# ('.', '7808'): {'his': 3, '<UNK>': 1}
# ('7808', 'his'): {'5078': 3, '<UNK>': 1}
# ('his', '5078'): {'business': 3, '<UNK>': 1}
# ('5078', 'business'): {'to': 3, '<UNK>': 1}
# ('to', 'Studies'): {'risen': 3, '<UNK>': 1}
# ('Studies', 'risen'): {'her': 3, '<UNK>': 1}
# ('risen', 'her'): {'3665': 3, '<UNK>': 1}
# ('her', '3665'): {',': 3, '<UNK>': 1}
# ('3665', ','): {'light': 3, '<UNK>': 1}
# (',', 'light'): {'.': 3, '<UNK>': 1}
# ('light', '.'): {'these': 3, '<UNK>': 1}
# ('these', 'days'): {'government': 3, '<UNK>': 1}
# ('days', 'government'): {'to': 3, '<UNK>': 1}
# ('of', 'required'): {'the': 3, '<UNK>': 1}
# ('next', 'bank'): {'execution': 3, '<UNK>': 1}
# ('bank', 'execution'): {'units': 3, '<UNK>': 1}
# ('execution', 'units'): {'not': 3, '<UNK>': 1}
# ('units', 'not'): {'of': 3, '<UNK>': 1}
# ('of', 'legislation'): {'the': 3, '<UNK>': 1}
# ('legislation', 'the'): {'1,597': 3, '<UNK>': 1}
# ('the', '1,597'): {'coming': 3, '<UNK>': 1}
# ('1,597', 'coming'): {'9584': 3, '<UNK>': 1}
# ('coming', '9584'): {',': 3, '<UNK>': 1}
# ('9584', ','): {'up': 3, '<UNK>': 1}
# ('up', 's'): {'the': 3, '<UNK>': 1}
# ('re', '12'): {'those': 3, '<UNK>': 1}
# ('12', 'those'): {'it': 3, '<UNK>': 1}
# ('’', 'alive'): {'attempt': 3, '<UNK>': 1}
# ('alive', 'attempt'): {'Financial': 3, '<UNK>': 1}
# ('attempt', 'Financial'): {'Stephen': 3, '<UNK>': 1}
# ('Financial', 'Stephen'): {'!': 3, '<UNK>': 1}
# ('Stephen', '!'): {'allegation': 3, '<UNK>': 1}
# ('!', 'allegation'): {'Korea': 3, '<UNK>': 1}
# ('allegation', 'Korea'): {'s': 3, '<UNK>': 1}
# ('Korea', 's'): {'suffocating': 3, '<UNK>': 1}
# ('s', 'suffocating'): {'mentored': 3, '<UNK>': 1}
# ('suffocating', 'mentored'): {'Yet': 3, '<UNK>': 1}
# ('mentored', 'Yet'): {',': 3, '<UNK>': 1}
# ('Yet', ','): {'Putin': 3, '<UNK>': 1}
# (',', 'Putin'): {'upset': 3, '<UNK>': 1}
# ('Putin', 'upset'): {'flowers': 3, '<UNK>': 1}
# ('upset', 'flowers'): {'lowered': 3, '<UNK>': 1}
# ('flowers', 'lowered'): {'he': 3, '<UNK>': 1}
# ('lowered', 'he'): {'said': 3, '<UNK>': 1}
# ('said', 'Dharavi'): {'been': 3, '<UNK>': 1}
# ('Dharavi', 'been'): {'’': 3, '<UNK>': 1}
# ('as', 're'): {'back': 3, '<UNK>': 1}
# ('re', 'back'): {'staging': 3, '<UNK>': 1}
# ('back', 'staging'): {'piney': 3, '<UNK>': 1}
# ('staging', 'piney'): {'.': 3, '<UNK>': 1}
# ('piney', '.'): {'without': 3, '<UNK>': 1}
# ('without', '6857'): {'6494': 3, '<UNK>': 1}
# ('6857', '6494'): {')': 3, '<UNK>': 1}
# ('6494', ')'): {'days': 3, '<UNK>': 1}
# (')', 'days'): {'in': 3, '<UNK>': 1}
# ('days', 'in'): {'.': 3, '<UNK>': 1}
# ('of', '3864'): {'8th': 3, '<UNK>': 1}
# ('3864', '8th'): {'fresh': 3, '<UNK>': 1}
# ('8th', 'fresh'): {'district': 3, '<UNK>': 1}
# ('fresh', 'district'): {'a': 3, '<UNK>': 1}
# ('a', 'Senate'): {'there': 3, '<UNK>': 1}
# ('Senate', 'there'): {'robustness': 3, '<UNK>': 1}
# ('there', 'robustness'): {'out': 3, '<UNK>': 1}
# ('robustness', 'out'): {'confirmed': 3, '<UNK>': 1}
# ('out', 'confirmed'): {'Hoisting': 3, '<UNK>': 1}
# ('confirmed', 'Hoisting'): {'is': 3, '<UNK>': 1}
# ('Hoisting', 'is'): {'to': 3, '<UNK>': 1}
# ('points', 'governments'): {'Hindu': 3, '<UNK>': 1}
# ('governments', 'Hindu'): {'worked': 3, '<UNK>': 1}
# ('Hindu', 'worked'): {'could': 3, '<UNK>': 1}
# ('worked', 'could'): {'and': 3, '<UNK>': 1}
# ('is', 'likely'): {'scowled': 3, '<UNK>': 1}
# ('likely', 'scowled'): {'community': 3, '<UNK>': 1}
# ('scowled', 'community'): {'comparing': 3, '<UNK>': 1}
# ('community', 'comparing'): {'the': 3, '<UNK>': 1}
# ('comparing', 'the'): {'a': 3, '<UNK>': 1}
# ('it', 'launched'): {'having': 3, '<UNK>': 1}
# ('launched', 'having'): {'awaiting': 3, '<UNK>': 1}
# ('having', 'awaiting'): {',': 3, '<UNK>': 1}
# ('awaiting', ','): {'ultrasound': 3, '<UNK>': 1}
# (',', 'ultrasound'): {'an': 3, '<UNK>': 1}
# ('ultrasound', 'an'): {'’': 3, '<UNK>': 1}
# ('’', 'background'): {'another': 3, '<UNK>': 1}
# ('background', 'another'): {'as': 3, '<UNK>': 1}
# ('another', 'as'): {'found': 3, '<UNK>': 1}
# ('.', 'full'): {'ensure': 3, '<UNK>': 1}
# ('full', 'ensure'): {'.': 3, '<UNK>': 1}
# ('.', 'songs'): {'of': 3, '<UNK>': 1}
# ('songs', 'of'): {'.': 3, '<UNK>': 1}
# ('.', 'End'): {'Trump': 3, '<UNK>': 1}
# ('End', 'Trump'): {'got': 3, '<UNK>': 1}
# ('Trump', 'got'): {'me': 3, '<UNK>': 1}
# ('got', 'me'): {'hygienic': 3, '<UNK>': 1}
# ('me', 'hygienic'): {'under': 3, '<UNK>': 1}
# ('hygienic', 'under'): {'knew': 3, '<UNK>': 1}
# ('under', 'knew'): {',': 3, '<UNK>': 1}
# ('to', 'communists'): {'there': 3, '<UNK>': 1}
# ('communists', 'there'): {'is': 3, '<UNK>': 1}
# ('there', 'is'): {'on': 3, '<UNK>': 1}
# ('will', 'emergency'): {'COVID-19': 3, '<UNK>': 1}
# ('emergency', 'COVID-19'): {'5': 3, '<UNK>': 1}
# ('COVID-19', '5'): {'9971': 3, '<UNK>': 1}
# ('5', '9971'): {'occupation': 3, '<UNK>': 1}
# ('9971', 'occupation'): {'dollar': 3, '<UNK>': 1}
# ('occupation', 'dollar'): {'year': 3, '<UNK>': 1}
# ('dollar', 'year'): {'March': 3, '<UNK>': 1}
# ('year', 'March'): {'pay': 3, '<UNK>': 1}
# ('March', 'pay'): {',': 3, '<UNK>': 1}
# (',', 'shouldn'): {'they': 3, '<UNK>': 1}
# ('shouldn', 'they'): {'many': 3, '<UNK>': 1}
# ('they', 'many'): {'opera': 3, '<UNK>': 1}
# ('many', 'opera'): {'individuals': 3, '<UNK>': 1}
# ('opera', 'individuals'): {'to': 3, '<UNK>': 1}
# ('it', 'pinning'): {'why': 3, '<UNK>': 1}
# ('pinning', 'why'): {'is': 3, '<UNK>': 1}
# ('why', 'is'): {'victim': 3, '<UNK>': 1}
# ('is', 'victim'): {'when': 3, '<UNK>': 1}
# ('victim', 'when'): {'regularly': 3, '<UNK>': 1}
# ('when', 'regularly'): {',': 3, '<UNK>': 1}
# ('regularly', ','): {'they': 3, '<UNK>': 1}
# ('out', 'be'): {'charities': 3, '<UNK>': 1}
# ('be', 'charities'): {'first': 3, '<UNK>': 1}
# ('charities', 'first'): {'.': 3, '<UNK>': 1}
# ('.', 'whose'): {'When': 3, '<UNK>': 1}
# ('whose', 'When'): {'and': 3, '<UNK>': 1}
# ('When', 'and'): {'was': 3, '<UNK>': 1}
# ('was', 'leasing'): {'there': 3, '<UNK>': 1}
# ('leasing', 'there'): {'to': 3, '<UNK>': 1}
# ('of', 'short-range'): {'Thursday': 3, '<UNK>': 1}
# ('short-range', 'Thursday'): {'industry': 3, '<UNK>': 1}
# ('Thursday', 'industry'): {'its': 3, '<UNK>': 1}
# ('industry', 'its'): {'land': 3, '<UNK>': 1}
# ('its', 'land'): {'.': 3, '<UNK>': 1}
# ('land', '.'): {'on': 3, '<UNK>': 1}
# ('the', 'highlighted'): {'mural': 3, '<UNK>': 1}
# ('highlighted', 'mural'): {'transfer': 3, '<UNK>': 1}
# ('mural', 'transfer'): {'AUPE': 3, '<UNK>': 1}
# ('transfer', 'AUPE'): {'worth': 3, '<UNK>': 1}
# ('AUPE', 'worth'): {'.': 3, '<UNK>': 1}
# ('worth', '.'): {'and': 3, '<UNK>': 1}
# ('and', 'Just'): {'would': 3, '<UNK>': 1}
# ('Just', 'would'): {',': 3, '<UNK>': 1}
# ('one', 'weekends'): {'Gap': 3, '<UNK>': 1}
# ('weekends', 'Gap'): {'get': 3, '<UNK>': 1}
# ('Gap', 'get'): {'We': 3, '<UNK>': 1}
# ('get', 'We'): {'scenes': 3, '<UNK>': 1}
# ('We', 'scenes'): {'by': 3, '<UNK>': 1}
# ('scenes', 'by'): {'?': 3, '<UNK>': 1}
# ('by', '?'): {'issue': 3, '<UNK>': 1}
# ('?', 'issue'): {'4336': 3, '<UNK>': 1}
# ('issue', '4336'): {'the': 3, '<UNK>': 1}
# ('4336', 'the'): {'video': 3, '<UNK>': 1}
# ('video', 'during'): {'last': 3, '<UNK>': 1}
# ('during', 'last'): {'unique': 3, '<UNK>': 1}
# ('last', 'unique'): {'Vatanen': 3, '<UNK>': 1}
# ('unique', 'Vatanen'): {',': 3, '<UNK>': 1}
# ('Vatanen', ','): {'the': 3, '<UNK>': 1}
# ('Friday', 'are'): {',': 3, '<UNK>': 1}
# ('for', 'plans'): {'of': 3, '<UNK>': 1}
# ('plans', 'of'): {'906': 3, '<UNK>': 1}
# ('of', '906'): {'to': 3, '<UNK>': 1}
# ('906', 'to'): {'and': 3, '<UNK>': 1}
# ('and', 'infamous'): {'are': 3, '<UNK>': 1}
# ('infamous', 'are'): {')': 3, '<UNK>': 1}
# ('body', '('): {'at': 3, '<UNK>': 1}
# ('(', 'at'): {'of': 3, '<UNK>': 1}
# ('of', 'Falcons'): {'by': 3, '<UNK>': 1}
# ('Falcons', 'by'): {'this': 3, '<UNK>': 1}
# (',', 'signs'): {'workers': 3, '<UNK>': 1}
# ('signs', 'workers'): {'of': 3, '<UNK>': 1}
# ('of', 'Nobel-prize'): {'pretty': 3, '<UNK>': 1}
# ('Nobel-prize', 'pretty'): {'each': 3, '<UNK>': 1}
# ('pretty', 'each'): {'that': 3, '<UNK>': 1}
# ('This', 'Kenosha'): {'1393': 3, '<UNK>': 1}
# ('Kenosha', '1393'): {'shoulder': 3, '<UNK>': 1}
# ('1393', 'shoulder'): {'reception': 3, '<UNK>': 1}
# ('shoulder', 'reception'): {'testing': 3, '<UNK>': 1}
# ('reception', 'testing'): {',': 3, '<UNK>': 1}
# (',', 'Patriotic'): {'an': 3, '<UNK>': 1}
# ('Patriotic', 'an'): {'encouraged': 3, '<UNK>': 1}
# ('an', 'encouraged'): {'in': 3, '<UNK>': 1}
# ('encouraged', 'in'): {'for': 3, '<UNK>': 1}
# ('for', '1281'): {'too': 3, '<UNK>': 1}
# ('1281', 'too'): {'8992': 3, '<UNK>': 1}
# ('too', '8992'): {'at': 3, '<UNK>': 1}
# ('8992', 'at'): {'I': 3, '<UNK>': 1}
# ('mother', 'wo'): {'.': 3, '<UNK>': 1}
# ('wo', '.'): {'to': 3, '<UNK>': 1}
# ('a', '6977'): {'and': 3, '<UNK>': 1}
# ('6977', 'and'): {'the': 3, '<UNK>': 1}
# ('the', 'compete'): {'Medicaid': 3, '<UNK>': 1}
# ('compete', 'Medicaid'): {',': 3, '<UNK>': 1}
# ('Medicaid', ','): {'revealed': 3, '<UNK>': 1}
# ('revealed', '.'): {'food': 3, '<UNK>': 1}
# ('food', 'petitioners'): {'the': 3, '<UNK>': 1}
# ('petitioners', 'the'): {'was': 3, '<UNK>': 1}
# ('was', 'Asexual'): {'as': 3, '<UNK>': 1}
# ('Asexual', 'as'): {'must': 3, '<UNK>': 1}
# ('as', 'must'): {'infants': 3, '<UNK>': 1}
# ('must', 'infants'): {'9337': 3, '<UNK>': 1}
# ('infants', '9337'): {'23': 3, '<UNK>': 1}
# ('9337', '23'): {'colored': 3, '<UNK>': 1}
# ('23', 'colored'): {',': 3, '<UNK>': 1}
# ('colored', ','): {'Australian': 3, '<UNK>': 1}
# (',', 'Australian'): {'I': 3, '<UNK>': 1}
# ('Australian', 'I'): {'Graphics': 3, '<UNK>': 1}
# ('I', 'Graphics'): {'“': 3, '<UNK>': 1}
# ('Graphics', '“'): {'increase': 3, '<UNK>': 1}
# ('“', 'increase'): {'the': 3, '<UNK>': 1}
# ('Chinese', 'never'): {'will': 3, '<UNK>': 1}
# ('never', 'will'): {',': 3, '<UNK>': 1}
# (',', 'these'): {'Many': 3, '<UNK>': 1}
# ('these', 'Many'): {'The': 3, '<UNK>': 1}
# ('Many', 'The'): {'and': 3, '<UNK>': 1}
# ('and', 'others'): {'1866': 3, '<UNK>': 1}
# ('others', '1866'): {'9867': 3, '<UNK>': 1}
# ('1866', '9867'): {'the': 3, '<UNK>': 1}
# ('9867', 'the'): {'the': 3, '<UNK>': 1}
# ('the', 'wasn'): {'considering': 3, '<UNK>': 1}
# ('wasn', 'considering'): {'year': 3, '<UNK>': 1}
# ('considering', 'year'): {'economic': 3, '<UNK>': 1}
# ('year', 'economic'): {'had': 3, '<UNK>': 1}
# ('economic', 'had'): {'angrily': 3, '<UNK>': 1}
# ('had', 'angrily'): {'be': 3, '<UNK>': 1}
# ('angrily', 'be'): {'of': 3, '<UNK>': 1}
# ('of', 'cases'): {'My': 3, '<UNK>': 1}
# ('cases', 'My'): {'it': 3, '<UNK>': 1}
# ('My', 'it'): {'not': 3, '<UNK>': 1}
# ('in', 'Smith'): {'Aashirvaad': 3, '<UNK>': 1}
# ('Smith', 'Aashirvaad'): {'the': 3, '<UNK>': 1}
# ('Aashirvaad', 'the'): {'I': 3, '<UNK>': 1}
# ('“', 'rose'): {"'Simon": 3, '<UNK>': 1}
# ('rose', "'Simon"): {'well': 3, '<UNK>': 1}
# ("'Simon", 'well'): {'will': 3, '<UNK>': 1}
# ('will', 'management'): {'.': 3, '<UNK>': 1}
# ('management', '.'): {"n't": 3, '<UNK>': 1}
# ("n't", 'oils'): {'3959': 3, '<UNK>': 1}
# ('oils', '3959'): {'she': 3, '<UNK>': 1}
# ('3959', 'she'): {'midsize': 3, '<UNK>': 1}
# ('she', 'midsize'): {'.': 3, '<UNK>': 1}
# ('midsize', '.'): {'.': 3, '<UNK>': 1}
# ('of', 'ways'): {'generations': 3, '<UNK>': 1}
# ('ways', 'generations'): {'do': 3, '<UNK>': 1}
# ('generations', 'do'): {'and': 3, '<UNK>': 1}
# ('having', 'will'): {'had': 3, '<UNK>': 1}
# ('will', 'had'): {'he': 3, '<UNK>': 1}
# ('he', 'critics'): {'closing': 3, '<UNK>': 1}
# ('critics', 'closing'): {'accompany': 3, '<UNK>': 1}
# ('closing', 'accompany'): {'but': 3, '<UNK>': 1}
# ('accompany', 'but'): {'advised': 3, '<UNK>': 1}
# ('but', 'advised'): {'unrealistic': 3, '<UNK>': 1}
# ('advised', 'unrealistic'): {'by': 3, '<UNK>': 1}
# ('unrealistic', 'by'): {',': 3, '<UNK>': 1}
# (',', 'drug'): {'an': 3, '<UNK>': 1}
# ('drug', 'an'): {'make': 3, '<UNK>': 1}
# ('make', 'survivors'): {'reiterated': 3, '<UNK>': 1}
# ('survivors', 'reiterated'): {'help': 3, '<UNK>': 1}
# ('reiterated', 'help'): {'believe': 3, '<UNK>': 1}
# ('help', 'believe'): {'was': 3, '<UNK>': 1}
# ('believe', 'was'): {'mat': 3, '<UNK>': 1}
# ('was', 'mat'): {'purchase': 3, '<UNK>': 1}
# ('mat', 'purchase'): {'and': 3, '<UNK>': 1}
# ('purchase', 'and'): {'how': 3, '<UNK>': 1}
# ('how', 'available'): {'and': 3, '<UNK>': 1}
# ('available', 'and'): {'have': 3, '<UNK>': 1}
# ('have', 'OK'): {'the': 3, '<UNK>': 1}
# ('OK', 'the'): {'company': 3, '<UNK>': 1}
# ('company', 'handed'): {':': 3, '<UNK>': 1}
# ('handed', ':'): {'made': 3, '<UNK>': 1}
# (':', 'made'): {'the': 3, '<UNK>': 1}
# ('told', 'left'): {'St.': 3, '<UNK>': 1}
# ('left', 'St.'): {'“': 3, '<UNK>': 1}
# ('St.', '“'): {',': 3, '<UNK>': 1}
# (',', 'relaxation'): {'their': 3, '<UNK>': 1}
# ('relaxation', 'their'): {'where': 3, '<UNK>': 1}
# ('where', 'activating'): {'the': 3, '<UNK>': 1}
# ('activating', 'the'): {'at': 3, '<UNK>': 1}
# ('half', 'been'): {'“': 3, '<UNK>': 1}
# ('“', 'many'): {'after': 3, '<UNK>': 1}
# ('many', 'after'): {'on': 3, '<UNK>': 1}
# ('after', 'on'): {'’': 3, '<UNK>': 1}
# ('’', 'makes'): {'and': 3, '<UNK>': 1}
# ('and', 'Bank'): {'zero': 3, '<UNK>': 1}
# ('Bank', 'zero'): {'rates': 3, '<UNK>': 1}
# ('zero', 'rates'): {'donated': 3, '<UNK>': 1}
# ('rates', 'donated'): {'the': 3, '<UNK>': 1}
# ('donated', 'the'): {'and': 3, '<UNK>': 1}
# ('and', 'fan'): {'don': 3, '<UNK>': 1}
# ('fan', 'don'): {'to': 3, '<UNK>': 1}
# ('be', 'reads'): {'handful': 3, '<UNK>': 1}
# ('reads', 'handful'): {'pursued': 3, '<UNK>': 1}
# ('handful', 'pursued'): {'long': 3, '<UNK>': 1}
# ('pursued', 'long'): {'it': 3, '<UNK>': 1}
# ('long', 'it'): {'that': 3, '<UNK>': 1}
# ('.', 'dominant'): {'forward': 3, '<UNK>': 1}
# ('dominant', 'forward'): {'Sunday': 3, '<UNK>': 1}
# ('forward', 'Sunday'): {'interest': 3, '<UNK>': 1}
# ('Sunday', 'interest'): {'7249': 3, '<UNK>': 1}
# ('interest', '7249'): {'.': 3, '<UNK>': 1}
# ('7249', '.'): {',': 3, '<UNK>': 1}
# ('every', '371'): {'’': 3, '<UNK>': 1}
# ('371', '’'): {'as': 3, '<UNK>': 1}
# ('as', 'Points'): {'medical': 3, '<UNK>': 1}
# ('Points', 'medical'): {'heartsTesting': 3, '<UNK>': 1}
# ('medical', 'heartsTesting'): {'pastor': 3, '<UNK>': 1}
# ('heartsTesting', 'pastor'): {'of': 3, '<UNK>': 1}
# ('pastor', 'of'): {',': 3, '<UNK>': 1}
# ('above', '.'): {'6958': 3, '<UNK>': 1}
# ('.', '6958'): {'a': 3, '<UNK>': 1}
# ('6958', 'a'): {'improve': 3, '<UNK>': 1}
# ('a', 'improve'): {'AN': 3, '<UNK>': 1}
# ('improve', 'AN'): {'in': 3, '<UNK>': 1}
# ('AN', 'in'): {'Meachum': 3, '<UNK>': 1}
# ('in', 'Meachum'): {')': 3, '<UNK>': 1}
# ('Meachum', ')'): {'Director': 3, '<UNK>': 1}
# (')', 'Director'): {'in': 3, '<UNK>': 1}
# ('Director', 'in'): {'course': 3, '<UNK>': 1}
# ('course', 'country'): {'Ore': 3, '<UNK>': 1}
# ('country', 'Ore'): {'together': 3, '<UNK>': 1}
# ('Ore', 'together'): {'a': 3, '<UNK>': 1}
# ('a', 'If'): {'just': 3, '<UNK>': 1}
# ('If', 'just'): {'fears': 3, '<UNK>': 1}
# ('just', 'fears'): {'and': 3, '<UNK>': 1}
# ('fears', 'and'): {'Chelsea': 3, '<UNK>': 1}
# ('and', 'Chelsea'): {'to': 3, '<UNK>': 1}
# ('Chelsea', 'to'): {'of': 3, '<UNK>': 1}
# ('of', 'trucks'): {'continuing': 3, '<UNK>': 1}
# ('trucks', 'continuing'): {'5659': 3, '<UNK>': 1}
# ('continuing', '5659'): {'and': 3, '<UNK>': 1}
# ('5659', 'and'): {'student': 3, '<UNK>': 1}
# ('and', 'student'): {'to': 3, '<UNK>': 1}
# ('student', 'to'): {'conditions': 3, '<UNK>': 1}
# ('to', 'conditions'): {'lower': 3, '’': 3, '<UNK>': 1}
# ('conditions', 'lower'): {'safely': 3, '<UNK>': 1}
# ('lower', 'safely'): {',': 3, '<UNK>': 1}
# ('safely', ','): {'’': 3, '<UNK>': 1}
# ('in', 'major'): {'drink': 3, '<UNK>': 1}
# ('major', 'drink'): {'adding': 3, '<UNK>': 1}
# ('drink', 'adding'): {'work': 3, '<UNK>': 1}
# ('adding', 'work'): {'the': 3, '<UNK>': 1}
# ('London', 'grainy'): {'9360': 3, '<UNK>': 1}
# ('grainy', '9360'): {'Senate': 3, '<UNK>': 1}
# ('9360', 'Senate'): {'has': 3, '<UNK>': 1}
# ('Senate', 'has'): {'thousand': 3, '<UNK>': 1}
# ('has', 'thousand'): {'From': 3, '<UNK>': 1}
# ('thousand', 'From'): {'MRU': 3, '<UNK>': 1}
# ('From', 'MRU'): {'Orange': 3, '<UNK>': 1}
# ('MRU', 'Orange'): {'Task': 3, '<UNK>': 1}
# ('Orange', 'Task'): {'should': 3, '<UNK>': 1}
# ('Task', 'should'): {'Line': 3, '<UNK>': 1}
# ('should', 'Line'): {'yesterday': 3, '<UNK>': 1}
# ('Line', 'yesterday'): {'the': 3, '<UNK>': 1}
# ('yesterday', 'the'): {'said': 3, '<UNK>': 1}
# ('said', 'climate'): {'launching': 3, '<UNK>': 1}
# ('climate', 'launching'): {'of': 3, '<UNK>': 1}
# ('were', 'major'): {'secret': 3, '<UNK>': 1}
# ('major', 'secret'): {'of': 3, '<UNK>': 1}
# ('secret', 'of'): {'results': 3, '<UNK>': 1}
# ('of', 'results'): {',': 3, '<UNK>': 1}
# ('longer', 'attendees'): {'four': 3, '<UNK>': 1}
# ('attendees', 'four'): {'taste': 3, '<UNK>': 1}
# ('four', 'taste'): {'to': 3, '<UNK>': 1}
# ('taste', 'to'): {'Kyle': 3, '<UNK>': 1}
# ('to', 'Kyle'): {'his': 3, '<UNK>': 1}
# ('Kyle', 'his'): {'no': 3, '<UNK>': 1}
# ('his', 'no'): {'it': 3, '<UNK>': 1}
# ('no', 'it'): {'in': 3, '<UNK>': 1}
# ('that', 'hole'): {'the': 3, '<UNK>': 1}
# ('hole', 'the'): {'that': 3, '<UNK>': 1}
# ('that', 'torrent'): {'whose': 3, '<UNK>': 1}
# ('torrent', 'whose'): {'achievement': 3, '<UNK>': 1}
# ('whose', 'achievement'): {'ahead': 3, '<UNK>': 1}
# ('achievement', 'ahead'): {'up': 3, '<UNK>': 1}
# ('ahead', 'up'): {'first': 3, '<UNK>': 1}
# ('up', 'first'): {'have': 3, '<UNK>': 1}
# ('first', 'have'): {'business': 3, '<UNK>': 1}
# ('have', 'business'): {'causes': 3, '<UNK>': 1}
# ('business', 'causes'): {',': 3, '<UNK>': 1}
# ('causes', ','): {'the': 3, '<UNK>': 1}
# ('quarter', 'educators'): {'out': 3, '<UNK>': 1}
# ('educators', 'out'): {'the': 3, '<UNK>': 1}
# ('four', 'steers'): {'was': 3, '<UNK>': 1}
# ('steers', 'was'): {'she': 3, '<UNK>': 1}
# ('’', 'Maine'): {'eligibility': 3, '<UNK>': 1}
# ('Maine', 'eligibility'): {'to': 3, '<UNK>': 1}
# ('eligibility', 'to'): {'find': 3, '<UNK>': 1}
# ('of', 'Arsenal'): {',': 3, '<UNK>': 1}
# ('were', 'business'): {'You': 3, '<UNK>': 1}
# ('business', 'You'): {'to': 3, '<UNK>': 1}
# ('of', 'skies'): {'Stand-in': 3, '<UNK>': 1}
# ('skies', 'Stand-in'): {'short': 3, '<UNK>': 1}
# ('Stand-in', 'short'): {'chapters': 3, '<UNK>': 1}
# ('short', 'chapters'): {'the': 3, '<UNK>': 1}
# ('chapters', 'the'): {'said': 3, '<UNK>': 1}
# ('said', 'rare'): {'musicians': 3, '<UNK>': 1}
# ('rare', 'musicians'): {'with': 3, '<UNK>': 1}
# ('musicians', 'with'): {'to': 3, '<UNK>': 1}
# ('who', 'Timberwolves'): {',': 3, '<UNK>': 1}
# ('Timberwolves', ','): {'With': 3, '<UNK>': 1}
# ('With', 'a'): {'believed': 3, '<UNK>': 1}
# ('a', 'believed'): {'said': 3, '<UNK>': 1}
# ('believed', 'said'): {'Raiders': 3, '<UNK>': 1}
# ('said', 'Raiders'): {'following': 3, '<UNK>': 1}
# ('Raiders', 'following'): {'to': 3, '<UNK>': 1}
# ('to', 'took'): {'emerald': 3, '<UNK>': 1}
# ('took', 'emerald'): {'to': 3, '<UNK>': 1}
# ('emerald', 'to'): {'the': 3, '<UNK>': 1}
# ('s', 'Games'): {'and': 3, '<UNK>': 1}
# ('Games', 'and'): {'a': 3, '<UNK>': 1}
# ('a', 'amphibian-like'): {'started': 3, '<UNK>': 1}
# ('amphibian-like', 'started'): {'Tails': 3, '<UNK>': 1}
# ('started', 'Tails'): {'an': 3, '<UNK>': 1}
# ('Tails', 'an'): {'increased': 3, '<UNK>': 1}
# ('an', 'increased'): {'2672': 3, '<UNK>': 1}
# ('increased', '2672'): {'Collin': 3, '<UNK>': 1}
# ('2672', 'Collin'): {'could': 3, '<UNK>': 1}
# ('Collin', 'could'): {'s': 3, '<UNK>': 1}
# ("'s", 'audience'): {'he': 3, '<UNK>': 1}
# ('audience', 'he'): {'Thursday': 3, '<UNK>': 1}
# ('he', 'Thursday'): {'counterparts': 3, '<UNK>': 1}
# ('Thursday', 'counterparts'): {'friends': 3, '<UNK>': 1}
# ('counterparts', 'friends'): {'in': 3, '<UNK>': 1}
# ('friends', 'in'): {'.': 3, '<UNK>': 1}
# ('the', '7470'): {'enough': 3, '<UNK>': 1}
# ('7470', 'enough'): {',': 3, '<UNK>': 1}
# ('of', '9509'): {'.': 3, '<UNK>': 1}
# ('9509', '.'): {'Carol': 3, '<UNK>': 1}
# ('.', 'Carol'): {'subject': 3, '<UNK>': 1}
# ('Carol', 'subject'): {'fleeing': 3, '<UNK>': 1}
# ('subject', 'fleeing'): {'that': 3, '<UNK>': 1}
# ('fleeing', 'that'): {'18th': 3, '<UNK>': 1}
# ('that', '18th'): {'charges': 3, '<UNK>': 1}
# ('18th', 'charges'): {'worked': 3, '<UNK>': 1}
# ('charges', 'worked'): {'or': 3, '<UNK>': 1}
# ('worked', 'or'): {'classrooms': 3, '<UNK>': 1}
# ('or', 'classrooms'): {',': 3, '<UNK>': 1}
# ('died', 'country'): {'human': 3, '<UNK>': 1}
# ('country', 'human'): {'10': 3, '<UNK>': 1}
# ('human', '10'): {'go': 3, '<UNK>': 1}
# ('10', 'go'): {'he': 3, '<UNK>': 1}
# ('go', 'he'): {'in': 3, '<UNK>': 1}
# ('in', 'write'): {'Rep.': 3, '<UNK>': 1}
# ('write', 'Rep.'): {'.': 3, '<UNK>': 1}
# ('shared', 'health'): {'keen': 3, '<UNK>': 1}
# ('health', 'keen'): {'originally': 3, '<UNK>': 1}
# ('keen', 'originally'): {'symptoms': 3, '<UNK>': 1}
# ('originally', 'symptoms'): {'!': 3, '<UNK>': 1}
# ('symptoms', '!'): {'and': 3, '<UNK>': 1}
# ('and', 'University'): {'a': 3, '<UNK>': 1}
# ('the', 'save'): {'at': 3, '<UNK>': 1}
# ('save', 'at'): {'.': 3, '<UNK>': 1}
# ('to', 'fart'): {'confirm': 3, '<UNK>': 1}
# ('fart', 'confirm'): {'looking': 3, '<UNK>': 1}
# ('confirm', 'looking'): {'adding': 3, '<UNK>': 1}
# ('looking', 'adding'): {',': 3, '<UNK>': 1}
# (',', 'Gretzky'): {'than': 3, '<UNK>': 1}
# ('Gretzky', 'than'): {'person': 3, '<UNK>': 1}
# ('than', 'person'): {'say': 3, '<UNK>': 1}
# ('person', 'say'): {'killings': 3, '<UNK>': 1}
# ('say', 'killings'): {'partnered': 3, '<UNK>': 1}
# ('killings', 'partnered'): {'sometimes': 3, '<UNK>': 1}
# ('partnered', 'sometimes'): {'He': 3, '<UNK>': 1}
# ('sometimes', 'He'): {'that': 3, '<UNK>': 1}
# ('that', 'rose'): {'their': 3, '<UNK>': 1}
# ('rose', 'their'): {'shots': 3, '<UNK>': 1}
# ('their', 'shots'): {'Morgan': 3, '<UNK>': 1}
# ('shots', 'Morgan'): {'partner': 3, '<UNK>': 1}
# ('Morgan', 'partner'): {'feet': 3, '<UNK>': 1}
# ('partner', 'feet'): {'next': 3, '<UNK>': 1}
# ('feet', 'next'): {'and': 3, '<UNK>': 1}
# ('and', 'torque'): {'of': 3, '<UNK>': 1}
# ('torque', 'of'): {'the': 3, '<UNK>': 1}
# ('didn', 'to'): {'reflective': 3, '<UNK>': 1}
# ('reflective', 'on'): {'track': 3, '<UNK>': 1}
# ('on', 'track'): {'Wednesday': 3, '<UNK>': 1}
# ('track', 'Wednesday'): {'death': 3, '<UNK>': 1}
# ('Wednesday', 'death'): {'to': 3, '<UNK>': 1}
# ('to', 'idleness'): {'the': 3, '<UNK>': 1}
# ('idleness', 'the'): {'face': 3, '<UNK>': 1}
# ('the', 'face'): {'resident': 3, '<UNK>': 1}
# ('face', 'resident'): {'abroad': 3, '<UNK>': 1}
# ('resident', 'abroad'): {'who': 3, '<UNK>': 1}
# ('abroad', 'who'): {'alongside': 3, '<UNK>': 1}
# ('who', 'alongside'): {'a': 3, '<UNK>': 1}
# ('alongside', 'a'): {'a': 3, '<UNK>': 1}
# ('a', 'us'): {'6945': 3, '<UNK>': 1}
# ('us', '6945'): {'said': 3, '<UNK>': 1}
# ('6945', 'said'): {'was': 3, '<UNK>': 1}
# ('said', 'was'): {'managed': 3, '<UNK>': 1}
# ('was', 'managed'): {'Red': 3, '<UNK>': 1}
# ('managed', 'Red'): {'also': 3, '<UNK>': 1}
# ('Red', 'also'): {'7142': 3, '<UNK>': 1}
# ('also', '7142'): {'Russell': 3, '<UNK>': 1}
# ('7142', 'Russell'): {'up': 3, '<UNK>': 1}
# ('Russell', 'up'): {',': 3, '<UNK>': 1}
# (',', '50s'): {'waving': 3, '<UNK>': 1}
# ('50s', 'waving'): {'the': 3, '<UNK>': 1}
# ('waving', 'the'): {'holes': 3, '<UNK>': 1}
# ('holes', 'this'): {'downright': 3, '<UNK>': 1}
# ('this', 'downright'): {'And': 3, '<UNK>': 1}
# ('downright', 'And'): {'RA': 3, '<UNK>': 1}
# ('And', 'RA'): {'Interim': 3, '<UNK>': 1}
# ('RA', 'Interim'): {'Adam': 3, '<UNK>': 1}
# ('Interim', 'Adam'): {'of': 3, '<UNK>': 1}
# ('Adam', 'of'): {'Who': 3, '<UNK>': 1}
# ('of', 'Who'): {'about': 3, '<UNK>': 1}
# ('Who', 'about'): {'succession': 3, '<UNK>': 1}
# ('about', 'succession'): {',': 3, '<UNK>': 1}
# ('succession', ','): {'of': 3, '<UNK>': 1}
# ('mind', 'campaign'): {'Shohei': 3, '<UNK>': 1}
# ('campaign', 'Shohei'): {'property': 3, '<UNK>': 1}
# ('Shohei', 'property'): {'8511': 3, '<UNK>': 1}
# ('property', '8511'): {'still': 3, '<UNK>': 1}
# ('8511', 'still'): {'6563': 3, '<UNK>': 1}
# ('still', '6563'): {'this': 3, '<UNK>': 1}
# ('6563', 'this'): {'away': 3, '<UNK>': 1}
# ('this', 'away'): {'cases': 3, '<UNK>': 1}
# ('away', 'cases'): {'can': 3, '<UNK>': 1}
# ('cases', 'can'): {'first': 3, '<UNK>': 1}
# ('first', 'thank'): {'a': 3, '<UNK>': 1}
# ('thank', 'a'): {'safety': 3, '<UNK>': 1}
# ('safety', 'end'): {'barrister': 3, '<UNK>': 1}
# ('end', 'barrister'): {'is': 3, '<UNK>': 1}
# ('barrister', 'is'): {'December': 3, '<UNK>': 1}
# ('is', 'December'): {'.': 3, '<UNK>': 1}
# ('has', 'happened'): {'me': 3, '<UNK>': 1}
# ('happened', 'me'): {'it': 3, '<UNK>': 1}
# ('me', 'it'): {'the': 3, '<UNK>': 1}
# ('While', 'older'): {'copy': 3, '<UNK>': 1}
# ('older', 'copy'): {'8619': 3, '<UNK>': 1}
# ('copy', '8619'): {'as': 3, '<UNK>': 1}
# ('8619', 'as'): {'Teresa': 3, '<UNK>': 1}
# ('as', 'Teresa'): {',': 3, '<UNK>': 1}
# ('Teresa', ','): {'her': 3, '<UNK>': 1}
# ('her', 'Ballarat'): {'and': 3, '<UNK>': 1}
# ('Ballarat', 'and'): {'in': 3, '<UNK>': 1}
# ('in', 'role'): {'such': 3, '<UNK>': 1}
# ('role', 'such'): {'detailed': 3, '<UNK>': 1}
# ('such', 'detailed'): {'that': 3, '<UNK>': 1}
# ('detailed', 'that'): {'wants': 3, '<UNK>': 1}
# ('that', 'wants'): {'of': 3, '<UNK>': 1}
# ('in', '8750'): {'and': 3, '<UNK>': 1}
# ('8750', 'and'): {'Tran': 3, '<UNK>': 1}
# ('and', 'Tran'): {'for': 3, '<UNK>': 1}
# ('Tran', 'for'): {'a': 3, '<UNK>': 1}
# ('open', 'leash…'): {'face': 3, '<UNK>': 1}
# ('leash…', 'face'): {'of': 3, '<UNK>': 1}
# ('face', 'of'): {'a': 3, '<UNK>': 1}
# ('their', 'entirety'): {'changed': 3, '<UNK>': 1}
# ('entirety', 'changed'): {'NABARD': 3, '<UNK>': 1}
# ('changed', 'NABARD'): {'Before': 3, '<UNK>': 1}
# ('NABARD', 'Before'): {'or': 3, '<UNK>': 1}
# ('Before', 'or'): {'4622': 3, '<UNK>': 1}
# ('or', '4622'): {'option': 3, '<UNK>': 1}
# ('4622', 'option'): {'entity': 3, '<UNK>': 1}
# ('option', 'entity'): {'has': 3, '<UNK>': 1}
# ('entity', 'has'): {'sending': 3, '<UNK>': 1}
# ('has', 'sending'): {'The': 3, '<UNK>': 1}
# ('sending', 'The'): {'Airlines': 3, '<UNK>': 1}
# ('The', 'Airlines'): {'.': 3, '<UNK>': 1}
# ('Airlines', '.'): {'at': 3, '<UNK>': 1}
# ('at', 'criminal'): {'the': 3, '<UNK>': 1}
# ('doors', ')'): {'spring': 3, '<UNK>': 1}
# (')', 'spring'): {'Cooke': 3, '<UNK>': 1}
# ('spring', 'Cooke'): {'and': 3, '<UNK>': 1}
# ('Cooke', 'and'): {'next': 3, '<UNK>': 1}
# ('next', 'Levels'): {'liberate': 3, '<UNK>': 1}
# ('Levels', 'liberate'): {'the': 3, '<UNK>': 1}
# ('liberate', 'the'): {'race': 3, '<UNK>': 1}
# ('the', 'race'): {'4943': 3, '<UNK>': 1}
# ('race', '4943'): {',': 3, '<UNK>': 1}
# ('4943', ','): {'In': 3, '<UNK>': 1}
# ('In', 'Despite'): {'game': 3, '<UNK>': 1}
# ('Despite', 'game'): {'“': 3, '<UNK>': 1}
# ('game', '“'): {'’': 3, '<UNK>': 1}
# ('this', 'predicted'): {'approves': 3, '<UNK>': 1}
# ('predicted', 'approves'): {'is': 3, '<UNK>': 1}
# ('approves', 'is'): {'police': 3, '<UNK>': 1}
# ('police', 'love'): {'.': 3, '<UNK>': 1}
# ('.', 'players'): {'the': 3, '<UNK>': 1}
# ('the', 'dozen'): {'.': 3, '<UNK>': 1}
# ('dozen', '.'): {'more': 3, '<UNK>': 1}
# ('.', '2644'): {'66,000': 3, '<UNK>': 1}
# ('2644', '66,000'): {'813': 3, '<UNK>': 1}
# ('66,000', '813'): {'physical': 3, '<UNK>': 1}
# ('813', 'physical'): {'their': 3, '<UNK>': 1}
# ('physical', 'their'): {'There': 3, '<UNK>': 1}
# ('their', 'There'): {'the': 3, '<UNK>': 1}
# ('The', 'just'): {'cheese': 3, '<UNK>': 1}
# ('just', 'cheese'): {',': 3, '<UNK>': 1}
# ('cheese', ','): {'that': 3, '<UNK>': 1}
# ('and', 'electric'): {'we': 3, '<UNK>': 1}
# ('electric', 'we'): {'than': 3, '<UNK>': 1}
# ('we', 'than'): {'low': 3, '<UNK>': 1}
# ('than', 'low'): {"'Seeing": 3, '<UNK>': 1}
# ('low', "'Seeing"): {'picking': 3, '<UNK>': 1}
# ("'Seeing", 'picking'): {'Crystal': 3, '<UNK>': 1}
# ('picking', 'Crystal'): {'the': 3, '<UNK>': 1}
# ('Crystal', 'the'): {'a': 3, '<UNK>': 1}
# ('a', '7512'): {'move': 3, '<UNK>': 1}
# ('7512', 'move'): {'353': 3, '<UNK>': 1}
# ('move', '353'): {'.': 3, '<UNK>': 1}
# ('353', '.'): {':': 3, '<UNK>': 1}
# (':', 'Why'): {'the': 3, '<UNK>': 1}
# ('Why', 'the'): {'eat': 3, '<UNK>': 1}
# ('the', 'eat'): {'was': 3, '<UNK>': 1}
# ('eat', 'was'): {'buses': 3, '<UNK>': 1}
# ('was', 'buses'): {'Louis': 3, '<UNK>': 1}
# ('buses', 'Louis'): {'and': 3, '<UNK>': 1}
# ('Louis', 'and'): {'In': 3, '<UNK>': 1}
# ('the', 'silly'): {'said': 3, '<UNK>': 1}
# ('silly', 'said'): {',': 3, '<UNK>': 1}
# ('shuttered', 'back'): {'are': 3, '<UNK>': 1}
# ('are', '6445'): {'Mosley': 3, '<UNK>': 1}
# ('6445', 'Mosley'): {'WHO': 3, '<UNK>': 1}
# ('Mosley', 'WHO'): {'Covington': 3, '<UNK>': 1}
# ('WHO', 'Covington'): {'9409': 3, '<UNK>': 1}
# ('Covington', '9409'): {'.': 3, '<UNK>': 1}
# ('9409', '.'): {'they': 3, '<UNK>': 1}
# ('According', 'a'): {'yourself': 3, '<UNK>': 1}
# ('yourself', 'Pre-School'): {'Detachment': 3, '<UNK>': 1}
# ('Pre-School', 'Detachment'): {'scheduled': 3, '<UNK>': 1}
# ('Detachment', 'scheduled'): {'.': 3, '<UNK>': 1}
# ('scheduled', '.'): {'many—if': 3, '<UNK>': 1}
# ('.', 'many—if'): {'Things': 3, '<UNK>': 1}
# ('many—if', 'Things'): {'Air': 3, '<UNK>': 1}
# ('Things', 'Air'): {'fashion': 3, '<UNK>': 1}
# ('Air', 'fashion'): {'of': 3, '<UNK>': 1}
# ('fashion', 'of'): {'This': 3, '<UNK>': 1}
# ('This', 'world'): {',': 3, '<UNK>': 1}
# (',', 'extradited'): {'the': 3, '<UNK>': 1}
# ('extradited', 'the'): {'.': 3, '<UNK>': 1}
# ('.', 'chance'): {'in': 3, '<UNK>': 1}
# (',', '920'): {'of': 3, '<UNK>': 1}
# ('920', 'of'): {',': 3, '<UNK>': 1}
# (',', 'Salt'): {'charged': 3, '<UNK>': 1}
# ('Salt', 'charged'): {'Washington': 3, '<UNK>': 1}
# ('charged', 'Washington'): {'catch': 3, '<UNK>': 1}
# ('Washington', 'catch'): {'Husker': 3, '<UNK>': 1}
# ('catch', 'Husker'): {'to': 3, '<UNK>': 1}
# ('Husker', 'to'): {"'s": 3, '<UNK>': 1}
# ("'s", 'game'): {'mayor': 3, '<UNK>': 1}
# ('game', 'mayor'): {'cancer': 3, '<UNK>': 1}
# ('mayor', 'cancer'): {'and': 3, '<UNK>': 1}
# ('cancer', 'and'): {'to': 3, '<UNK>': 1}
# ('It', 'got'): {'and': 3, '<UNK>': 1}
# ('will', 'Lee'): {'a': 3, '<UNK>': 1}
# ('Lee', 'a'): {"'s": 3, '<UNK>': 1}
# ('was', 'K-12'): {'that': 3, '<UNK>': 1}
# ('K-12', 'that'): {'a': 3, '<UNK>': 1}
# ('they', 'Queen'): {'the': 3, '<UNK>': 1}
# ('Queen', 'the'): {'Jan.': 3, '<UNK>': 1}
# ('of', 'others'): {'a': 3, '<UNK>': 1}
# ('a', 'Becky'): {'to': 3, '<UNK>': 1}
# ('Becky', 'to'): {'days': 3, '<UNK>': 1}
# ('days', 'order'): {'the': 3, '<UNK>': 1}
# ('was', 'appearance'): {'an': 3, '<UNK>': 1}
# ('appearance', 'an'): {',': 3, '<UNK>': 1}
# (',', 'failure'): {'may': 3, '<UNK>': 1}
# ('failure', 'may'): {'633': 3, '<UNK>': 1}
# ('may', '633'): {'“': 3, '<UNK>': 1}
# ('633', '“'): {'to': 3, '<UNK>': 1}
# ('to', 'statue'): {'would': 3, '<UNK>': 1}
# ('statue', 'would'): {'meet': 3, '<UNK>': 1}
# ('would', 'meet'): {'Congress': 3, '<UNK>': 1}
# ('meet', 'Congress'): {'4995': 3, '<UNK>': 1}
# ('Congress', '4995'): {'of': 3, '<UNK>': 1}
# ('4995', 'of'): {'Parle': 3, '<UNK>': 1}
# ('of', 'Parle'): {'by': 3, '<UNK>': 1}
# ('Parle', 'by'): {'.': 3, '<UNK>': 1}
# ('.', 'episode'): {'the': 3, '<UNK>': 1}
# ('episode', 'the'): {'that': 3, '<UNK>': 1}
# ('that', '23rd'): {'.': 3, '<UNK>': 1}
# ('23rd', '.'): {'to': 3, '<UNK>': 1}
# ('to', 'seven-play'): {'add': 3, '<UNK>': 1}
# ('seven-play', 'add'): {'casualties': 3, '<UNK>': 1}
# ('add', 'casualties'): {'Our': 3, '<UNK>': 1}
# ('casualties', 'Our'): {'Last': 3, '<UNK>': 1}
# ('Our', 'Last'): {'failure': 3, '<UNK>': 1}
# ('Last', 'failure'): {'That': 3, '<UNK>': 1}
# ('failure', 'That'): {'are': 3, '<UNK>': 1}
# ('That', 'are'): {'of': 3, '<UNK>': 1}
# ('be', 'receive'): {'another': 3, '<UNK>': 1}
# ('receive', 'another'): {'norms': 3, '<UNK>': 1}
# ('another', 'norms'): {'3563': 3, '<UNK>': 1}
# ('norms', '3563'): {'reduced': 3, '<UNK>': 1}
# ('3563', 'reduced'): {'representative': 3, '<UNK>': 1}
# ('reduced', 'representative'): {'of': 3, '<UNK>': 1}
# ('representative', 'of'): {'were': 3, '<UNK>': 1}
# ('the', '4279'): {'Randewich': 3, '<UNK>': 1}
# ('4279', 'Randewich'): {'ravens': 3, '<UNK>': 1}
# ('Randewich', 'ravens'): {'the': 3, '<UNK>': 1}
# ('ravens', 'the'): {'Commander': 3, '<UNK>': 1}
# ('the', 'Commander'): {'I': 3, '<UNK>': 1}
# ('Commander', 'I'): {'art': 3, '<UNK>': 1}
# ('I', 'art'): {'refused': 3, '<UNK>': 1}
# ('art', 'refused'): {'We': 3, '<UNK>': 1}
# ('refused', 'We'): {'he': 3, '<UNK>': 1}
# ('he', 'anticipated'): {'7455': 3, '<UNK>': 1}
# ('anticipated', '7455'): {'a': 3, '<UNK>': 1}
# ('7455', 'a'): {'been': 3, '<UNK>': 1}
# ('been', 've'): {"''": 3, '<UNK>': 1}
# ('or', 'died'): {'public': 3, '<UNK>': 1}
# ('died', 'public'): {'.': 3, '<UNK>': 1}
# ('s', 'critical'): {'under': 3, '<UNK>': 1}
# ('critical', 'under'): {'president': 3, '<UNK>': 1}
# ('under', 'president'): {'the': 3, '<UNK>': 1}
# ('the', 'artists'): {'terrorists': 3, '<UNK>': 1}
# ('artists', 'terrorists'): {'star': 3, '<UNK>': 1}
# ('terrorists', 'star'): {'Nigeria': 3, '<UNK>': 1}
# ('star', 'Nigeria'): {'9172': 3, '<UNK>': 1}
# ('Nigeria', '9172'): {'closed': 3, '<UNK>': 1}
# ('9172', 'closed'): {'.': 3, '<UNK>': 1}
# ('.', 'slick'): {'on': 3, '<UNK>': 1}
# ('slick', 'on'): {'8116': 3, '<UNK>': 1}
# ('on', '8116'): {'move': 3, '<UNK>': 1}
# ('8116', 'move'): {'Jellicle': 3, '<UNK>': 1}
# ('move', 'Jellicle'): {'the': 3, '<UNK>': 1}
# ('Jellicle', 'the'): {'Ramaphosa': 3, '<UNK>': 1}
# ('Ramaphosa', 'but'): {'Is': 3, '<UNK>': 1}
# ('but', 'Is'): {'the': 3, '<UNK>': 1}
# ('Is', 'the'): {'now': 3, '<UNK>': 1}
# ('now', 'specialists'): {'1096': 3, '<UNK>': 1}
# ('specialists', '1096'): {'United': 3, '<UNK>': 1}
# ('1096', 'United'): {'policy': 3, '<UNK>': 1}
# ('United', 'policy'): {'said': 3, '<UNK>': 1}
# ('policy', 'said'): {'this': 3, '<UNK>': 1}
# ('this', '9791'): {'pattern': 3, '<UNK>': 1}
# ('9791', 'pattern'): {'green': 3, '<UNK>': 1}
# ('pattern', 'green'): {'interpreter': 3, '<UNK>': 1}
# ('green', 'interpreter'): {'Here': 3, '<UNK>': 1}
# ('interpreter', 'Here'): {'also': 3, '<UNK>': 1}
# ('Here', 'also'): {'vaccination': 3, '<UNK>': 1}
# ('also', 'vaccination'): {'that': 3, '<UNK>': 1}
# ('vaccination', 'that'): {'’': 3, '<UNK>': 1}
# ('’', '705'): {'it': 3, '<UNK>': 1}
# ('705', 'it'): {'give': 3, '<UNK>': 1}
# ('it', 'give'): {'healthcare': 3, '<UNK>': 1}
# ('give', 'healthcare'): {'Control': 3, '<UNK>': 1}
# ...
# ('3661', 'in'): {'8755': 3, '<UNK>': 1}
# ('in', '8755'): {'occasion': 3, '<UNK>': 1}
# ('8755', 'occasion'): {'show': 3, '<UNK>': 1}
# ('occasion', 'show'): {'so': 3, '<UNK>': 1}
# ('show', 'so'): {'Constitutional': 3, '<UNK>': 1}
# ('so', 'Constitutional'): {'on': 3, '<UNK>': 1}
# ('Constitutional', 'on'): {'Neligh': 3, '<UNK>': 1}
# ('on', 'Neligh'): {'commissioned': 3, '<UNK>': 1}
# ('Neligh', 'commissioned'): {'will': 3, '<UNK>': 1}
# ('commissioned', 'will'): {'We': 3, '<UNK>': 1}
# ('will', 'We'): {'officer': 3, '<UNK>': 1}
# ('We', 'officer'): {'latest': 3, '<UNK>': 1}
# ('officer', 'latest'): {'the': 3, '<UNK>': 1}
# ('’', 'willing'): {'the': 3, '<UNK>': 1}
# ('willing', 'the'): {'8820': 3, '<UNK>': 1}
# ('the', '8820'): {'’': 3, '<UNK>': 1}
# ('8820', '’'): {'Group': 3, '<UNK>': 1}
# ('’', 'Group'): {'comments': 3, '<UNK>': 1}
# ('Group', 'comments'): {'as': 3, '<UNK>': 1}
# ('comments', 'as'): {'7407': 3, '<UNK>': 1}
# ('as', '7407'): {'2017': 3, '<UNK>': 1}
# ('7407', '2017'): {'if': 3, '<UNK>': 1}
# ('2017', 'if'): {'things': 3, '<UNK>': 1}
# ('if', 'things'): {'an': 3, '<UNK>': 1}
# ('things', 'an'): {',': 3, '<UNK>': 1}
# ('be', 'over'): {'also': 3, '<UNK>': 1}
# ('over', 'also'): {',': 3, '<UNK>': 1}
# (',', 'NAN'): {'man': 3, '<UNK>': 1}
# ('NAN', 'man'): {'life': 3, '<UNK>': 1}
# ('man', 'life'): {'verified': 3, '<UNK>': 1}
# ('life', 'verified'): {'sports': 3, '<UNK>': 1}
# ('verified', 'sports'): {'these': 3, '<UNK>': 1}
# ('sports', 'these'): {'a': 3, '<UNK>': 1}
# ('and', 'Gold'): {',': 3, '<UNK>': 1}
# ('Gold', ','): {'Terrell': 3, '<UNK>': 1}
# (',', 'Terrell'): {'payroll': 3, '<UNK>': 1}
# ('Terrell', 'payroll'): {'s': 3, '<UNK>': 1}
# ('payroll', 's'): {'.': 3, '<UNK>': 1}
# (',', 'walk'): {'team': 3, '<UNK>': 1}
# ('walk', 'team'): {'in': 3, '<UNK>': 1}
# ('the', 'Huntington'): {'4014': 3, '<UNK>': 1}
# ('Huntington', '4014'): {'proportionate': 3, '<UNK>': 1}
# ('4014', 'proportionate'): {'.': 3, '<UNK>': 1}
# ('proportionate', '.'): {'Roe': 3, '<UNK>': 1}
# ('.', 'Roe'): {'to': 3, '<UNK>': 1}
# ('Roe', 'to'): {'it': 3, '<UNK>': 1}
# ('.', 'signing'): {'Lesbian': 3, '<UNK>': 1}
# ('signing', 'Lesbian'): {'wall': 3, '<UNK>': 1}
# ('Lesbian', 'wall'): {'old': 3, '<UNK>': 1}
# ('wall', 'old'): {'has': 3, '<UNK>': 1}
# ('old', 'has'): {'and': 3, '<UNK>': 1}
# ('best', 'several'): {'voted': 3, '<UNK>': 1}
# ('several', 'voted'): {'before': 3, '<UNK>': 1}
# ('voted', 'before'): {'of': 3, '<UNK>': 1}
# ('“', 'stay'): {'department': 3, '<UNK>': 1}
# ('stay', 'department'): {'US': 3, '<UNK>': 1}
# ('department', 'US'): {'of': 3, '<UNK>': 1}
# (',', 'easyJet'): {'.': 3, '<UNK>': 1}
# ('easyJet', '.'): {'chef': 3, '<UNK>': 1}
# ('.', 'chef'): {',': 3, '<UNK>': 1}
# ('chef', ','): {'Rose': 3, '<UNK>': 1}
# (',', 'Rose'): {'days': 3, '<UNK>': 1}
# ('Rose', 'days'): {'Williams': 3, '<UNK>': 1}
# ('days', 'Williams'): {'rooms': 3, '<UNK>': 1}
# ('Williams', 'rooms'): {'humanitarian': 3, '<UNK>': 1}
# ('rooms', 'humanitarian'): {'her': 3, '<UNK>': 1}
# ('humanitarian', 'her'): {'involving': 3, '<UNK>': 1}
# ('her', 'involving'): {'from': 3, '<UNK>': 1}
# ('involving', 'from'): {'late': 3, '<UNK>': 1}
# ('late', 'pizza'): {'the': 3, '<UNK>': 1}
# ('pizza', 'the'): {',': 3, '<UNK>': 1}
# ('His', 'per'): {'it': 3, '<UNK>': 1}
# ('again', 'Some'): {'a': 3, '<UNK>': 1}
# ('Some', 'a'): {'comfort': 3, '<UNK>': 1}
# ('a', 'comfort'): {'western': 3, '<UNK>': 1}
# ('comfort', 'western'): {'eye': 3, '<UNK>': 1}
# ('western', 'eye'): {'Court': 3, '<UNK>': 1}
# ('eye', 'Court'): {'to': 3, '<UNK>': 1}
# ('Court', 'to'): {'In': 3, '<UNK>': 1}
# ('.', '4683'): {'that': 3, '<UNK>': 1}
# ('4683', 'that'): {'rock': 3, '<UNK>': 1}
# ('that', 'rock'): {'than': 3, '<UNK>': 1}
# ('rock', 'than'): {'If': 3, '<UNK>': 1}
# ('than', 'If'): {'from': 3, '<UNK>': 1}
# ('from', 'Andrea'): {'a': 3, '<UNK>': 1}
# ('Andrea', 'a'): {'visitors': 3, '<UNK>': 1}
# ('a', 'visitors'): {'data': 3, '<UNK>': 1}
# ('visitors', 'data'): {'guarantee': 3, '<UNK>': 1}
# ('data', 'guarantee'): {'time': 3, '<UNK>': 1}
# ('guarantee', 'time'): {'Our': 3, '<UNK>': 1}
# ('time', 'Our'): {'Pikachu': 3, '<UNK>': 1}
# ('Our', 'Pikachu'): {'eventually': 3, '<UNK>': 1}
# ('Pikachu', 'eventually'): {'The': 3, '<UNK>': 1}
# ('eventually', 'The'): {'said': 3, '<UNK>': 1}
# ('said', 'drink'): {'that': 3, '<UNK>': 1}
# ('drink', 'that'): {'Dewhurst': 3, '<UNK>': 1}
# ('that', 'Dewhurst'): {'.': 3, '<UNK>': 1}
# ('Dewhurst', '.'): {'both': 3, '<UNK>': 1}
# ('both', 'like'): {'project': 3, '<UNK>': 1}
# ('like', 'project'): {'library': 3, '<UNK>': 1}
# ('project', 'library'): {'crossed': 3, '<UNK>': 1}
# ('library', 'crossed'): {'efforts': 3, '<UNK>': 1}
# ('crossed', 'efforts'): {'a': 3, '<UNK>': 1}
# ('efforts', 'a'): {'2770': 3, '<UNK>': 1}
# ('a', '2770'): {'The': 3, '<UNK>': 1}
# ('2770', 'The'): {'where': 3, '<UNK>': 1}
# ('where', 'interest'): {'expectations': 3, '<UNK>': 1}
# ('interest', 'expectations'): {',': 3, '<UNK>': 1}
# ('expectations', ','): {'mobile': 3, '<UNK>': 1}
# (',', 'mobile'): {'oxygen': 3, '<UNK>': 1}
# ('mobile', 'oxygen'): {'the': 3, '<UNK>': 1}
# ('oxygen', 'the'): {'review': 3, '<UNK>': 1}
# ('the', 'review'): {'not': 3, '<UNK>': 1}
# ('review', 'not'): {'their': 3, '<UNK>': 1}
# ('their', 'chair'): {'”': 3, '<UNK>': 1}
# ('chair', '”'): {'.': 3, '<UNK>': 1}
# ('EU', 'bra'): {'resurgence': 3, '<UNK>': 1}
# ('bra', 'resurgence'): {'She': 3, '<UNK>': 1}
# ('resurgence', 'She'): {'over': 3, '<UNK>': 1}
# ('She', 'over'): {'session': 3, '<UNK>': 1}
# ('over', 'session'): {'the': 3, '<UNK>': 1}
# ('do', 'already'): {'have': 3, '<UNK>': 1}
# ('already', 'have'): {'Pakistan': 3, '<UNK>': 1}
# ('have', 'Pakistan'): {',': 3, '<UNK>': 1}
# ('Pakistan', ','): {'through': 3, '<UNK>': 1}
# ('through', '“'): {'George': 3, '<UNK>': 1}
# ('George', 'D.C'): {'about': 3, '<UNK>': 1}
# ('D.C', 'about'): {"n't": 3, '<UNK>': 1}
# ("n't", 'featuring'): {'its': 3, '<UNK>': 1}
# ('featuring', 'its'): {"'s": 3, '<UNK>': 1}
# ('its', "'s"): {'Sport': 3, '<UNK>': 1}
# ("'s", 'Sport'): {'staff': 3, '<UNK>': 1}
# ('Sport', 'staff'): {'Rebuild': 3, '<UNK>': 1}
# ('staff', 'Rebuild'): {'through': 3, '<UNK>': 1}
# ('Rebuild', 'through'): {'and': 3, '<UNK>': 1}
# ('and', 'closed'): {"''": 3, '<UNK>': 1}
# ('closed', "''"): {'–': 3, '<UNK>': 1}
# ("''", '–'): {'in': 3, '<UNK>': 1}
# ('this', 'shut'): {'channel': 3, '<UNK>': 1}
# ('shut', 'channel'): {'qualities': 3, '<UNK>': 1}
# ('channel', 'qualities'): {'while': 3, '<UNK>': 1}
# ('qualities', 'while'): {'’': 3, '<UNK>': 1}
# ('(', 'very'): {'discretionary': 3, '<UNK>': 1}
# ('very', 'discretionary'): {'’': 3, '<UNK>': 1}
# ('discretionary', '’'): {'two': 3, '<UNK>': 1}
# ('two', 'scare'): {'Squire': 3, '<UNK>': 1}
# ('scare', 'Squire'): {'overall': 3, '<UNK>': 1}
# ('Squire', 'overall'): {'from': 3, '<UNK>': 1}
# ('overall', 'from'): {'have': 3, '<UNK>': 1}
# ('have', 'effect'): {'for': 3, '<UNK>': 1}
# ('effect', 'for'): {'.': 3, '<UNK>': 1}
# ('U.S.', 'Rose'): {'one': 3, '<UNK>': 1}
# ('Rose', 'one'): {'August': 3, '<UNK>': 1}
# ('one', 'August'): {'Cheap': 3, '<UNK>': 1}
# ('August', 'Cheap'): {'March-end': 3, '<UNK>': 1}
# ('Cheap', 'March-end'): {'the': 3, '<UNK>': 1}
# ('March-end', 'the'): {'The': 3, '<UNK>': 1}
# ('The', 'Speed'): {'certain': 3, '<UNK>': 1}
# ('Speed', 'certain'): {'trailer': 3, '<UNK>': 1}
# ('certain', 'trailer'): {'taking': 3, '<UNK>': 1}
# ('trailer', 'taking'): {'California': 3, '<UNK>': 1}
# ('taking', 'California'): {'and': 3, '<UNK>': 1}
# ('him', 'best'): {'the': 3, '<UNK>': 1}
# ('that', 'speed'): {'depends': 3, '<UNK>': 1}
# ('speed', 'depends'): {'Bear': 3, '<UNK>': 1}
# ('depends', 'Bear'): {'get': 3, '<UNK>': 1}
# ('Bear', 'get'): {'worked': 3, '<UNK>': 1}
# ('get', 'worked'): {'play': 3, '<UNK>': 1}
# ('worked', 'play'): {'hockey': 3, '<UNK>': 1}
# ('play', 'hockey'): {'upstairs': 3, '<UNK>': 1}
# ('hockey', 'upstairs'): {'open': 3, '<UNK>': 1}
# ('upstairs', 'open'): {'by': 3, '<UNK>': 1}
# ('open', 'by'): {',': 3, '<UNK>': 1}
# ('be', '7466'): {'by': 3, '<UNK>': 1}
# ('7466', 'by'): {'7794': 3, '<UNK>': 1}
# ('by', '7794'): {'and': 3, '<UNK>': 1}
# ('7794', 'and'): {'the': 3, '<UNK>': 1}
# ('the', 'Flour'): {'in': 3, '<UNK>': 1}
# ('Flour', 'in'): {'Fakhrizadeh': 3, '<UNK>': 1}
# ('in', 'Fakhrizadeh'): {'twist': 3, '<UNK>': 1}
# ('Fakhrizadeh', 'twist'): {'any': 3, '<UNK>': 1}
# ('twist', 'any'): {'assistance': 3, '<UNK>': 1}
# ('any', 'assistance'): {'their': 3, '<UNK>': 1}
# ('assistance', 'their'): {'once': 3, '<UNK>': 1}
# ('their', 'once'): {'Gutekunst': 3, '<UNK>': 1}
# ('once', 'Gutekunst'): {'factor': 3, '<UNK>': 1}
# ('Gutekunst', 'factor'): {'to': 3, '<UNK>': 1}
# ('factor', 'to'): {'will': 3, '<UNK>': 1}
# ('will', 'saw'): {'was': 3, '<UNK>': 1}
# ('by', 'There'): {'?': 3, '<UNK>': 1}
# ('There', '?'): {'Irving': 3, '<UNK>': 1}
# ('?', 'Irving'): {'a': 3, '<UNK>': 1}
# ('Irving', 'a'): {'treat': 3, '<UNK>': 1}
# ('a', 'treat'): {'of': 3, '<UNK>': 1}
# ('treat', 'of'): {'check': 3, '<UNK>': 1}
# ('of', 'check'): {'share': 3, '<UNK>': 1}
# ('check', 'share'): {'it': 3, '<UNK>': 1}
# ('share', 'it'): {'6786': 3, '<UNK>': 1}
# ('it', '6786'): {'being': 3, '<UNK>': 1}
# ('6786', 'being'): {',': 3, '<UNK>': 1}
# ('wrote', 'Tuesday'): {',': 3, '<UNK>': 1}
# ('and', 'spot'): {'or': 3, '<UNK>': 1}
# ('spot', 'or'): {'their': 3, '<UNK>': 1}
# ('their', 'when'): {'region': 3, '<UNK>': 1}
# ('when', 'region'): {'Last': 3, '<UNK>': 1}
# ('region', 'Last'): {'critical': 3, '<UNK>': 1}
# ('Last', 'critical'): {'facilitate': 3, '<UNK>': 1}
# ('critical', 'facilitate'): {'2648': 3, '<UNK>': 1}
# ('facilitate', '2648'): {'system': 3, '<UNK>': 1}
# ('2648', 'system'): {'in': 3, '<UNK>': 1}
# ('system', 'in'): {'hijacked': 3, '<UNK>': 1}
# ('in', 'hijacked'): {'with': 3, '<UNK>': 1}
# ('hijacked', 'with'): {'he': 3, '<UNK>': 1}
# ('he', 'f'): {'Trump': 3, '<UNK>': 1}
# ('f', 'Trump'): {'where': 3, '<UNK>': 1}
# ('Trump', 'where'): {'said': 3, '<UNK>': 1}
# ('where', 'said'): {'Orthodox': 3, '<UNK>': 1}
# ('said', 'Orthodox'): {'University': 3, '<UNK>': 1}
# ('Orthodox', 'University'): {'16': 3, '<UNK>': 1}
# ('University', '16'): {'help': 3, '<UNK>': 1}
# ('16', 'help'): {'308,261,000': 3, '<UNK>': 1}
# ('help', '308,261,000'): {'to': 3, '<UNK>': 1}
# ('308,261,000', 'to'): {'concerts': 3, '<UNK>': 1}
# ('to', 'concerts'): {'3662': 3, '<UNK>': 1}
# ('concerts', '3662'): {'of': 3, '<UNK>': 1}
# ('3662', 'of'): {'partisans': 3, '<UNK>': 1}
# ('of', 'partisans'): {'the': 3, '<UNK>': 1}
# ('partisans', 'the'): {'White': 3, '<UNK>': 1}
# ('White', '2055'): {'“': 3, '<UNK>': 1}
# ('2055', '“'): {'but': 3, '<UNK>': 1}
# ('but', 'ensure'): {'tremendous': 3, '<UNK>': 1}
# ('ensure', 'tremendous'): {'feel': 3, '<UNK>': 1}
# ('tremendous', 'feel'): {'security': 3, '<UNK>': 1}
# ('feel', 'security'): {'heading': 3, '<UNK>': 1}
# ('security', 'heading'): {'Jet': 3, '<UNK>': 1}
# ('heading', 'Jet'): {'while': 3, '<UNK>': 1}
# ('Jet', 'while'): {'s': 3, '<UNK>': 1}
# ('while', 's'): {'is': 3, '<UNK>': 1}
# ('is', 'Agostino'): {'went': 3, '<UNK>': 1}
# ('Agostino', 'went'): {'Africa': 3, '<UNK>': 1}
# ('went', 'Africa'): {'locally': 3, '<UNK>': 1}
# ('Africa', 'locally'): {'there': 3, '<UNK>': 1}
# ('locally', 'there'): {'the': 3, '<UNK>': 1}
# ('create', 'shift'): {'her': 3, '<UNK>': 1}
# ('shift', 'her'): {'as': 3, '<UNK>': 1}
# ('Company', 'were'): {'cleared': 3, '<UNK>': 1}
# ('were', 'cleared'): {'No': 3, '<UNK>': 1}
# ('cleared', 'No'): {'file': 3, '<UNK>': 1}
# ('No', 'file'): {'improving': 3, '<UNK>': 1}
# ('file', 'improving'): {'week': 3, '<UNK>': 1}
# ('improving', 'week'): {'and': 3, '<UNK>': 1}
# ('and', 'Insisting'): {',': 3, '<UNK>': 1}
# ('Insisting', ','): {'for': 3, '<UNK>': 1}
# ('for', 'somewhere'): {'releasing': 3, '<UNK>': 1}
# ('somewhere', 'releasing'): {'bearing': 3, '<UNK>': 1}
# ('releasing', 'bearing'): {'Kenosha': 3, '<UNK>': 1}
# ('bearing', 'Kenosha'): {'them': 3, '<UNK>': 1}
# ('Kenosha', 'them'): {'.': 3, '<UNK>': 1}
# ('the', 'Kepler'): {'Iran': 3, '<UNK>': 1}
# ('Kepler', 'Iran'): {'that': 3, '<UNK>': 1}
# ('Iran', 'that'): {'their': 3, '<UNK>': 1}
# ('India', 'party'): {'the': 3, '<UNK>': 1}
# ('in', 'store'): {'in': 3, '<UNK>': 1}
# ('most', 'powerhouse'): {'offered': 3, '<UNK>': 1}
# ('powerhouse', 'offered'): {'everyone': 3, '<UNK>': 1}
# ('offered', 'everyone'): {'A': 3, '<UNK>': 1}
# ('everyone', 'A'): {'regions': 3, '<UNK>': 1}
# ('A', 'regions'): {'of': 3, '<UNK>': 1}
# ('regions', 'of'): {'there': 3, '<UNK>': 1}
# ('there', 'Stadium'): {'“': 3, '<UNK>': 1}
# ('Stadium', '“'): {'Television': 3, '<UNK>': 1}
# ('“', 'Television'): {'steal': 3, '<UNK>': 1}
# ('Television', 'steal'): {'at': 3, '<UNK>': 1}
# ('steal', 'at'): {'was': 3, '<UNK>': 1}
# ('was', 'or'): {'’': 3, '<UNK>': 1}
# ('president', '1909'): {'children': 3, '<UNK>': 1}
# ('1909', 'children'): {',': 3, '<UNK>': 1}
# (',', 'beer'): {'t': 3, '<UNK>': 1}
# ('beer', 't'): {'on': 3, '<UNK>': 1}
# ('on', '9326'): {'the': 3, '<UNK>': 1}
# ('9326', 'the'): {'Netanyahu': 3, '<UNK>': 1}
# ('the', 'Netanyahu'): {'Compression': 3, '<UNK>': 1}
# ('Netanyahu', 'Compression'): {'Carra': 3, '<UNK>': 1}
# ('Compression', 'Carra'): {'bargained': 3, '<UNK>': 1}
# ('Carra', 'bargained'): {'number': 3, '<UNK>': 1}
# ('bargained', 'number'): {'dealing': 3, '<UNK>': 1}
# ('number', 'dealing'): {'9419': 3, '<UNK>': 1}
# ('dealing', '9419'): {'at': 3, '<UNK>': 1}
# ('9419', 'at'): {'there': 3, '<UNK>': 1}
# ('at', 'there'): {'”': 3, '<UNK>': 1}
# ('of', 'charitable'): {'a': 3, '<UNK>': 1}
# ('charitable', 'a'): {'pots': 3, '<UNK>': 1}
# ('a', 'pots'): {'8306': 3, '<UNK>': 1}
# ('pots', '8306'): {'Trump': 3, '<UNK>': 1}
# ('8306', 'Trump'): {'and': 3, '<UNK>': 1}
# ('.', 'intervention'): {'lining': 3, '<UNK>': 1}
# ('intervention', 'lining'): {'Lemon': 3, '<UNK>': 1}
# ('lining', 'Lemon'): {'try': 3, '<UNK>': 1}
# ('Lemon', 'try'): {'.': 3, '<UNK>': 1}
# ('.', 'Gov'): {'Soon': 3, '<UNK>': 1}
# ('Gov', 'Soon'): {'virus': 3, '<UNK>': 1}
# ('Soon', 'virus'): {'necessarily': 3, '<UNK>': 1}
# ('virus', 'necessarily'): {'2828': 3, '<UNK>': 1}
# ('necessarily', '2828'): {',': 3, '<UNK>': 1}
# ('2828', ','): {'division': 3, '<UNK>': 1}
# (',', 'division'): {'others': 3, '<UNK>': 1}
# ('division', 'others'): {'by': 3, '<UNK>': 1}
# ('others', 'by'): {'to': 3, '<UNK>': 1}
# ('to', 'guidance'): {'expansion': 3, '<UNK>': 1}
# ('guidance', 'expansion'): {'improve': 3, '<UNK>': 1}
# ('expansion', 'improve'): {'fatal': 3, '<UNK>': 1}
# ('improve', 'fatal'): {'11-2-2': 3, '<UNK>': 1}
# ('fatal', '11-2-2'): {'ability': 3, '<UNK>': 1}
# ('11-2-2', 'ability'): {'games': 3, '<UNK>': 1}
# ('ability', 'games'): {'435': 3, '<UNK>': 1}
# ('games', '435'): {'at': 3, '<UNK>': 1}
# ('435', 'at'): {'academic': 3, '<UNK>': 1}
# ('at', 'academic'): {'their': 3, '<UNK>': 1}
# ('academic', 'their'): {'.': 3, '<UNK>': 1}
# ('.', 'organizing'): {'and': 3, '<UNK>': 1}
# ('organizing', 'and'): {'’': 3, '<UNK>': 1}
# ('of', 'markets'): {'deserve': 3, '<UNK>': 1}
# ('markets', 'deserve'): {'accused': 3, '<UNK>': 1}
# ('deserve', 'accused'): {'GO': 3, '<UNK>': 1}
# ('accused', 'GO'): {'no': 3, '<UNK>': 1}
# ('GO', 'no'): {'now': 3, '<UNK>': 1}
# ('no', 'now'): {'Voter': 3, '<UNK>': 1}
# ('now', 'Voter'): {'COVID-19': 3, '<UNK>': 1}
# ('Voter', 'COVID-19'): {'attacks': 3, '<UNK>': 1}
# ('COVID-19', 'attacks'): {'.': 3, '<UNK>': 1}
# ('.', 'Sako'): {'any': 3, '<UNK>': 1}
# ('Sako', 'any'): {'described': 3, '<UNK>': 1}
# ('any', 'described'): {'get': 3, '<UNK>': 1}
# ('described', 'get'): {'in': 3, '<UNK>': 1}
# ('in', 'lifted'): {'Rolling': 3, '<UNK>': 1}
# ('lifted', 'Rolling'): {'Abhijeet': 3, '<UNK>': 1}
# ('Rolling', 'Abhijeet'): {'United': 3, '<UNK>': 1}
# ('Abhijeet', 'United'): {'Telles': 3, '<UNK>': 1}
# ('United', 'Telles'): {'carbon': 3, '<UNK>': 1}
# ('Telles', 'carbon'): {'we': 3, '<UNK>': 1}
# ('carbon', 'we'): {'all': 3, '<UNK>': 1}
# ('we', 'all'): {'2685': 3, '<UNK>': 1}
# ('all', '2685'): {'and': 3, '<UNK>': 1}
# ('2685', 'and'): {'average': 3, '<UNK>': 1}
# ('average', 'Clasic'): {'time': 3, '<UNK>': 1}
# ('Clasic', 'time'): {'capacity': 3, '<UNK>': 1}
# ('time', 'capacity'): {'a': 3, '<UNK>': 1}
# ('capacity', 'a'): {'Lucy': 3, '<UNK>': 1}
# ('a', 'Lucy'): {'month': 3, '<UNK>': 1}
# ('Lucy', 'month'): {'vouchers': 3, '<UNK>': 1}
# ('month', 'vouchers'): {'crisis': 3, '<UNK>': 1}
# ('vouchers', 'crisis'): {'against': 3, '<UNK>': 1}
# ('crisis', 'against'): {'have': 3, '<UNK>': 1}
# ('have', '—'): {'of': 3, '<UNK>': 1}
# ('of', 'references'): {'and': 3, '<UNK>': 1}
# ('references', 'and'): {'fail': 3, '<UNK>': 1}
# ('and', 'fail'): {'McKinney': 3, '<UNK>': 1}
# ('fail', 'McKinney'): {'has': 3, '<UNK>': 1}

# %%
def calculate_sentence_probability(sentence, model):
    # words = sentence.split()
    probability = 1.0

    # Calculate probability using the bigram model
    if len(sentence) < 2:
        return probability

    for i in range(len(sentence) - 1):
        current_word, next_word = sentence[i], sentence[i + 1]
        if current_word in model and next_word in model[current_word]:
            transition_probability = model[current_word][next_word] / sum(model[current_word].values())
            probability *= transition_probability
        else:
            # Handle unknown words using Laplace smoothing
            numerator = model[current_word].get(next_word, 0) + 1  # Add 1 for Laplace smoothing
            denominator = sum(model[current_word].values()) + len(model[current_word])  # Add vocabulary size for Laplace smoothing
            if denominator != 0:  # Avoid division by zero
                transition_probability = numerator / denominator
                probability *= transition_probability

    return probability

# %%
# print()
val_tokens=np.array(val_tokens)
val_tokens
# Out:
# array(['the', 'permits', 'director', ..., 'suspects', 'least', '7570'],
#       dtype='<U22')

# %%
# Example usage
# test_sentence = "This is a test sentence."
bigram_probability = calculate_sentence_probability(val_tokens, bigram_model_smoothed)
trigram_probability = calculate_sentence_probability(val_tokens, trigram_model_smoothed)

print("Probability of the sentence using Bigram Model with Laplace Smoothing:", bigram_probability)
print("Probability of the sentence using Trigram Model with Laplace Smoothing:", trigram_probability)
# Out:
# Probability of the sentence using Bigram Model with Laplace Smoothing: 0.0
# Probability of the sentence using Trigram Model with Laplace Smoothing: 1.0

# %%
def evaluate_models(test_data, bigram_model, trigram_model):
    correct_bigram_predictions = 0
    correct_trigram_predictions = 0
    total_sentences = len(test_data)

    for sentence in test_data:
        # Calculate probability for bigram model
        bigram_probability = calculate_sentence_probability(sentence, bigram_model_smoothed)

        # Calculate probability for trigram model
        trigram_probability = calculate_sentence_probability(sentence, trigram_model_smoothed)

        # Determine which model has higher probability
        if bigram_probability > trigram_probability:
            correct_bigram_predictions += 1
        elif bigram_probability < trigram_probability:
            correct_trigram_predictions += 1
        else:
            # If probabilities are equal, we can choose any model
            correct_bigram_predictions += 1

    # Calculate accuracy
    bigram_accuracy = (correct_bigram_predictions / total_sentences) * 100
    trigram_accuracy = (correct_trigram_predictions / total_sentences) * 100

    return bigram_accuracy, trigram_accuracy

# Evaluate the models
bigram_accuracy, trigram_accuracy = evaluate_models(val_tokens, bigram_model_smoothed, trigram_model_smoothed)

# Print the accuracy of each model
print("Bigram Model Accuracy:", bigram_accuracy)
print("Trigram Model Accuracy:", trigram_accuracy)
# Out:
# Bigram Model Accuracy: 22.758358662613983
# Trigram Model Accuracy: 77.24164133738601
